# %% [markdown]
# # NFL Baseline
# - create target_df (distance in tracking_df is lower than threshold=3)
# https://www.kaggle.com/code/stgkrtua/nfl-creatatraindataset-targetdf
# - create dataset save frames in target_df
# https://www.kaggle.com/code/stgkrtua/nfl-createdataset-saveframes
# - check saved images
# https://www.kaggle.com/code/stgkrtua/nfl-checkdataset-plotsavedimage

# %% [markdown]
# # import libraries

# %%
# general
import os
import gc
import pickle
import glob
import random
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import cv2
import matplotlib.pyplot as plt
import time
import math

import sys
sys.path.append('/kaggle/input/timm-pytorch-image-models/pytorch-image-models-master')
import timm


# deep learning
from torch.utils.data import Dataset, DataLoader
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import albumentations as A
from albumentations.pytorch import ToTensorV2

from sklearn.model_selection import StratifiedKFold

# loss metrics
from sklearn.metrics import matthews_corrcoef, confusion_matrix, roc_auc_score

import mlflow
# import wandb
# warningの表示方法の設定
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Set Configurations

# %%
CFG = {
        "kaggle" : False,
        "DEBUG" : False,
        # model config
        "model_name" : "swin_s3_tiny_224",
        "out_features" : 20,
        "inp_channels": 3*2,
        "num_extractFTR" : 5,
        "pretrained" : True,
        "features" : ['x_position_1', 'y_position_1', 'x_position_2', 'y_position_2', 
                      'speed_1', 'distance_1', 'direction_1', 'orientation_1','acceleration_1', 'sa_1', 
                      'speed_2', 'distance_2', 'direction_2', 'orientation_2', 'acceleration_2', 'sa_2',
                      'players_dis', 'is_ground'],
        "track_features_x_1" : ['x_position_shift-6_1','x_position_shift-5_1', 'x_position_shift-4_1',
                                'x_position_shift-3_1','x_position_shift-2_1', 'x_position_shift-1_1', 
                                'x_position_shift0_1','x_position_shift1_1', 'x_position_shift2_1', 
                                'x_position_shift3_1','x_position_shift4_1', 'x_position_shift5_1'],    
        "track_features_y_1" : ['y_position_shift-6_1','y_position_shift-5_1', 'y_position_shift-4_1',
                                'y_position_shift-3_1','y_position_shift-2_1', 'y_position_shift-1_1',
                                'y_position_shift0_1','y_position_shift1_1', 'y_position_shift2_1',
                                'y_position_shift3_1','y_position_shift4_1', 'y_position_shift5_1'],
        "track_features_x_2" : ['x_position_shift-6_2','x_position_shift-5_2', 'x_position_shift-4_2',
                                'x_position_shift-3_2','x_position_shift-2_2', 'x_position_shift-1_2',
                                'x_position_shift0_2','x_position_shift1_2', 'x_position_shift2_2',
                                'x_position_shift3_2','x_position_shift4_2', 'x_position_shift5_2'],
        "track_features_y_2" : ['y_position_shift-6_2','y_position_shift-5_2', 'y_position_shift-4_2',
                                'y_position_shift-3_2','y_position_shift-2_2', 'y_position_shift-1_2',
                                'y_position_shift0_2','y_position_shift1_2', 'y_position_shift2_2',
                                'y_position_shift3_2','y_position_shift4_2', 'y_position_shift5_2'],
        # learning config
        "n_epoch" : 20,
        "lr" : 5e-4,
        "T_max" : 10,
        "min_lr" : 1e-8,
        "weight_decay" : 1e-6,

        # etc
        "print_freq" : 1000,
        "random_seed" : 21,

        # data config    
        "img_size" : (224, 224),
        "batch_size" : 32,
        "num_workers" : 8,
        "masksize_helmet_ratio" : 4, # helmetサイズにこの係数をかけたサイズだけ色を残して後は黒塗りする
        "TRAIN_VIDEO_NUM" : 100,
        "VALID_VIDEO_NUM" : 10,
        "sample_num" : -1, 

        "EXP_CATEGORY" : "exps",
        "EXP_NAME" : "exp006_swins3tiny_extractFTR",
}

if CFG["DEBUG"]:
    CFG["EXP_CATEGORY"] = "DEBUG"
    CFG["EXP_NAME"] = "DEBUG"
    CFG["n_epoch"] = 2
    CFG["sample_num"] = 1000
    CFG["batch_size"] = 32

if CFG["kaggle"]:
    CFG["INPUT_DIR"] = "/kaggle/input/"
    CFG["OUTPUT_DIR"] = "/kaggle/working/"
    CFG["TRAIN_HELMET_CSV"] = os.path.join(CFG["INPUT_DIR"], "nfl-player-contact-detection", "train_baseline_helmets.csv")
    CFG["TRAIN_TRACKING_CSV"] = os.path.join(CFG["INPUT_DIR"], "nfl-player-contact-detection", "train_player_tracking.csv")
    CFG["TRAIN_VIDEO_META_CSV"] = os.path.join(CFG["INPUT_DIR"], "nfl-player-contact-detection", "train_video_metadata.csv")
    CFG["TRAIN_LABEL_CSV"] = os.path.join(CFG["INPUT_DIR"], "nfl-player-contact-detection", "train_labels.csv")
    CFG["TARGET_CSV"] = os.path.join(CFG["INPUT_DIR"], "nfl-createdataset-saveframes-shift", "saved_frame_target.csv")
    CFG["TRAIN_E_IMG_DIR"] = os.path.join(CFG["INPUT_DIR"], "nfl-createdataset-saveframes-shift", "train_images")
    CFG["TRAIN_S_IMG_DIR"] = os.path.join(CFG["INPUT_DIR"], "nfl-createdataset-saveframes-shift-sview", "train_images")
    CFG["MODEL_DIR"] = CFG["OUTPUT_DIR"]
else:
    CFG["INPUT_DIR"] = "/workspace/input"
    CFG["OUTPUT_DIR"] = "/workspace/output"
    CFG["TRAIN_HELMET_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_baseline_helmets.csv")
    CFG["TRAIN_TRACKING_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_player_tracking.csv")
    CFG["TRAIN_VIDEO_META_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_video_metadata.csv")
    CFG["TRAIN_LABEL_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_labels.csv")
    CFG["TARGET_CSV"] = os.path.join(CFG["INPUT_DIR"], "target_fillna0_shift_2.csv")
    CFG["TRAIN_E_IMG_DIR"] = os.path.join(CFG["INPUT_DIR"], "train_frames")
    CFG["TRAIN_S_IMG_DIR"] = CFG["TRAIN_E_IMG_DIR"]
    CFG["CONTACT_IMG_DIR"] = os.path.join(CFG["INPUT_DIR"], "contact_images")
    CFG["MODEL_DIR"] = os.path.join(CFG["OUTPUT_DIR"], CFG["EXP_NAME"] ,"model")
    
if not CFG["kaggle"] and not CFG["DEBUG"]:
    os.mkdir(os.path.join(CFG["OUTPUT_DIR"], CFG["EXP_NAME"]))
    os.mkdir(CFG["MODEL_DIR"])

# %%
if CFG["kaggle"]:
    os.environ["WANDB_SILENT"] = "true"
    WANDB_CONFIG = {'competition': 'NFL', '_wandb_kernel': 'taro'}
    # Secrets
    from kaggle_secrets import UserSecretsClient
    user_secrets = UserSecretsClient()
    secret_value_0 = user_secrets.get_secret("wandb")

    # !wandb login $secret_value_0
    #! TODO : logger settings
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"])

else:
    mlflow.set_tracking_uri("/workspace/mlruns")
    experiment = mlflow.get_experiment_by_name(CFG["EXP_CATEGORY"])
    if experiment is None:  # 当該Experiment存在しないとき、新たに作成
        experiment_id = mlflow.create_experiment(name=CFG["EXP_CATEGORY"])
    else: # 当該Experiment存在するとき、IDを取得
        experiment_id = experiment.experiment_id

# %% [markdown]
# # Utils

# %%
def logging_metrics_epoch(fold, epoch, train_loss_avg, valid_loss_avg, score, threshold, tn_best, fp_best, fn_best, tp_best, auc_score):
    if CFG["kaggle"]:
        wandb.log({"loss avg":{f"train/fold{fold}": train_loss_avg,
                                f"valid/fold{fold}": valid_loss_avg}}, step=epoch)
        wandb.log({"Metircs" : {f"score/fold{fold}":score,
                                f"score threshold/fold{fold}":threshold,
                                f"tn/fold{fold}":tn_best,
                                f"fp/fold{fold}":fp_best,
                                f"fn/fold{fold}":fn_best,
                                f"tp/fold{fold}":tp_best,
                                f"auc/fold{fold}":auc_score,
                               }}, step=epoch)
    else:
        mlflow.log_metric(f"fold{fold} train loss avg", train_loss_avg, step=epoch)
        mlflow.log_metric(f"fold{fold} valid loss avg", valid_loss_avg, step=epoch)
        mlflow.log_metric(f"fold{fold} score", score, step=epoch)
        mlflow.log_metric(f"fold{fold} score threshold", threshold, step=epoch)
        mlflow.log_metric(f"fold{fold} tn", tn_best, step=epoch)
        mlflow.log_metric(f"fold{fold} fp", fp_best, step=epoch)
        mlflow.log_metric(f"fold{fold} fn", fn_best, step=epoch)
        mlflow.log_metric(f"fold{fold} tp", tp_best, step=epoch)
        mlflow.log_metric(f"fold{fold} auc", auc_score, step=epoch)

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed%(2**32-1))
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # Load Data

# %%
target_df = pd.read_csv(CFG["TARGET_CSV"])
# target_game_plays = target_df["game_play"].unique()[:50]
train_game_plays = target_df["game_play"].unique()[:CFG["TRAIN_VIDEO_NUM"]]
valid_game_plays = target_df["game_play"].unique()[-CFG["VALID_VIDEO_NUM"]:]
target_game_plays = list(set(train_game_plays) | set(valid_game_plays))
CFG["target_game_plays"] = list(target_game_plays)
target_df = target_df[target_df["game_play"].isin(target_game_plays)]

if CFG["DEBUG"]:
    target_df = target_df.sample(CFG["sample_num"])
elif CFG["sample_num"] != -1:
    target_df = target_df.sample(CFG["sample_num"])

target_df["is_ground"] = (target_df["nfl_player_id_2"] == "G").astype(np.int)
print(len(target_df))
display(target_df["contact"].value_counts())
# Out:
# 305164
# 0    274357
# 1     30807
# Name: contact, dtype: int64

# %%
# diff_cols = ['speed', 'distance', 'direction', 'orientation','acceleration', 'sa']

# for col in diff_cols:
#     target_df[f"{col}_diff"] = abs(target_df[f"{col}_1"] - target_df[f"{col}_2"])

# %%
train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.3, 0.3), p=0.5),
    A.Normalize(mean=[0.], std=[1.]),
    ToTensorV2()
])

valid_transform = A.Compose([
    A.Normalize(mean=[0.], std=[1.]),
    ToTensorV2()
])

# %% [markdown]
# # Dataset

# %%
class NFLDataset(Dataset):
    def __init__(self, target_df, transform=None):
        self.target_df = target_df
        self.features = target_df[CFG["features"]].values
        self.track_features_x_1 = target_df[CFG["track_features_x_1"]].values
        self.track_features_y_1 = target_df[CFG["track_features_y_1"]].values
        self.track_features_x_2 = target_df[CFG["track_features_x_2"]].values
        self.track_features_y_2 = target_df[CFG["track_features_y_2"]].values
        self.transform = transform

    def __len__(self):
        return len(self.target_df)

    def __getitem__(self, idx):
        target_info = self.target_df.iloc[idx]
        features = self.features[idx]
        track_x_1 = self.track_features_x_1[idx]
        track_y_1 = self.track_features_y_1[idx]
        track_x_2 = self.track_features_x_2[idx]
        track_y_2 = self.track_features_y_2[idx]
        track_features = np.concatenate([track_x_1[np.newaxis, :],
                                         track_y_1[np.newaxis, :],
                                         track_x_2[np.newaxis, :],
                                         track_y_2[np.newaxis, :]])

        target = target_info.contact
        # read frame image
        game_play = target_info.game_play
        frame = target_info.frame
        contact_id = target_info.contact_id
        contact_fileid = f"{contact_id}_Endzone.jpg"
        contact_filename = os.path.join(CFG["CONTACT_IMG_DIR"], contact_fileid)
        img = cv2.imread(contact_filename)
        if img is None:
            img = np.zeros((224, 224, 3))
            img = np.transpose(img, (2, 0, 1)).astype(np.float)
            img = torch.tensor(img, dtype=torch.float)
        else:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img / 255. # convert to 0-1
                img = np.transpose(img, (2, 0, 1)).astype(np.float32)
            img = torch.tensor(img, dtype=torch.float)
        input_img = img
        contact_fileid = f"{contact_id}_Sideline.jpg"
        contact_filename = os.path.join(CFG["CONTACT_IMG_DIR"], contact_fileid)
        img = cv2.imread(contact_filename)
        if img is None:
            img = np.zeros((224, 224, 3))
            img = np.transpose(img, (2, 0, 1)).astype(np.float)
            img = torch.tensor(img, dtype=torch.float)
        else:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img / 255. # convert to 0-1
                img = np.transpose(img, (2, 0, 1)).astype(np.float32)
            img = torch.tensor(img, dtype=torch.float)
        input_img = np.concatenate([input_img, img], axis=0)
        input_img = torch.tensor(input_img, dtype=torch.float)
        target = torch.tensor(target, dtype=torch.float)
        features = torch.tensor(features, dtype=torch.float)
        track_features = torch.tensor(track_features, dtype=torch.float)
        return input_img, features, track_features, target

# %%
# checkするときは255.で割るのを全体にかける(normalizeがcheckにはないので真っ白とか真っ黒になるのを回避)
# show_img_num = 4

# check_transform = A.Compose([
#     A.HorizontalFlip(p=1.0),
#     A.RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.3, 0.3), p=1.0),
# #     A.Normalize(mean=[0.], std=[1.]),
#     ToTensorV2()
# ])


# pick_df = target_df[target_df["contact"]==1]
# train_dataset = NFLDataset(pick_df, check_transform)
# train_loader = DataLoader(
#     train_dataset,
#     batch_size = show_img_num,
#     shuffle = False,
#     num_workers = CFG["num_workers"],
#     pin_memory = True
# )
# for batch_idx, (images, features, track_features, targets) in enumerate(train_loader):
#     fig = plt.figure(figsize=(12, 25))
#     print(images.shape)
#     print("features shape =",features.shape)
#     print("track features shape =",track_features.shape)
#     for idx in range(show_img_num):
#         img = images[idx].numpy()
#         img = img.transpose((1,2,0))
#         img = img[:, :, 0:3]
#         fig.add_subplot(1,show_img_num ,idx+1)
#         plt.imshow(img)
#         plt.title(targets[idx].numpy())
#     plt.show()
    
#     fig = plt.figure(figsize=(12, 25))
#     for idx in range(show_img_num):
#         img = images[idx].numpy()
#         img = img.transpose((1,2,0))
#         img = img[:, :, 3:6]
#         fig.add_subplot(1,show_img_num ,idx+1)
#         plt.imshow(img)
#         plt.title(targets[idx].numpy())
#     plt.show()
#     break
# del train_loader, train_dataset

# pick_df = target_df[target_df["contact"]==1]
# train_dataset = NFLDataset(pick_df)
# train_loader = DataLoader(
#     train_dataset,
#     batch_size = show_img_num,
#     shuffle = False,
#     num_workers = CFG["num_workers"],
#     pin_memory = True
# )
# for batch_idx, (images, features, track_features, targets) in enumerate(train_loader):
#     fig = plt.figure(figsize=(12, 25))
#     print(images.shape)
#     print("features shape =",features.shape)
#     print("track features shape =",track_features.shape)
#     for idx in range(show_img_num):
#         img = images[idx].numpy()
#         img = img.transpose((1,2,0))
#         img = img[:, :, 0:3]
#         fig.add_subplot(1,show_img_num ,idx+1)
#         plt.imshow(img)
#         plt.title(targets[idx].numpy())
#     plt.show()
    
#     fig = plt.figure(figsize=(12, 25))
#     for idx in range(show_img_num):
#         img = images[idx].numpy()
#         img = img.transpose((1,2,0))
#         img = img[:, :, 3:6]
#         fig.add_subplot(1,show_img_num ,idx+1)
#         plt.imshow(img)
#         plt.title(targets[idx].numpy())
#     plt.show()
#     break
# del train_loader, train_dataset

# %% [markdown]
# # Model

# %%
# without meta
class NFLNet(nn.Module):
    def __init__(
        self,
        model_name = CFG["model_name"],
        out_features = CFG["out_features"],
        inp_channels= CFG["inp_channels"],
        pretrained = CFG["pretrained"]
    ):
        super().__init__()
        self.model = timm.create_model(model_name, pretrained=pretrained, in_chans=inp_channels, num_classes=out_features)
        self.mlp = nn.Sequential(
                        nn.Linear(len(CFG["features"]), 32),
                        nn.LayerNorm(32),
                        nn.ReLU(),
                        nn.Dropout(0.2),
                    )
        self.conv1 = nn.Sequential(
                        nn.Conv1d(4, 1, 5),
                        nn.Linear(len(CFG["track_features_y_2"])-4, 32),
                        nn.ReLU(),
                    )
        self.fc = nn.Linear(out_features+32+32, 1)
        self.emb = nn.Linear(out_features+32, CFG["num_extractFTR"])

    def forward(self, image, features, track_features):
        image_feature = self.model(image)
        features = self.mlp(features)
        track_features = self.conv1(track_features)
        if features.shape[0] == 1:
            track_featurs = track_featurs.reshape(1, -1)
        else:
            track_featurs = torch.squeeze(track_features)
        output = self.fc(torch.cat([image_feature, features, track_featurs], dim=1))
        embeddings = self.emb(torch.cat([image_feature, track_featurs], dim=1))
        return output, embeddings

# %% [markdown]
# # train fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start, end = time.time(), time.time()
    for batch_idx, (images, features, track_features, targets) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float().view(-1, 1)      
        features = features.to(device, non_blocking = True).float()
        track_features = track_features.to(device, non_blocking = True).float()
        preds, _ = model(images, features, track_features)
        
        loss = criterion(preds, targets)
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = torch.sigmoid(preds).detach().cpu().numpy().ravel().tolist()

        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('\t Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, features, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %% [markdown]
# # valid fn

# %%
def valid_fn(model, valid_loader, criterion):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []

    batch_time = AverageMeter()
    losses = AverageMeter()
    start, end = time.time(), time.time()
    for batch_idx, (images, features, track_features, targets) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float().view(-1, 1)
        features = features.to(device, non_blocking = True).float()
        track_features = track_features.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds, _ = model(images, features, track_features)
            loss = criterion(preds, targets)
        losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = torch.sigmoid(preds).detach().cpu().numpy().ravel().tolist()

        test_preds.extend(preds)
        test_targets.extend(targets)
        # score = matthews_corrcoef(preds, targets)
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1):
            print('\t EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, features, targets
        gc.collect()
        torch.cuda.empty_cache()
    test_preds = np.array(test_preds)
    test_targets = np.array(test_targets)
    return test_targets, test_preds, losses.avg

# %% [markdown]
# # Train loop

# %%
def training_loop(target_df):
    # set model & learning fn
    model = NFLNet()
    model = model.to(device)
    if CFG["kaggle"]:
        wandb.watch(model)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
    scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)

    oof_df = pd.DataFrame()
    fold = 0
    # separate train/valid data 
    train_df = target_df[target_df["game_play"].isin(train_game_plays)]
    valid_df = target_df[target_df["game_play"].isin(valid_game_plays)]
    train_dataset = NFLDataset(train_df, train_transform)
    valid_dataset = NFLDataset(valid_df, valid_transform)
    train_loader = DataLoader(train_dataset,batch_size=CFG["batch_size"], shuffle = True,
                                num_workers = CFG["num_workers"], pin_memory = True)
    valid_loader = DataLoader(valid_dataset,batch_size=CFG["batch_size"], shuffle = False,
                                num_workers = CFG["num_workers"], pin_memory = True)

    # training
    best_score = -np.inf
    best_auc = -np.inf
    start_time, end = time.time(), time.time()
    for epoch in range(1, CFG["n_epoch"] + 1):
        print(f'\t === epoch: {epoch}: training ===')
        train_loss_avg = train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler)
        valid_targets, valid_preds, valid_loss_avg = valid_fn(model, valid_loader, criterion)

        valid_score = -np.inf
        valid_threshold = 0
        tn_best, fp_best, fn_best, tp_best = 0, 0, 0, 0
        for idx in range(1, 10, 1):
            thr = idx*0.1
            valid_targets = (np.array(valid_targets) > thr).astype(np.int32)
            valid_binary_preds = (np.array(valid_preds) > thr).astype(np.int32)
            score_tmp = matthews_corrcoef(valid_targets, valid_binary_preds)
            cm = confusion_matrix(valid_targets, valid_binary_preds)
            tn, fp, fn, tp = cm.flatten()
            if score_tmp > valid_score:
                valid_score = score_tmp 
                valid_threshold = thr
                tn_best, fp_best, fn_best, tp_best = tn, fp, fn, tp
        elapsed = time.time() - start_time
        print(f'\t epoch:{epoch}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}, score:{valid_score:.4f}(th={valid_threshold}) ::: time:{elapsed:.2f}s')
        scheduler.step()
        # validationスコアがbestを更新したらモデルを保存する
        if valid_score > best_score:
            best_score = valid_score
            model_name = CFG["model_name"]
            torch.save(model.state_dict(), f'{CFG["MODEL_DIR"]}/{model_name}_fold{fold}.pth')
            print(f'\t Epoch {epoch} - Save Best Score: {best_score:.4f}. Model is saved.')
            contact_id = valid_df["contact_id"].values
            _oof_df = pd.DataFrame({
                "contact_id" : contact_id,
                "pred" : valid_preds,
                "contact" : valid_targets,
                "fold" : fold,
            })
            
        auc_score = roc_auc_score(valid_targets, valid_preds)
        if best_auc < auc_score:
            best_auc = auc_score
            model_name = CFG["model_name"]
            torch.save(model.state_dict(), f'{CFG["MODEL_DIR"]}/{model_name}_bestauc_fold{fold}.pth')
            print(f'\t Epoch {epoch} - Save Best AUC Score: {best_auc:.4f}. Model is saved.')
            
        logging_metrics_epoch(fold, epoch, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, tn_best, fp_best, fn_best, tp_best, auc_score)

    del train_loader, train_dataset, valid_loader, valid_dataset
    oof_df = pd.concat([oof_df, _oof_df], axis = 0)
    del _oof_df
    gc.collect()
    torch.cuda.empty_cache()
    return oof_df

# %%
if CFG["kaggle"]:
    oof_df = training_loop(target_df)
    wandb.finish()
else:
    with mlflow.start_run(experiment_id=experiment_id, run_name=CFG["EXP_NAME"]) as run:
        mlflow.log_dict(CFG, "configuration.yaml")
        mlflow.log_param("positive data num", len(target_df[target_df["contact"]==1]))
        mlflow.log_param("negative data num", len(target_df[target_df["contact"]==0]))
        oof_df = training_loop(target_df)
# Out:
# 	 === epoch: 1: training ===
# 	 Epoch: [1][0/8782] Elapsed 0m 1s (remain 247m 45s) Loss: 0.5872(0.5872)
# 	 Epoch: [1][1000/8782] Elapsed 2m 4s (remain 16m 4s) Loss: 0.3276(0.3105)
# 	 Epoch: [1][2000/8782] Elapsed 4m 6s (remain 13m 55s) Loss: 0.0635(0.3073)
# 	 Epoch: [1][3000/8782] Elapsed 6m 8s (remain 11m 50s) Loss: 0.4080(0.3025)
# 	 Epoch: [1][4000/8782] Elapsed 8m 11s (remain 9m 46s) Loss: 0.3024(0.2988)
# 	 Epoch: [1][5000/8782] Elapsed 10m 13s (remain 7m 43s) Loss: 0.2852(0.2952)
# 	 Epoch: [1][6000/8782] Elapsed 12m 16s (remain 5m 41s) Loss: 0.4229(0.2929)
# 	 Epoch: [1][7000/8782] Elapsed 14m 18s (remain 3m 38s) Loss: 0.3966(0.2907)
# 	 Epoch: [1][8000/8782] Elapsed 16m 20s (remain 1m 35s) Loss: 0.0984(0.2891)
# 	 Epoch: [1][8781/8782] Elapsed 17m 55s (remain 0m 0s) Loss: 0.1035(0.2874)
# 	 EVAL: [0/756] Elapsed 0m 1s (remain 15m 35s) Loss: 0.0638(0.0638)
# 	 EVAL: [755/756] Elapsed 1m 43s (remain 0m 0s) Loss: 0.0208(0.2356)
# 	 epoch:1, avg train loss:0.2874, avg valid loss:0.2356, score:0.3559(th=0.2) ::: time:1179.37s
# 	 Epoch 1 - Save Best Score: 0.3559. Model is saved.
# 	 Epoch 1 - Save Best AUC Score: 0.8215. Model is saved.
# 	 === epoch: 2: training ===
# 	 Epoch: [2][0/8782] Elapsed 0m 1s (remain 168m 37s) Loss: 0.2478(0.2478)
# 	 Epoch: [2][1000/8782] Elapsed 2m 1s (remain 15m 42s) Loss: 0.3737(0.2705)
# 	 Epoch: [2][2000/8782] Elapsed 4m 1s (remain 13m 37s) Loss: 0.1142(0.2656)
# 	 Epoch: [2][3000/8782] Elapsed 6m 1s (remain 11m 35s) Loss: 0.2671(0.2630)
# 	 Epoch: [2][4000/8782] Elapsed 8m 1s (remain 9m 35s) Loss: 0.2093(0.2612)
# 	 Epoch: [2][5000/8782] Elapsed 10m 1s (remain 7m 34s) Loss: 0.2611(0.2594)
# 	 Epoch: [2][6000/8782] Elapsed 12m 2s (remain 5m 34s) Loss: 0.2048(0.2572)
# 	 Epoch: [2][7000/8782] Elapsed 14m 3s (remain 3m 34s) Loss: 0.2248(0.2556)
# 	 Epoch: [2][8000/8782] Elapsed 16m 3s (remain 1m 34s) Loss: 0.3229(0.2545)
# 	 Epoch: [2][8781/8782] Elapsed 17m 36s (remain 0m 0s) Loss: 0.0410(0.2531)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 52s) Loss: 0.0483(0.0483)
# 	 EVAL: [755/756] Elapsed 1m 37s (remain 0m 0s) Loss: 0.0112(0.2053)
# 	 epoch:2, avg train loss:0.2531, avg valid loss:0.2053, score:0.4417(th=0.2) ::: time:2335.41s
# 	 Epoch 2 - Save Best Score: 0.4417. Model is saved.
# 	 Epoch 2 - Save Best AUC Score: 0.8846. Model is saved.
# 	 === epoch: 3: training ===
# 	 Epoch: [3][0/8782] Elapsed 0m 1s (remain 169m 29s) Loss: 0.2868(0.2868)
# 	 Epoch: [3][1000/8782] Elapsed 2m 1s (remain 15m 42s) Loss: 0.1283(0.2400)
# 	 Epoch: [3][2000/8782] Elapsed 4m 1s (remain 13m 37s) Loss: 0.2712(0.2348)
# 	 Epoch: [3][3000/8782] Elapsed 6m 1s (remain 11m 37s) Loss: 0.3202(0.2327)
# 	 Epoch: [3][4000/8782] Elapsed 8m 2s (remain 9m 36s) Loss: 0.2096(0.2318)
# 	 Epoch: [3][5000/8782] Elapsed 10m 2s (remain 7m 35s) Loss: 0.3829(0.2304)
# 	 Epoch: [3][6000/8782] Elapsed 12m 2s (remain 5m 34s) Loss: 0.4037(0.2304)
# 	 Epoch: [3][7000/8782] Elapsed 14m 2s (remain 3m 34s) Loss: 0.2390(0.2298)
# 	 Epoch: [3][8000/8782] Elapsed 16m 2s (remain 1m 33s) Loss: 0.3548(0.2295)
# 	 Epoch: [3][8781/8782] Elapsed 17m 36s (remain 0m 0s) Loss: 0.0845(0.2293)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 45s) Loss: 0.1469(0.1469)
# 	 EVAL: [755/756] Elapsed 1m 37s (remain 0m 0s) Loss: 0.0218(0.1973)
# 	 epoch:3, avg train loss:0.2293, avg valid loss:0.1973, score:0.4613(th=0.30000000000000004) ::: time:3490.40s
# 	 Epoch 3 - Save Best Score: 0.4613. Model is saved.
# 	 Epoch 3 - Save Best AUC Score: 0.8958. Model is saved.
# 	 === epoch: 4: training ===
# 	 Epoch: [4][0/8782] Elapsed 0m 1s (remain 159m 19s) Loss: 0.1341(0.1341)
# 	 Epoch: [4][1000/8782] Elapsed 2m 1s (remain 15m 44s) Loss: 0.1923(0.2254)
# 	 Epoch: [4][2000/8782] Elapsed 4m 1s (remain 13m 39s) Loss: 0.2029(0.2241)
# 	 Epoch: [4][3000/8782] Elapsed 6m 2s (remain 11m 38s) Loss: 0.1332(0.2238)
# 	 Epoch: [4][4000/8782] Elapsed 8m 2s (remain 9m 36s) Loss: 0.2226(0.2230)
# 	 Epoch: [4][5000/8782] Elapsed 10m 3s (remain 7m 35s) Loss: 0.2712(0.2229)
# 	 Epoch: [4][6000/8782] Elapsed 12m 3s (remain 5m 35s) Loss: 0.1010(0.2215)
# 	 Epoch: [4][7000/8782] Elapsed 14m 3s (remain 3m 34s) Loss: 0.2033(0.2214)
# 	 Epoch: [4][8000/8782] Elapsed 16m 3s (remain 1m 34s) Loss: 0.2567(0.2209)
# 	 Epoch: [4][8781/8782] Elapsed 17m 37s (remain 0m 0s) Loss: 0.3817(0.2210)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 11m 13s) Loss: 0.0658(0.0658)
# 	 EVAL: [755/756] Elapsed 1m 41s (remain 0m 0s) Loss: 0.0059(0.1997)
# 	 epoch:4, avg train loss:0.2210, avg valid loss:0.1997, score:0.4570(th=0.2) ::: time:4651.33s
# 	 Epoch 4 - Save Best AUC Score: 0.8977. Model is saved.
# 	 === epoch: 5: training ===
# 	 Epoch: [5][0/8782] Elapsed 0m 1s (remain 172m 24s) Loss: 0.0817(0.0817)
# 	 Epoch: [5][1000/8782] Elapsed 2m 1s (remain 15m 45s) Loss: 0.3857(0.2154)
# 	 Epoch: [5][2000/8782] Elapsed 4m 1s (remain 13m 40s) Loss: 0.1025(0.2161)
# 	 Epoch: [5][3000/8782] Elapsed 6m 2s (remain 11m 38s) Loss: 0.1612(0.2160)
# 	 Epoch: [5][4000/8782] Elapsed 8m 2s (remain 9m 36s) Loss: 0.1529(0.2160)
# 	 Epoch: [5][5000/8782] Elapsed 10m 3s (remain 7m 36s) Loss: 0.2543(0.2167)
# 	 Epoch: [5][6000/8782] Elapsed 12m 3s (remain 5m 35s) Loss: 0.2467(0.2166)
# 	 Epoch: [5][7000/8782] Elapsed 14m 3s (remain 3m 34s) Loss: 0.1226(0.2172)
# 	 Epoch: [5][8000/8782] Elapsed 16m 4s (remain 1m 34s) Loss: 0.0688(0.2169)
# 	 Epoch: [5][8781/8782] Elapsed 17m 38s (remain 0m 0s) Loss: 0.2440(0.2169)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 11m 33s) Loss: 0.0713(0.0713)
# 	 EVAL: [755/756] Elapsed 1m 40s (remain 0m 0s) Loss: 0.0092(0.1894)
# 	 epoch:5, avg train loss:0.2169, avg valid loss:0.1894, score:0.4634(th=0.30000000000000004) ::: time:5811.33s
# 	 Epoch 5 - Save Best Score: 0.4634. Model is saved.
# 	 Epoch 5 - Save Best AUC Score: 0.9021. Model is saved.
# 	 === epoch: 6: training ===
# 	 Epoch: [6][0/8782] Elapsed 0m 1s (remain 161m 53s) Loss: 0.2452(0.2452)
# 	 Epoch: [6][1000/8782] Elapsed 2m 1s (remain 15m 43s) Loss: 0.2809(0.2185)
# 	 Epoch: [6][2000/8782] Elapsed 4m 1s (remain 13m 38s) Loss: 0.2041(0.2145)
# 	 Epoch: [6][3000/8782] Elapsed 6m 1s (remain 11m 36s) Loss: 0.1031(0.2154)
# 	 Epoch: [6][4000/8782] Elapsed 8m 1s (remain 9m 35s) Loss: 0.4716(0.2159)
# 	 Epoch: [6][5000/8782] Elapsed 10m 2s (remain 7m 35s) Loss: 0.1328(0.2164)
# 	 Epoch: [6][6000/8782] Elapsed 12m 2s (remain 5m 34s) Loss: 0.3104(0.2167)
# 	 Epoch: [6][7000/8782] Elapsed 14m 3s (remain 3m 34s) Loss: 0.3066(0.2157)
# 	 Epoch: [6][8000/8782] Elapsed 16m 4s (remain 1m 34s) Loss: 0.2922(0.2148)
# 	 Epoch: [6][8781/8782] Elapsed 17m 38s (remain 0m 0s) Loss: 0.1419(0.2143)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 29s) Loss: 0.1202(0.1202)
# 	 EVAL: [755/756] Elapsed 1m 37s (remain 0m 0s) Loss: 0.0131(0.1864)
# 	 epoch:6, avg train loss:0.2143, avg valid loss:0.1864, score:0.4699(th=0.2) ::: time:6968.00s
# 	 Epoch 6 - Save Best Score: 0.4699. Model is saved.
# 	 Epoch 6 - Save Best AUC Score: 0.9074. Model is saved.
# 	 === epoch: 7: training ===
# 	 Epoch: [7][0/8782] Elapsed 0m 1s (remain 169m 22s) Loss: 0.3257(0.3257)
# 	 Epoch: [7][1000/8782] Elapsed 2m 1s (remain 15m 41s) Loss: 0.3117(0.2139)
# 	 Epoch: [7][2000/8782] Elapsed 4m 1s (remain 13m 38s) Loss: 0.1687(0.2137)
# 	 Epoch: [7][3000/8782] Elapsed 6m 2s (remain 11m 38s) Loss: 0.0652(0.2118)
# 	 Epoch: [7][4000/8782] Elapsed 8m 2s (remain 9m 37s) Loss: 0.1444(0.2113)
# 	 Epoch: [7][5000/8782] Elapsed 10m 2s (remain 7m 35s) Loss: 0.1287(0.2113)
# 	 Epoch: [7][6000/8782] Elapsed 12m 3s (remain 5m 35s) Loss: 0.2235(0.2113)
# 	 Epoch: [7][7000/8782] Elapsed 14m 3s (remain 3m 34s) Loss: 0.2469(0.2116)
# 	 Epoch: [7][8000/8782] Elapsed 16m 3s (remain 1m 34s) Loss: 0.1290(0.2116)
# 	 Epoch: [7][8781/8782] Elapsed 17m 38s (remain 0m 0s) Loss: 0.0828(0.2116)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 18s) Loss: 0.0822(0.0822)
# 	 EVAL: [755/756] Elapsed 1m 37s (remain 0m 0s) Loss: 0.0090(0.1875)
# 	 epoch:7, avg train loss:0.2116, avg valid loss:0.1875, score:0.4749(th=0.2) ::: time:8125.68s
# 	 Epoch 7 - Save Best Score: 0.4749. Model is saved.
# 	 === epoch: 8: training ===
# 	 Epoch: [8][0/8782] Elapsed 0m 1s (remain 163m 12s) Loss: 0.2582(0.2582)
# 	 Epoch: [8][1000/8782] Elapsed 2m 0s (remain 15m 37s) Loss: 0.1727(0.2056)
# 	 Epoch: [8][2000/8782] Elapsed 4m 0s (remain 13m 36s) Loss: 0.2750(0.2096)
# 	 Epoch: [8][3000/8782] Elapsed 6m 1s (remain 11m 35s) Loss: 0.1468(0.2111)
# 	 Epoch: [8][4000/8782] Elapsed 8m 1s (remain 9m 35s) Loss: 0.4866(0.2115)
# 	 Epoch: [8][5000/8782] Elapsed 10m 1s (remain 7m 35s) Loss: 0.1291(0.2118)
# 	 Epoch: [8][6000/8782] Elapsed 12m 2s (remain 5m 34s) Loss: 0.1840(0.2111)
# 	 Epoch: [8][7000/8782] Elapsed 14m 2s (remain 3m 34s) Loss: 0.2227(0.2105)
# 	 Epoch: [8][8000/8782] Elapsed 16m 2s (remain 1m 33s) Loss: 0.1741(0.2101)
# 	 Epoch: [8][8781/8782] Elapsed 17m 36s (remain 0m 0s) Loss: 0.1711(0.2097)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 34s) Loss: 0.0983(0.0983)
# 	 EVAL: [755/756] Elapsed 1m 37s (remain 0m 0s) Loss: 0.0114(0.1861)
# 	 epoch:8, avg train loss:0.2097, avg valid loss:0.1861, score:0.4819(th=0.2) ::: time:9281.06s
# 	 Epoch 8 - Save Best Score: 0.4819. Model is saved.
# 	 === epoch: 9: training ===
# 	 Epoch: [9][0/8782] Elapsed 0m 1s (remain 161m 20s) Loss: 0.2342(0.2342)
# 	 Epoch: [9][1000/8782] Elapsed 2m 1s (remain 15m 41s) Loss: 0.2591(0.2108)
# 	 Epoch: [9][2000/8782] Elapsed 4m 1s (remain 13m 39s) Loss: 0.2176(0.2081)
# 	 Epoch: [9][3000/8782] Elapsed 6m 2s (remain 11m 37s) Loss: 0.2947(0.2100)
# 	 Epoch: [9][4000/8782] Elapsed 8m 2s (remain 9m 36s) Loss: 0.2398(0.2090)
# 	 Epoch: [9][5000/8782] Elapsed 10m 2s (remain 7m 35s) Loss: 0.2893(0.2083)
# 	 Epoch: [9][6000/8782] Elapsed 12m 3s (remain 5m 35s) Loss: 0.1486(0.2073)
# 	 Epoch: [9][7000/8782] Elapsed 14m 3s (remain 3m 34s) Loss: 0.2118(0.2075)
# 	 Epoch: [9][8000/8782] Elapsed 16m 4s (remain 1m 34s) Loss: 0.2281(0.2078)
# 	 Epoch: [9][8781/8782] Elapsed 17m 39s (remain 0m 0s) Loss: 0.0377(0.2082)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 14s) Loss: 0.0974(0.0974)
# 	 EVAL: [755/756] Elapsed 1m 37s (remain 0m 0s) Loss: 0.0095(0.1853)
# 	 epoch:9, avg train loss:0.2082, avg valid loss:0.1853, score:0.4774(th=0.2) ::: time:10438.77s
# 	 === epoch: 10: training ===
# 	 Epoch: [10][0/8782] Elapsed 0m 1s (remain 164m 58s) Loss: 0.2267(0.2267)
# 	 Epoch: [10][1000/8782] Elapsed 2m 1s (remain 15m 44s) Loss: 0.1436(0.2043)
# 	 Epoch: [10][2000/8782] Elapsed 4m 2s (remain 13m 41s) Loss: 0.1492(0.2049)
# 	 Epoch: [10][3000/8782] Elapsed 6m 2s (remain 11m 38s) Loss: 0.0383(0.2062)
# 	 Epoch: [10][4000/8782] Elapsed 8m 2s (remain 9m 37s) Loss: 0.1129(0.2087)
# 	 Epoch: [10][5000/8782] Elapsed 10m 2s (remain 7m 35s) Loss: 0.0530(0.2083)
# 	 Epoch: [10][6000/8782] Elapsed 12m 2s (remain 5m 35s) Loss: 0.5006(0.2079)
# 	 Epoch: [10][7000/8782] Elapsed 14m 3s (remain 3m 34s) Loss: 0.3485(0.2077)
# 	 Epoch: [10][8000/8782] Elapsed 16m 4s (remain 1m 34s) Loss: 0.2699(0.2078)
# 	 Epoch: [10][8781/8782] Elapsed 17m 37s (remain 0m 0s) Loss: 0.1218(0.2077)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 41s) Loss: 0.1026(0.1026)
# 	 EVAL: [755/756] Elapsed 1m 37s (remain 0m 0s) Loss: 0.0106(0.1853)
# 	 epoch:10, avg train loss:0.2077, avg valid loss:0.1853, score:0.4784(th=0.2) ::: time:11594.86s
# 	 === epoch: 11: training ===
# 	 Epoch: [11][0/8782] Elapsed 0m 1s (remain 200m 15s) Loss: 0.1038(0.1038)
# 	 Epoch: [11][1000/8782] Elapsed 2m 2s (remain 15m 51s) Loss: 0.1249(0.2073)
# 	 Epoch: [11][2000/8782] Elapsed 4m 2s (remain 13m 41s) Loss: 0.2812(0.2068)
# 	 Epoch: [11][3000/8782] Elapsed 6m 2s (remain 11m 39s) Loss: 0.2713(0.2070)
# 	 Epoch: [11][4000/8782] Elapsed 8m 3s (remain 9m 37s) Loss: 0.1556(0.2073)
# 	 Epoch: [11][5000/8782] Elapsed 10m 3s (remain 7m 36s) Loss: 0.1775(0.2076)
# 	 Epoch: [11][6000/8782] Elapsed 12m 4s (remain 5m 35s) Loss: 0.1350(0.2071)
# 	 Epoch: [11][7000/8782] Elapsed 14m 4s (remain 3m 34s) Loss: 0.2245(0.2074)
# 	 Epoch: [11][8000/8782] Elapsed 16m 5s (remain 1m 34s) Loss: 0.2336(0.2073)
# 	 Epoch: [11][8781/8782] Elapsed 17m 38s (remain 0m 0s) Loss: 0.0120(0.2072)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 11m 17s) Loss: 0.1024(0.1024)
# 	 EVAL: [755/756] Elapsed 1m 38s (remain 0m 0s) Loss: 0.0106(0.1853)
# 	 epoch:11, avg train loss:0.2072, avg valid loss:0.1853, score:0.4784(th=0.2) ::: time:12753.13s
# 	 === epoch: 12: training ===
# 	 Epoch: [12][0/8782] Elapsed 0m 1s (remain 161m 13s) Loss: 0.1966(0.1966)
# 	 Epoch: [12][1000/8782] Elapsed 2m 1s (remain 15m 42s) Loss: 0.1936(0.2024)
# 	 Epoch: [12][2000/8782] Elapsed 4m 1s (remain 13m 37s) Loss: 0.0702(0.2058)
# 	 Epoch: [12][3000/8782] Elapsed 6m 1s (remain 11m 37s) Loss: 0.1394(0.2068)
# 	 Epoch: [12][4000/8782] Elapsed 8m 2s (remain 9m 36s) Loss: 0.2534(0.2068)
# 	 Epoch: [12][5000/8782] Elapsed 10m 4s (remain 7m 36s) Loss: 0.1149(0.2069)
# 	 Epoch: [12][6000/8782] Elapsed 12m 6s (remain 5m 36s) Loss: 0.2181(0.2057)
# 	 Epoch: [12][7000/8782] Elapsed 14m 8s (remain 3m 35s) Loss: 0.5186(0.2068)
# 	 Epoch: [12][8000/8782] Elapsed 16m 10s (remain 1m 34s) Loss: 0.1377(0.2075)
# 	 Epoch: [12][8781/8782] Elapsed 17m 45s (remain 0m 0s) Loss: 0.0695(0.2073)
# 	 EVAL: [0/756] Elapsed 0m 1s (remain 14m 21s) Loss: 0.0956(0.0956)
# 	 EVAL: [755/756] Elapsed 1m 44s (remain 0m 0s) Loss: 0.0099(0.1857)
# 	 epoch:12, avg train loss:0.2073, avg valid loss:0.1857, score:0.4788(th=0.2) ::: time:13924.47s
# 	 === epoch: 13: training ===
# 	 Epoch: [13][0/8782] Elapsed 0m 1s (remain 182m 20s) Loss: 0.1688(0.1688)
# 	 Epoch: [13][1000/8782] Elapsed 2m 1s (remain 15m 45s) Loss: 0.1479(0.2074)
# 	 Epoch: [13][2000/8782] Elapsed 4m 2s (remain 13m 41s) Loss: 0.2825(0.2083)
# 	 Epoch: [13][3000/8782] Elapsed 6m 2s (remain 11m 39s) Loss: 0.1957(0.2093)
# 	 Epoch: [13][4000/8782] Elapsed 8m 3s (remain 9m 37s) Loss: 0.4577(0.2085)
# 	 Epoch: [13][5000/8782] Elapsed 10m 4s (remain 7m 37s) Loss: 0.2900(0.2080)
# 	 Epoch: [13][6000/8782] Elapsed 12m 5s (remain 5m 36s) Loss: 0.0785(0.2079)
# 	 Epoch: [13][7000/8782] Elapsed 14m 5s (remain 3m 35s) Loss: 0.1200(0.2080)
# 	 Epoch: [13][8000/8782] Elapsed 16m 6s (remain 1m 34s) Loss: 0.1116(0.2079)
# 	 Epoch: [13][8781/8782] Elapsed 17m 40s (remain 0m 0s) Loss: 0.0450(0.2081)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 3s) Loss: 0.1113(0.1113)
# 	 EVAL: [755/756] Elapsed 1m 38s (remain 0m 0s) Loss: 0.0109(0.1851)
# 	 epoch:13, avg train loss:0.2081, avg valid loss:0.1851, score:0.4788(th=0.2) ::: time:15084.32s
# 	 Epoch 13 - Save Best AUC Score: 0.9078. Model is saved.
# 	 === epoch: 14: training ===
# 	 Epoch: [14][0/8782] Elapsed 0m 1s (remain 174m 52s) Loss: 0.1711(0.1711)
# 	 Epoch: [14][1000/8782] Elapsed 2m 0s (remain 15m 39s) Loss: 0.1834(0.2113)
# 	 Epoch: [14][2000/8782] Elapsed 4m 1s (remain 13m 38s) Loss: 0.1466(0.2094)
# 	 Epoch: [14][3000/8782] Elapsed 6m 0s (remain 11m 35s) Loss: 0.3072(0.2103)
# 	 Epoch: [14][4000/8782] Elapsed 8m 1s (remain 9m 34s) Loss: 0.0771(0.2107)
# 	 Epoch: [14][5000/8782] Elapsed 10m 1s (remain 7m 34s) Loss: 0.0661(0.2100)
# 	 Epoch: [14][6000/8782] Elapsed 12m 1s (remain 5m 34s) Loss: 0.2039(0.2098)
# 	 Epoch: [14][7000/8782] Elapsed 14m 0s (remain 3m 33s) Loss: 0.1882(0.2093)
# 	 Epoch: [14][8000/8782] Elapsed 16m 1s (remain 1m 33s) Loss: 0.2117(0.2092)
# 	 Epoch: [14][8781/8782] Elapsed 17m 35s (remain 0m 0s) Loss: 0.0298(0.2092)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 54s) Loss: 0.0845(0.0845)
# 	 EVAL: [755/756] Elapsed 1m 37s (remain 0m 0s) Loss: 0.0087(0.1857)
# 	 epoch:14, avg train loss:0.2092, avg valid loss:0.1857, score:0.4756(th=0.2) ::: time:16238.62s
# 	 === epoch: 15: training ===
# 	 Epoch: [15][0/8782] Elapsed 0m 1s (remain 160m 56s) Loss: 0.0846(0.0846)
# 	 Epoch: [15][1000/8782] Elapsed 2m 1s (remain 15m 43s) Loss: 0.0772(0.2117)
# 	 Epoch: [15][2000/8782] Elapsed 4m 1s (remain 13m 39s) Loss: 0.2371(0.2124)
# 	 Epoch: [15][3000/8782] Elapsed 6m 1s (remain 11m 36s) Loss: 0.2320(0.2106)
# 	 Epoch: [15][4000/8782] Elapsed 8m 1s (remain 9m 35s) Loss: 0.1490(0.2094)
# 	 Epoch: [15][5000/8782] Elapsed 10m 2s (remain 7m 35s) Loss: 0.1288(0.2091)
# 	 Epoch: [15][6000/8782] Elapsed 12m 2s (remain 5m 34s) Loss: 0.2388(0.2097)
# 	 Epoch: [15][7000/8782] Elapsed 14m 1s (remain 3m 34s) Loss: 0.1546(0.2099)
# 	 Epoch: [15][8000/8782] Elapsed 16m 2s (remain 1m 33s) Loss: 0.0750(0.2098)
# 	 Epoch: [15][8781/8782] Elapsed 17m 35s (remain 0m 0s) Loss: 0.0220(0.2098)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 17s) Loss: 0.1017(0.1017)
# 	 EVAL: [755/756] Elapsed 1m 43s (remain 0m 0s) Loss: 0.0106(0.1858)
# 	 epoch:15, avg train loss:0.2098, avg valid loss:0.1858, score:0.4833(th=0.2) ::: time:17398.21s
# 	 Epoch 15 - Save Best Score: 0.4833. Model is saved.
# 	 === epoch: 16: training ===
# 	 Epoch: [16][0/8782] Elapsed 0m 1s (remain 161m 57s) Loss: 0.2467(0.2467)
# 	 Epoch: [16][1000/8782] Elapsed 2m 1s (remain 15m 45s) Loss: 0.1026(0.2149)
# 	 Epoch: [16][2000/8782] Elapsed 4m 1s (remain 13m 37s) Loss: 0.1325(0.2114)
# 	 Epoch: [16][3000/8782] Elapsed 6m 1s (remain 11m 36s) Loss: 0.0971(0.2119)
# 	 Epoch: [16][4000/8782] Elapsed 8m 1s (remain 9m 35s) Loss: 0.1136(0.2114)
# 	 Epoch: [16][5000/8782] Elapsed 10m 1s (remain 7m 34s) Loss: 0.3018(0.2113)
# 	 Epoch: [16][6000/8782] Elapsed 12m 1s (remain 5m 34s) Loss: 0.3322(0.2113)
# 	 Epoch: [16][7000/8782] Elapsed 14m 2s (remain 3m 34s) Loss: 0.2049(0.2116)
# 	 Epoch: [16][8000/8782] Elapsed 16m 2s (remain 1m 33s) Loss: 0.3463(0.2109)
# 	 Epoch: [16][8781/8782] Elapsed 17m 35s (remain 0m 0s) Loss: 0.0212(0.2109)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 9m 53s) Loss: 0.0839(0.0839)
# 	 EVAL: [755/756] Elapsed 1m 41s (remain 0m 0s) Loss: 0.0104(0.1857)
# 	 epoch:16, avg train loss:0.2109, avg valid loss:0.1857, score:0.4768(th=0.2) ::: time:18556.39s
# 	 === epoch: 17: training ===
# 	 Epoch: [17][0/8782] Elapsed 0m 1s (remain 163m 39s) Loss: 0.1057(0.1057)
# 	 Epoch: [17][1000/8782] Elapsed 2m 0s (remain 15m 38s) Loss: 0.3439(0.2134)
# 	 Epoch: [17][2000/8782] Elapsed 4m 0s (remain 13m 34s) Loss: 0.3883(0.2129)
# 	 Epoch: [17][3000/8782] Elapsed 6m 0s (remain 11m 35s) Loss: 0.0866(0.2129)
# 	 Epoch: [17][4000/8782] Elapsed 8m 0s (remain 9m 34s) Loss: 0.3780(0.2125)
# 	 Epoch: [17][5000/8782] Elapsed 10m 0s (remain 7m 34s) Loss: 0.1571(0.2129)
# 	 Epoch: [17][6000/8782] Elapsed 12m 0s (remain 5m 33s) Loss: 0.2574(0.2126)
# 	 Epoch: [17][7000/8782] Elapsed 14m 0s (remain 3m 33s) Loss: 0.0992(0.2124)
# 	 Epoch: [17][8000/8782] Elapsed 16m 0s (remain 1m 33s) Loss: 0.3943(0.2124)
# 	 Epoch: [17][8781/8782] Elapsed 17m 34s (remain 0m 0s) Loss: 0.1149(0.2122)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 11s) Loss: 0.0886(0.0886)
# 	 EVAL: [755/756] Elapsed 1m 37s (remain 0m 0s) Loss: 0.0083(0.1875)
# 	 epoch:17, avg train loss:0.2122, avg valid loss:0.1875, score:0.4713(th=0.2) ::: time:19709.90s
# 	 === epoch: 18: training ===
# 	 Epoch: [18][0/8782] Elapsed 0m 1s (remain 152m 8s) Loss: 0.4874(0.4874)
# 	 Epoch: [18][1000/8782] Elapsed 2m 0s (remain 15m 37s) Loss: 0.2376(0.2124)
# 	 Epoch: [18][2000/8782] Elapsed 4m 0s (remain 13m 36s) Loss: 0.2561(0.2154)
# 	 Epoch: [18][3000/8782] Elapsed 6m 1s (remain 11m 35s) Loss: 0.3585(0.2131)
# 	 Epoch: [18][4000/8782] Elapsed 8m 0s (remain 9m 34s) Loss: 0.1629(0.2132)
# 	 Epoch: [18][5000/8782] Elapsed 10m 1s (remain 7m 34s) Loss: 0.3669(0.2127)
# 	 Epoch: [18][6000/8782] Elapsed 12m 1s (remain 5m 34s) Loss: 0.4999(0.2125)
# 	 Epoch: [18][7000/8782] Elapsed 14m 1s (remain 3m 34s) Loss: 0.1955(0.2125)
# 	 Epoch: [18][8000/8782] Elapsed 16m 1s (remain 1m 33s) Loss: 0.2086(0.2119)
# 	 Epoch: [18][8781/8782] Elapsed 17m 35s (remain 0m 0s) Loss: 0.0693(0.2124)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 21s) Loss: 0.1229(0.1229)
# 	 EVAL: [755/756] Elapsed 1m 38s (remain 0m 0s) Loss: 0.0125(0.1898)
# 	 epoch:18, avg train loss:0.2124, avg valid loss:0.1898, score:0.4659(th=0.2) ::: time:20864.28s
# 	 === epoch: 19: training ===
# 	 Epoch: [19][0/8782] Elapsed 0m 1s (remain 200m 42s) Loss: 0.1372(0.1372)
# 	 Epoch: [19][1000/8782] Elapsed 2m 0s (remain 15m 39s) Loss: 0.1807(0.2102)
# 	 Epoch: [19][2000/8782] Elapsed 4m 1s (remain 13m 37s) Loss: 0.2821(0.2100)
# 	 Epoch: [19][3000/8782] Elapsed 6m 1s (remain 11m 35s) Loss: 0.0601(0.2100)
# 	 Epoch: [19][4000/8782] Elapsed 8m 1s (remain 9m 35s) Loss: 0.2393(0.2119)
# 	 Epoch: [19][5000/8782] Elapsed 10m 1s (remain 7m 34s) Loss: 0.3375(0.2122)
# 	 Epoch: [19][6000/8782] Elapsed 12m 1s (remain 5m 34s) Loss: 0.2949(0.2127)
# 	 Epoch: [19][7000/8782] Elapsed 14m 1s (remain 3m 34s) Loss: 0.3098(0.2125)
# 	 Epoch: [19][8000/8782] Elapsed 16m 1s (remain 1m 33s) Loss: 0.3164(0.2128)
# 	 Epoch: [19][8781/8782] Elapsed 17m 35s (remain 0m 0s) Loss: 0.1154(0.2129)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 51s) Loss: 0.0890(0.0890)
# 	 EVAL: [755/756] Elapsed 1m 37s (remain 0m 0s) Loss: 0.0097(0.1858)
# 	 epoch:19, avg train loss:0.2129, avg valid loss:0.1858, score:0.4818(th=0.2) ::: time:22017.82s
# 	 === epoch: 20: training ===
# 	 Epoch: [20][0/8782] Elapsed 0m 1s (remain 162m 40s) Loss: 0.1992(0.1992)
# 	 Epoch: [20][1000/8782] Elapsed 2m 0s (remain 15m 36s) Loss: 0.4024(0.2149)
# 	 Epoch: [20][2000/8782] Elapsed 4m 1s (remain 13m 36s) Loss: 0.1020(0.2158)
# 	 Epoch: [20][3000/8782] Elapsed 6m 0s (remain 11m 35s) Loss: 0.1034(0.2150)
# 	 Epoch: [20][4000/8782] Elapsed 8m 0s (remain 9m 34s) Loss: 0.0938(0.2155)
# 	 Epoch: [20][5000/8782] Elapsed 10m 0s (remain 7m 34s) Loss: 0.0440(0.2139)
# 	 Epoch: [20][6000/8782] Elapsed 12m 0s (remain 5m 34s) Loss: 0.1678(0.2134)
# 	 Epoch: [20][7000/8782] Elapsed 14m 1s (remain 3m 33s) Loss: 0.2109(0.2137)
# 	 Epoch: [20][8000/8782] Elapsed 16m 1s (remain 1m 33s) Loss: 0.1124(0.2132)
# 	 Epoch: [20][8781/8782] Elapsed 17m 34s (remain 0m 0s) Loss: 0.1976(0.2129)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 10m 26s) Loss: 0.0696(0.0696)
# 	 EVAL: [755/756] Elapsed 1m 38s (remain 0m 0s) Loss: 0.0089(0.1931)
# 	 epoch:20, avg train loss:0.2129, avg valid loss:0.1931, score:0.4617(th=0.2) ::: time:23172.17s

# %%
display(oof_df)
if CFG["kaggle"]:
    oof_filename = os.path.join(CFG["OUTPUT_DIR"], "oof_df.csv")
    oof_df.to_csv(oof_filename, index=False)
else:
    oof_filename = os.path.join(CFG["OUTPUT_DIR"], CFG["EXP_NAME"], "oof_df.csv")
    oof_df.to_csv(oof_filename, index=False)
# Out:
#                        contact_id      pred  contact  fold
# 0      58573_000445_0_46131_47976  0.001068        0     0
# 1      58573_000445_0_47801_47976  0.001106        0     0
# 2      58573_000445_0_47801_52466  0.004594        0     0
# 3      58573_000445_0_44834_44888  0.002598        0     0
# 4      58573_000445_0_40171_47801  0.015263        0     0
# ...                           ...       ...      ...   ...
# 24162     58582_003121_91_48220_G  0.000584        0     0
# 24163     58582_003121_91_47906_G  0.001385        0     0
# 24164     58582_003121_91_38557_G  0.001083        0     0
# 24165     58582_003121_91_47872_G  0.010894        0     0
# 24166     58582_003121_91_52619_G  0.010701        0     0
#
# [24167 rows x 4 columns]

# %% [markdown]
# # Create CNN-Emb df

# %%
target_df = pd.read_csv(CFG["TARGET_CSV"])
target_game_plays = target_df["game_play"].unique()[-100:]
CFG["target_game_plays"] = list(target_game_plays)
target_df = target_df[target_df["game_play"].isin(target_game_plays)]

if CFG["DEBUG"]:
    target_df = target_df.sample(CFG["sample_num"])
elif CFG["sample_num"] != -1:
    target_df = target_df.sample(CFG["sample_num"])

target_df = target_df.reset_index(drop=True)
target_df["is_ground"] = (target_df["nfl_player_id_2"] == "G").astype(np.int)
target_df["is_helmet"] = 1 - ((target_df["E_width_1"]==0) & (target_df["E_width_2"]==0) & (target_df["S_width_1"]==0) & (target_df["S_width_2"]==0)).astype(np.int)
print(len(target_df))
display(target_df["contact"].value_counts())
# Out:
# 276406
# 0    251345
# 1     25061
# Name: contact, dtype: int64

# %%
emb_dataset = NFLDataset(target_df, valid_transform)
emb_loader = DataLoader(
    emb_dataset,
    batch_size = CFG["batch_size"],
    shuffle = False,
    num_workers = CFG["num_workers"],
    pin_memory = True
)
model = NFLNet()
model = model.to(device)
# model.load_state_dict(torch.load(CFG["trained_model_path"]))
model.load_state_dict(torch.load(f'{CFG["MODEL_DIR"]}/{CFG["model_name"]}_fold0.pth'))
model.eval()# モデルを検証モードに設定
cnn_features = []
for batch_idx, (images, features, track_features, targets) in enumerate(emb_loader):
    print("\r {}/{}".format(batch_idx, len(emb_loader)), end="")
    images = images.to(device, non_blocking = True).float()
    features = features.to(device, non_blocking = True).float()
    track_features = track_features.to(device, non_blocking = True).float()    
    preds, emb = model(images, features, track_features)    
    emb_numpy = emb.detach().cpu().numpy()
    cnn_features.extend(emb_numpy)
# Out:
#  8637/8638

# %%
cnn_feature_df = pd.DataFrame(cnn_features, columns=[f'cnn_feature_{i}' for i in range(CFG["num_extractFTR"])])
display(cnn_feature_df)
# Out:
#         cnn_feature_0  cnn_feature_1  cnn_feature_2  cnn_feature_3  \
# 0            2.031351       1.760265       1.953135      -0.191285
# 1            2.142363       2.012026       2.307324      -0.308227
# 2            2.069842       1.935473       2.119442      -0.069914
# 3            2.259351       2.080654       2.223809      -0.257539
# 4            2.243525       1.997871       2.306551      -0.212355
# ...               ...            ...            ...            ...
# 276401       0.097467       0.304543       0.535117      -0.590326
# 276402      -0.015185      -0.367305       0.159633      -1.196302
# 276403       0.456821       0.385565       0.639967      -1.700135
# 276404      -0.071327      -0.390098      -0.009951      -1.048942
# 276405       0.342146       0.777870       0.156176      -1.388187
#
#         cnn_feature_4
# 0           -1.633296
# 1           -1.876232
# 2           -1.845215
# 3           -1.797060
# 4           -2.082059
# ...               ...
# 276401      -0.913574
# 276402      -2.685038
# 276403      -2.194365
# 276404      -2.038753
# 276405      -1.823835
#
# [276406 rows x 5 columns]

# %%
concat_df = target_df.copy()
concat_df = pd.concat([target_df, cnn_feature_df], axis=1)
display(concat_df)
cnn_features_filename = os.path.join(CFG["OUTPUT_DIR"], CFG["EXP_NAME"] ,"target_cnn_emb.csv")
concat_df.to_csv(cnn_features_filename, index=False)
# Out:
#                         contact_id     game_play  \
# 0       58403_001076_0_46082_46232  58403_001076
# 1       58403_001076_0_42424_46082  58403_001076
# 2       58403_001076_0_42424_46232  58403_001076
# 3       58403_001076_0_42424_44876  58403_001076
# 4       58403_001076_0_42393_46649  58403_001076
# ...                            ...           ...
# 276401     58582_003121_91_48220_G  58582_003121
# 276402     58582_003121_91_47906_G  58582_003121
# 276403     58582_003121_91_38557_G  58582_003121
# 276404     58582_003121_91_47872_G  58582_003121
# 276405     58582_003121_91_52619_G  58582_003121
#
#                                 datetime  step  nfl_player_id_1  \
# 0       2020-12-27 21:47:57.800000+00:00     0            46082
# 1       2020-12-27 21:47:57.800000+00:00     0            42424
# 2       2020-12-27 21:47:57.800000+00:00     0            42424
# 3       2020-12-27 21:47:57.800000+00:00     0            42424
# 4       2020-12-27 21:47:57.800000+00:00     0            42393
# ...                                  ...   ...              ...
# 276401  2021-10-12 02:42:29.100000+00:00    91            48220
# 276402  2021-10-12 02:42:29.100000+00:00    91            47906
# 276403  2021-10-12 02:42:29.100000+00:00    91            38557
# 276404  2021-10-12 02:42:29.100000+00:00    91            47872
# 276405  2021-10-12 02:42:29.100000+00:00    91            52619
#
#        nfl_player_id_2  contact  frame        game_frame  \
# 0                46232        0    297  58403_001076_297
# 1                46082        0    297  58403_001076_297
# 2                46232        0    297  58403_001076_297
# 3                44876        0    297  58403_001076_297
# 4                46649        0    297  58403_001076_297
# ...                ...      ...    ...               ...
# 276401               G        0    840  58582_003121_840
# 276402               G        0    840  58582_003121_840
# 276403               G        0    840  58582_003121_840
# 276404               G        0    840  58582_003121_840
# 276405               G        0    840  58582_003121_840
#
#            game_frame_player_1  ... S_width_2  S_top_2  S_height_2  is_ground  \
# 0       58403_001076_297_46082  ...      17.0    302.0        18.0          0
# 1       58403_001076_297_42424  ...      20.0    346.0        26.0          0
# 2       58403_001076_297_42424  ...      17.0    302.0        18.0          0
# 3       58403_001076_297_42424  ...      19.0    274.0        26.0          0
# 4       58403_001076_297_42393  ...      22.0    227.0        24.0          0
# ...                        ...  ...       ...      ...         ...        ...
# 276401  58582_003121_840_48220  ...       0.0      0.0         0.0          1
# 276402  58582_003121_840_47906  ...       0.0      0.0         0.0          1
# 276403  58582_003121_840_38557  ...       0.0      0.0         0.0          1
# 276404  58582_003121_840_47872  ...       0.0      0.0         0.0          1
# 276405  58582_003121_840_52619  ...       0.0      0.0         0.0          1
#
#         is_helmet  cnn_feature_0  cnn_feature_1  cnn_feature_2  cnn_feature_3  \
# 0               1       2.031351       1.760265       1.953135      -0.191285
# 1               1       2.142363       2.012026       2.307324      -0.308227
# 2               1       2.069842       1.935473       2.119442      -0.069914
# 3               1       2.259351       2.080654       2.223809      -0.257539
# 4               1       2.243525       1.997871       2.306551      -0.212355
# ...           ...            ...            ...            ...            ...
# 276401          0       0.097467       0.304543       0.535117      -0.590326
# 276402          0      -0.015185      -0.367305       0.159633      -1.196302
# 276403          0       0.456821       0.385565       0.639967      -1.700135
# 276404          1      -0.071327      -0.390098      -0.009951      -1.048942
# 276405          0       0.342146       0.777870       0.156176      -1.388187
#
#         cnn_feature_4
# 0           -1.633296
# 1           -1.876232
# 2           -1.845215
# 3           -1.797060
# 4           -2.082059
# ...               ...
# 276401      -0.913574
# 276402      -2.685038
# 276403      -2.194365
# 276404      -2.038753
# 276405      -1.823835
#
# [276406 rows x 99 columns]
