# %% [markdown]
# # NFL Baseline

# %% [markdown]
# # import libraries

# %%
# general
import os
import gc
import pickle
import glob
import random
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import cv2
import matplotlib.pyplot as plt
import time
import math

import sys
sys.path.append('/kaggle/input/timm-pytorch-image-models/pytorch-image-models-master')
import timm


# deep learning
from torch.utils.data import Dataset, DataLoader
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# loss metrics
from sklearn.metrics import matthews_corrcoef, confusion_matrix

# warningの表示方法の設定
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Set Configurations

# %%
kaggle = False

class CFG:
    if kaggle:
        BASE_DIR = "/kaggle/input/nfl-player-contact-detection"
    else:
        BASE_DIR = "/workspace/input"
        FRAME_IMAGE_DIR = "/workspace/input/train_images"
    TRAIN_HELMET_CSV = os.path.join(BASE_DIR, "train_baseline_helmets.csv")
    TRAIN_TRACKING_CSV = os.path.join(BASE_DIR, "train_player_tracking.csv")
    TRAIN_VIDEO_META_CSV = os.path.join(BASE_DIR, "train_video_metadata.csv")
    TRAIN_LABEL_CSV = os.path.join(BASE_DIR, "train_labels.csv")
    TARGET_CSV = os.path.join(BASE_DIR, "target_fillna0_3.csv")
    

    # data config    
    img_size = (224, 224)
    batch_size = 64
    num_workers = 0
    n_fold = 1

    # model config
    model_name = "tf_efficientnet_b0"
    out_features = 1
    inp_channels= 3
    pretrained = True
    model_dir = os.path.join(os.path.dirname(BASE_DIR), "model")
    if kaggle:
        model_dir = "/kaggle/working"
    
    # learning config
    n_epoch = 20
    lr = 1e-6
    T_max = 10
    min_lr = 1e-7
    weight_decay = 1e-6
    
    # etc
    print_freq = 100
    random_seed = 21

# %% [markdown]
# # Utils

# %%
def seed_everything(seed=CFG.random_seed):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed%(2**32-1))
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# ## Dataset Utils

# %%
def get_snap_frame(row):
    elaped_time_start2snap = row.snap_time - row.start_time
    elaped_seconds = elaped_time_start2snap.seconds
    snap_frame = elaped_seconds*59.95
    return snap_frame

# %%
def set_inimg_window(crop_area, img_size=(720, 1280)):
    left, top, right, bot = crop_area
    # set crop area (area size in img size)
    crop_left = max(0, left)
    crop_top = max(0, top)
    if crop_left != left:   right = right - left
    if crop_top != top:    bot = bot - top
    crop_bot = min(img_size[0], bot)
    crop_right = min(img_size[1], right)
    if crop_bot != bot:    crop_top = crop_top - (bot - img_size[0])
    if crop_right != right:   crop_left = left - (right - img_size[1])
    
    return [crop_left, crop_top, crop_right, crop_bot]

# %%
def make_player_mask(img, helmet_pos, img_size=(720, 1280, 3), alpha=0.3):
    crop_size=[-helmet_pos[2], -helmet_pos[3], helmet_pos[2]*3, helmet_pos[3]*6] # helmetの大きさによってplayerの範囲も変更
    base_area = np.array(helmet_pos) + np.array(crop_size) # [left, top, width, height]
    # set players area
    palyer_area = [base_area[0],  base_area[1], base_area[0] + base_area[2], base_area[1] + base_area[3]]
    palyer_area = set_inimg_window(palyer_area)
    mask = np.zeros(img_size, dtype=np.uint8)
    cv2.rectangle(mask, [palyer_area[0], palyer_area[1]], [palyer_area[2], palyer_area[3]], (255, 255, 255), -1)
    mask = np.clip(mask, 0, 1).astype(np.uint8)
    return mask

# %%
def get_1player_croparea(helmet_pos, img_size=(720, 1280)):
    crop_size=[-helmet_pos[2]*3, -helmet_pos[3]*4, helmet_pos[2]*6, helmet_pos[3]*6] # helmetの大きさによってplayerの範囲も変更
    players_area = np.array(helmet_pos) + np.array(crop_size) # [left, top, width, height]
    # set players area
    crop_area = [players_area[0],  players_area[1], players_area[0] + players_area[2], players_area[1] + players_area[3]]
    crop_area = set_inimg_window(crop_area)
    return crop_area

# %%
def get_2player_croparea(helmet1_pos, helmet2_pos, img_size=(720, 1280)):
    player1_crop_size=[-10, -10, helmet1_pos[2]*4, helmet1_pos[3]*4] # helmetの大きさによってplayerの範囲も変更
    player2_crop_size=[-10, -10, helmet2_pos[2]*4, helmet2_pos[3]*4] # helmetの大きさによってplayerの範囲も変更
    player1_area = np.array(helmet1_pos) + np.array(player1_crop_size) # [left, top, width, height]
    player2_area = np.array(helmet2_pos) + np.array(player2_crop_size) # [left, top, width, height]
    # [left, top, width, height] => [left, top, right, bot]
    player1_crop_area = np.array([player1_area[0], player1_area[1], player1_area[0]+player1_area[2], player1_area[1]+player1_area[3]]) # [left, top, right, bot]
    player2_crop_area = np.array([player2_area[0], player2_area[1], player2_area[0]+player2_area[2], player2_area[1]+player2_area[3]]) # [left, top, right, bot]
    # get min max for set pos in img
    area_min = np.min(np.array([player1_crop_area, player2_crop_area]), axis=0)
    area_max = np.max(np.array([player1_crop_area, player2_crop_area]), axis=0)
    crop_area = [area_min[0], area_min[1], area_max[2], area_max[3]]
    crop_area = set_inimg_window(crop_area)
    return crop_area

# %%
def mask_blend(img, mask):
    img = np.clip(img, 0, 255).astype(np.uint8)
    mask = np.clip(mask, 0, 1).astype(np.uint8)
    img = img*mask
    img = np.clip(img, 0, 255).astype(np.uint8)
    return img

# %%
def search_helmet(helmet_df, player, frame):
    for diff_frame in range(5):
        read_frame = frame + diff_frame
        player_helmet = helmet_df.query('nfl_player_id==@player and frame==@read_frame')
        if len(player_helmet) > 0:
            return player_helmet
        read_frame = frame - diff_frame
        player_helmet = helmet_df.query('nfl_player_id==@player and frame==@read_frame')
        if len(player_helmet) > 0:
            return player_helmet
    return []

# %% [markdown]
# # Read Data

# %%
target_df = pd.read_csv(CFG.TARGET_CSV)
print(len(target_df["game_play"].unique()))
# Out:
# 240

# %% [markdown]
# # Save frame images

# %%
view = "Endzone"
all_video_start = time.time()
filelist = []

target_game_plays = target_df["game_play"].unique()
target_videos_num = len(target_game_plays)

start_time = time.time()
for idx, game_play in enumerate(target_game_plays):
    video_id = game_play + "_" + view
    video_path = os.path.join(CFG.BASE_DIR, "train", video_id)
    print("target video =", video_path)    
    # !ffmpeg -i /workspace/input/train/{video_id}.mp4 -q:v 2 -f image2 /workspace/input/train_frames/{video_id}_%04d.jpg -hide_banner -loglevel error
    

elapsed = (time.time() - all_video_start)/60
print(f"all video elapsed time = {elapsed:.3f} min. [{idx+1}/{target_videos_num}]")
# Out:
# target video = /workspace/input/train/58168_003392_Endzone
# target video = /workspace/input/train/58172_003247_Endzone
# target video = /workspace/input/train/58173_003606_Endzone
# target video = /workspace/input/train/58174_001792_Endzone
# target video = /workspace/input/train/58176_002844_Endzone
# target video = /workspace/input/train/58177_004239_Endzone
# target video = /workspace/input/train/58180_000986_Endzone
# target video = /workspace/input/train/58180_004644_Endzone
# target video = /workspace/input/train/58187_001341_Endzone
# target video = /workspace/input/train/58187_001383_Endzone
# target video = /workspace/input/train/58187_001691_Endzone
# target video = /workspace/input/train/58187_002329_Endzone
# target video = /workspace/input/train/58187_002815_Endzone
# target video = /workspace/input/train/58187_003092_Endzone
# target video = /workspace/input/train/58188_001358_Endzone
# target video = /workspace/input/train/58188_001757_Endzone
# target video = /workspace/input/train/58189_002566_Endzone
# target video = /workspace/input/train/58190_000309_Endzone
# target video = /workspace/input/train/58190_002259_Endzone
# target video = /workspace/input/train/58198_002514_Endzone
# target video = /workspace/input/train/58198_003771_Endzone
# target video = /workspace/input/train/58200_000058_Endzone
# target video = /workspace/input/train/58200_000736_Endzone
# target video = /workspace/input/train/58200_003925_Endzone
# target video = /workspace/input/train/58202_000170_Endzone
# target video = /workspace/input/train/58202_000546_Endzone
# target video = /workspace/input/train/58202_000758_Endzone
# target video = /workspace/input/train/58202_002335_Endzone
# target video = /workspace/input/train/58203_003141_Endzone
# target video = /workspace/input/train/58204_000790_Endzone
# target video = /workspace/input/train/58204_001073_Endzone
# target video = /workspace/input/train/58204_001094_Endzone
# target video = /workspace/input/train/58204_002822_Endzone
# target video = /workspace/input/train/58204_002864_Endzone
# target video = /workspace/input/train/58204_003581_Endzone
# target video = /workspace/input/train/58205_000809_Endzone
# target video = /workspace/input/train/58209_001445_Endzone
# target video = /workspace/input/train/58211_002891_Endzone
# target video = /workspace/input/train/58211_003268_Endzone
# target video = /workspace/input/train/58211_003628_Endzone
# target video = /workspace/input/train/58213_004027_Endzone
# target video = /workspace/input/train/58215_002887_Endzone
# target video = /workspace/input/train/58216_001891_Endzone
# target video = /workspace/input/train/58216_001939_Endzone
# target video = /workspace/input/train/58217_002635_Endzone
# target video = /workspace/input/train/58218_001523_Endzone
# target video = /workspace/input/train/58218_003210_Endzone
# target video = /workspace/input/train/58219_000820_Endzone
# target video = /workspace/input/train/58219_002964_Endzone
# target video = /workspace/input/train/58220_002149_Endzone
# target video = /workspace/input/train/58221_001269_Endzone
# target video = /workspace/input/train/58224_000998_Endzone
# target video = /workspace/input/train/58224_001771_Endzone
# target video = /workspace/input/train/58224_002486_Endzone
# target video = /workspace/input/train/58224_003139_Endzone
# target video = /workspace/input/train/58225_003821_Endzone
# target video = /workspace/input/train/58226_000777_Endzone
# target video = /workspace/input/train/58226_001740_Endzone
# target video = /workspace/input/train/58226_003009_Endzone
# target video = /workspace/input/train/58227_000943_Endzone
# target video = /workspace/input/train/58233_001668_Endzone
# target video = /workspace/input/train/58240_000086_Endzone
# target video = /workspace/input/train/58241_001260_Endzone
# target video = /workspace/input/train/58245_002594_Endzone
# target video = /workspace/input/train/58247_003522_Endzone
# target video = /workspace/input/train/58251_002850_Endzone
# target video = /workspace/input/train/58254_002516_Endzone
# target video = /workspace/input/train/58255_002579_Endzone
# target video = /workspace/input/train/58255_003091_Endzone
# target video = /workspace/input/train/58257_001078_Endzone
# target video = /workspace/input/train/58257_003529_Endzone
# target video = /workspace/input/train/58260_001249_Endzone
# target video = /workspace/input/train/58261_000085_Endzone
# target video = /workspace/input/train/58261_002636_Endzone
# target video = /workspace/input/train/58266_000095_Endzone
# target video = /workspace/input/train/58267_001152_Endzone
# target video = /workspace/input/train/58270_002527_Endzone
# target video = /workspace/input/train/58273_003282_Endzone
# target video = /workspace/input/train/58273_003586_Endzone
# target video = /workspace/input/train/58274_001016_Endzone
# target video = /workspace/input/train/58279_002309_Endzone
# target video = /workspace/input/train/58281_000692_Endzone
# target video = /workspace/input/train/58281_002521_Endzone
# target video = /workspace/input/train/58282_000120_Endzone
# target video = /workspace/input/train/58282_001429_Endzone
# target video = /workspace/input/train/58282_004520_Endzone
# target video = /workspace/input/train/58284_002768_Endzone
# target video = /workspace/input/train/58285_004176_Endzone
# target video = /workspace/input/train/58290_000442_Endzone
# target video = /workspace/input/train/58291_001043_Endzone
# target video = /workspace/input/train/58291_001415_Endzone
# target video = /workspace/input/train/58293_000319_Endzone
# target video = /workspace/input/train/58295_003441_Endzone
# target video = /workspace/input/train/58297_002555_Endzone
# target video = /workspace/input/train/58301_000419_Endzone
# target video = /workspace/input/train/58301_000786_Endzone
# target video = /workspace/input/train/58301_002369_Endzone
# target video = /workspace/input/train/58301_002557_Endzone
# target video = /workspace/input/train/58301_003176_Endzone
# target video = /workspace/input/train/58302_003012_Endzone
# target video = /workspace/input/train/58302_004013_Endzone
# target video = /workspace/input/train/58306_002362_Endzone
# target video = /workspace/input/train/58308_000965_Endzone
# target video = /workspace/input/train/58308_004092_Endzone
# target video = /workspace/input/train/58311_001819_Endzone
# target video = /workspace/input/train/58311_002159_Endzone
# target video = /workspace/input/train/58311_002205_Endzone
# target video = /workspace/input/train/58314_003381_Endzone
# target video = /workspace/input/train/58316_002463_Endzone
# target video = /workspace/input/train/58316_004059_Endzone
# target video = /workspace/input/train/58316_004343_Endzone
# target video = /workspace/input/train/58321_004155_Endzone
# target video = /workspace/input/train/58325_003176_Endzone
# target video = /workspace/input/train/58325_003506_Endzone
# target video = /workspace/input/train/58326_001078_Endzone
# target video = /workspace/input/train/58326_002516_Endzone
# target video = /workspace/input/train/58327_004116_Endzone
# target video = /workspace/input/train/58329_002938_Endzone
# target video = /workspace/input/train/58330_000759_Endzone
# target video = /workspace/input/train/58331_001797_Endzone
# target video = /workspace/input/train/58332_003535_Endzone
# target video = /workspace/input/train/58336_000203_Endzone
# target video = /workspace/input/train/58341_002805_Endzone
# target video = /workspace/input/train/58346_000251_Endzone
# target video = /workspace/input/train/58346_002013_Endzone
# target video = /workspace/input/train/58348_003069_Endzone
# target video = /workspace/input/train/58348_004222_Endzone
# target video = /workspace/input/train/58354_002499_Endzone
# target video = /workspace/input/train/58362_003882_Endzone
# target video = /workspace/input/train/58366_001484_Endzone
# target video = /workspace/input/train/58368_003010_Endzone
# target video = /workspace/input/train/58368_003163_Endzone
# target video = /workspace/input/train/58377_003872_Endzone
# target video = /workspace/input/train/58382_000973_Endzone
# target video = /workspace/input/train/58384_000142_Endzone
# target video = /workspace/input/train/58387_000381_Endzone
# target video = /workspace/input/train/58387_001481_Endzone
# target video = /workspace/input/train/58399_000570_Endzone
# target video = /workspace/input/train/58401_001720_Endzone
# target video = /workspace/input/train/58401_002419_Endzone
# target video = /workspace/input/train/58403_001076_Endzone
# target video = /workspace/input/train/58406_000188_Endzone
# target video = /workspace/input/train/58407_001855_Endzone
# target video = /workspace/input/train/58414_000727_Endzone
# target video = /workspace/input/train/58414_002210_Endzone
# target video = /workspace/input/train/58415_003155_Endzone
# target video = /workspace/input/train/58418_000608_Endzone
# target video = /workspace/input/train/58418_000637_Endzone
# target video = /workspace/input/train/58418_000886_Endzone
# target video = /workspace/input/train/58418_002446_Endzone
# target video = /workspace/input/train/58422_001140_Endzone
# target video = /workspace/input/train/58422_001959_Endzone
# target video = /workspace/input/train/58422_003849_Endzone
# target video = /workspace/input/train/58491_000084_Endzone
# target video = /workspace/input/train/58491_001948_Endzone
# target video = /workspace/input/train/58503_000869_Endzone
# target video = /workspace/input/train/58503_003486_Endzone
# target video = /workspace/input/train/58504_002063_Endzone
# target video = /workspace/input/train/58504_002631_Endzone
# target video = /workspace/input/train/58504_003623_Endzone
# target video = /workspace/input/train/58506_001241_Endzone
# target video = /workspace/input/train/58506_002821_Endzone
# target video = /workspace/input/train/58507_003903_Endzone
# target video = /workspace/input/train/58508_001718_Endzone
# target video = /workspace/input/train/58509_003605_Endzone
# target video = /workspace/input/train/58510_000152_Endzone
# target video = /workspace/input/train/58510_000855_Endzone
# target video = /workspace/input/train/58511_000863_Endzone
# target video = /workspace/input/train/58511_003245_Endzone
# target video = /workspace/input/train/58512_002068_Endzone
# target video = /workspace/input/train/58514_000929_Endzone
# target video = /workspace/input/train/58514_001989_Endzone
# target video = /workspace/input/train/58514_003151_Endzone
# target video = /workspace/input/train/58516_003014_Endzone
# target video = /workspace/input/train/58516_003538_Endzone
# target video = /workspace/input/train/58517_001943_Endzone
# target video = /workspace/input/train/58517_003494_Endzone
# target video = /workspace/input/train/58518_003619_Endzone
# target video = /workspace/input/train/58519_003798_Endzone
# target video = /workspace/input/train/58520_002380_Endzone
# target video = /workspace/input/train/58524_000212_Endzone
# target video = /workspace/input/train/58524_002909_Endzone
# target video = /workspace/input/train/58524_003049_Endzone
# target video = /workspace/input/train/58524_003113_Endzone
# target video = /workspace/input/train/58525_001428_Endzone
# target video = /workspace/input/train/58525_003852_Endzone
# target video = /workspace/input/train/58526_001849_Endzone
# target video = /workspace/input/train/58527_000757_Endzone
# target video = /workspace/input/train/58527_002375_Endzone
# target video = /workspace/input/train/58528_000317_Endzone
# target video = /workspace/input/train/58529_001441_Endzone
# target video = /workspace/input/train/58529_001853_Endzone
# target video = /workspace/input/train/58530_001942_Endzone
# target video = /workspace/input/train/58535_002015_Endzone
# target video = /workspace/input/train/58536_002108_Endzone
# target video = /workspace/input/train/58537_000757_Endzone
# target video = /workspace/input/train/58537_003722_Endzone
# target video = /workspace/input/train/58538_002774_Endzone
# target video = /workspace/input/train/58540_002206_Endzone
# target video = /workspace/input/train/58540_002625_Endzone
# target video = /workspace/input/train/58541_000795_Endzone
# target video = /workspace/input/train/58543_000962_Endzone
# target video = /workspace/input/train/58544_002496_Endzone
# target video = /workspace/input/train/58545_000874_Endzone
# target video = /workspace/input/train/58546_002764_Endzone
# target video = /workspace/input/train/58546_003306_Endzone
# target video = /workspace/input/train/58548_003091_Endzone
# target video = /workspace/input/train/58550_001554_Endzone
# target video = /workspace/input/train/58550_002742_Endzone
# target video = /workspace/input/train/58551_003569_Endzone
# target video = /workspace/input/train/58552_000100_Endzone
# target video = /workspace/input/train/58552_000452_Endzone
# target video = /workspace/input/train/58552_002943_Endzone
# target video = /workspace/input/train/58552_004264_Endzone
# target video = /workspace/input/train/58553_001995_Endzone
# target video = /workspace/input/train/58553_003801_Endzone
# target video = /workspace/input/train/58555_002451_Endzone
# target video = /workspace/input/train/58555_002563_Endzone
# target video = /workspace/input/train/58555_003204_Endzone
# target video = /workspace/input/train/58557_000463_Endzone
# target video = /workspace/input/train/58558_000573_Endzone
# target video = /workspace/input/train/58560_001856_Endzone
# target video = /workspace/input/train/58561_003088_Endzone
# target video = /workspace/input/train/58564_000126_Endzone
# target video = /workspace/input/train/58564_000452_Endzone
# target video = /workspace/input/train/58565_001768_Endzone
# target video = /workspace/input/train/58565_003743_Endzone
# target video = /workspace/input/train/58567_004074_Endzone
# target video = /workspace/input/train/58568_002209_Endzone
# target video = /workspace/input/train/58571_002679_Endzone
# target video = /workspace/input/train/58573_000445_Endzone
# target video = /workspace/input/train/58573_002569_Endzone
# target video = /workspace/input/train/58574_002922_Endzone
# target video = /workspace/input/train/58575_003081_Endzone
# target video = /workspace/input/train/58577_002486_Endzone
# target video = /workspace/input/train/58579_003527_Endzone
# target video = /workspace/input/train/58580_001136_Endzone
# target video = /workspace/input/train/58580_003294_Endzone
# target video = /workspace/input/train/58581_000040_Endzone
# target video = /workspace/input/train/58582_003121_Endzone
# all video elapsed time = 10.745 min. [240/240]
