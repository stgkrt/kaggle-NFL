# %% [markdown]
# # NFL Baseline
# - create target_df (distance in tracking_df is lower than threshold=3)
# https://www.kaggle.com/code/stgkrtua/nfl-creatatraindataset-targetdf
# - create dataset save frames in target_df
# https://www.kaggle.com/code/stgkrtua/nfl-createdataset-saveframes
# - check saved images
# https://www.kaggle.com/code/stgkrtua/nfl-checkdataset-plotsavedimage

# %% [markdown]
# # import libraries

# %%
# general
import os
import gc
import pickle
import glob
import random
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
import time
import math
from tqdm.notebook import tqdm

import sys
# warningの表示方法の設定
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Set Configurations

# %%
CFG = {
        "kaggle" : False,
        "DEBUG" : False,
        "img_size" : (224, 224),
        "masksize_helmet_ratio" : 4,
}
if CFG["DEBUG"]:
        CFG["sample_num"] = 1000
else:
        CFG["sample_num"] = -1
CFG["INPUT_DIR"] = "/workspace/input"
CFG["OUTPUT_DIR"] = "/workspace/output"
CFG["TRAIN_HELMET_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_baseline_helmets.csv")
CFG["TRAIN_TRACKING_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_player_tracking.csv")
CFG["TRAIN_VIDEO_META_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_video_metadata.csv")
CFG["TRAIN_LABEL_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_labels.csv")
CFG["TARGET_CSV"] = os.path.join(CFG["INPUT_DIR"], "target_fillna0_shift_2.csv")
CFG["TRAIN_E_IMG_DIR"] = os.path.join(CFG["INPUT_DIR"], "train_frames")
CFG["TRAIN_S_IMG_DIR"] = CFG["TRAIN_E_IMG_DIR"]
CFG["CONTACT_IMG_DIR"] = os.path.join(CFG["INPUT_DIR"], "contact_images")

# %% [markdown]
# ## Dataset Utils

# %%
def set_inimg_window(crop_pos, mask_size, img_size=(720, 1280)):#crop_pos = [left, top, right, bot]
    if mask_size[1] >= img_size[0]:
        top, bot = 0, img_size[1]
    else:
        top=(crop_pos[1] + crop_pos[3])//2 - mask_size[1]//2
        bot=(crop_pos[1] + crop_pos[3])//2 + mask_size[1]//2
        if top < 0:
            bot = bot - top
            top = 0
        elif bot > img_size[0]:
            top = top - (bot-img_size[0])
            bot = img_size[0]

    if mask_size[0] >= img_size[1]:
        left, right = 0, img_size[1]
    else:
        left = (crop_pos[0] + crop_pos[2])//2 - mask_size[0]//2
        right = (crop_pos[0] + crop_pos[2])//2 + mask_size[0]//2
        if left < 0:
            right = right - left
            left = 0
        elif right > img_size[1]:
            left = left - (right - img_size[1])
            right = img_size[1]
    crop_area = np.array([left, top, right, bot]).astype(np.int)
    return crop_area

# %%
def get_crop_area(p1_helmet, p2_helmet, input_size=(720, 1280)):#helmet[left, width, top, height]
    if (p1_helmet[1]==0 and p1_helmet[3]==0) and (p2_helmet[1]==0 and p2_helmet[3]==0):
        crop_area = [0, 0, input_size[1], input_size[0]]
        # print("bose player's helmet is not detected.")
        return crop_area
    elif (p2_helmet[1]==0 and p2_helmet[3]==0) and (p1_helmet[1] != 0 and p1_helmet[3]!=0):
        # print("p1 detected.")
        crop_x_center, crop_y_center = p1_helmet[0] + (p1_helmet[1])//2, p1_helmet[2] + (p1_helmet[3])//2
        helmet_base_size = (p1_helmet[1] + p1_helmet[3])*0.5*CFG["masksize_helmet_ratio"]*4
        output_size = [helmet_base_size, helmet_base_size]
    elif (p1_helmet[1]==0 and p1_helmet[3]==0) and (p2_helmet[1]!=0 and p2_helmet[3]!=0):
        # print("p2 detected.")
        crop_x_center, crop_y_center = p2_helmet[0] + (p2_helmet[1])//2, p2_helmet[2] + (p2_helmet[3])//2
        helmet_base_size = (p2_helmet[1] + p2_helmet[3])*0.5*CFG["masksize_helmet_ratio"]*4
        output_size = [helmet_base_size, helmet_base_size]
    else:
    #     print("p1 and p2 detected.")
        p1_x_center, p1_y_center = p1_helmet[0] + (p1_helmet[1])//2, p1_helmet[2] + (p1_helmet[3])//2
        p2_x_center, p2_y_center = p2_helmet[0] + (p2_helmet[1])//2, p2_helmet[2] + (p2_helmet[3])//2
        crop_x_center, crop_y_center = (p1_x_center + p2_x_center)//2, (p1_y_center + p2_y_center)//2
        helmet_base_size = (abs(p1_x_center - p2_x_center) + abs(p1_y_center - p2_y_center))*0.5 \
                            + ((p1_helmet[1] + p2_helmet[1])*0.5 + (p1_helmet[3] + p2_helmet[3])*0.5)*0.5*CFG["masksize_helmet_ratio"]*2
        output_size = [helmet_base_size, helmet_base_size]
    
    # print("crop center", crop_x_center, crop_y_center)
    crop_left = crop_x_center - output_size[1]//2
    crop_top = crop_y_center - output_size[0]//2
    crop_right = crop_x_center + output_size[1]//2
    crop_bot = crop_y_center + output_size[0]//2
    crop_area = [crop_left, crop_top, crop_right, crop_bot]
    crop_area = set_inimg_window(crop_area, output_size)
    return crop_area

# %%
def get_playermasked_img(img, helmet_pos, img_size=(720, 1280, 3)):#helmet pos = [left, width, top, height]
    if helmet_pos[1] == 0 and helmet_pos[3] == 0:
        mask = np.ones_like(img)
        return mask
    mask_size=(helmet_pos[1]+helmet_pos[3])*0.5*CFG["masksize_helmet_ratio"]# helmetの大きさによってplayerの範囲も変更
    helmet_area = [helmet_pos[0], helmet_pos[2], helmet_pos[0]+helmet_pos[1], helmet_pos[2]+helmet_pos[3]]#[left, top, right, bot]
    player_area = set_inimg_window(helmet_area, (mask_size,mask_size))
    mask = np.zeros(img_size, dtype=np.float)
    cv2.rectangle(mask, [player_area[0], player_area[1]], [player_area[2], player_area[3]], (255, 255, 255), -1)
    mask = np.clip(mask, 0, 1).astype(np.float)
    return mask

# %% [markdown]
# # Load Data

# %%
target_df = pd.read_csv(CFG["TARGET_CSV"])
if CFG["DEBUG"]:
    target_df = target_df.sample(CFG["sample_num"])
elif CFG["sample_num"] != -1:
    target_df = target_df.sample(CFG["sample_num"])
print(len(target_df))
display(target_df["contact"].value_counts())
# Out:
# 660553
# 0    596241
# 1     64312
# Name: contact, dtype: int64

# %%
for view in ["Endzone", "Sideline"]:
    file_id_tmp = None
    start_time = time.time()
    for idx in range(len(target_df)):
        print("\r {}/{}".format(idx, len(target_df)), end="")
        target_info = target_df.iloc[idx]
        # read frame image
        game_play = target_info.game_play
        frame = target_info.frame
        contact_id = target_info.contact_id
        file_id = f"{game_play}_{view}_{frame:04}.jpg"
        if file_id != file_id_tmp:
            filename = os.path.join(CFG["TRAIN_E_IMG_DIR"], file_id)
            img = cv2.imread(filename)
            if not img is None:
                img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
                view_tmp = view
                file_id_tmp = file_id
            else:
                print(f"\t\t {file_id} does not exists.")
        else:
            # player highlight mask
            player1 = target_info.nfl_player_id_1
            player2 = target_info.nfl_player_id_2
            if view == "Endzone":
                p1_helmet = np.array([target_info.E_left_1, target_info.E_width_1,
                                    target_info.E_top_1, target_info.E_height_1]).astype(np.int)
                p2_helmet = np.array([target_info.E_left_2, target_info.E_width_2,
                                    target_info.E_top_2, target_info.E_height_2]).astype(np.int)
            elif view == "Sideline":
                p1_helmet = np.array([target_info.S_left_1, target_info.S_width_1,
                                    target_info.S_top_1, target_info.S_height_1]).astype(np.int)
                p2_helmet = np.array([target_info.S_left_2, target_info.S_width_2,
                                    target_info.S_top_2, target_info.S_height_2]).astype(np.int)
            mask_img = img.copy()
            mask1 = get_playermasked_img(mask_img, p1_helmet)# helmet=[left, width, top, height]
            mask2 = get_playermasked_img(mask_img, p2_helmet)
            mask = np.clip(mask1 + mask2, 0, 1).astype(np.float)
            mask_img = mask*mask_img
            # crop players area
            crop_area = get_crop_area(p1_helmet, p2_helmet)# crop_area=[left, top, right, bot]

            mask_img = mask_img[crop_area[1]:crop_area[3], crop_area[0]:crop_area[2], :]
            mask_img = cv2.resize(mask_img, dsize=CFG["img_size"])
            
            contact_fileid = f"{contact_id}_{view}.jpg"
            contact_filename = os.path.join(CFG["CONTACT_IMG_DIR"], contact_fileid)
            cv2.imwrite(contact_filename, mask_img)
        if idx%10000 == 0:
            elapsed_time = (time.time() - start_time)/60
            print(f"\t\t idx = {idx}, elapsed time = {elapsed_time:.3f} min")
# Out:
#  0/660553		 idx = 0, elapsed time = 0.000 min
#  10000/660553		 idx = 10000, elapsed time = 3.511 min
#  20000/660553		 idx = 20000, elapsed time = 7.015 min
#  25001/66055358180_000986_Endzone_1046.jpg does not exists.
#  25002/66055358180_000986_Endzone_1046.jpg does not exists.
#  25003/66055358180_000986_Endzone_1046.jpg does not exists.
#  25004/66055358180_000986_Endzone_1046.jpg does not exists.
#  25005/66055358180_000986_Endzone_1046.jpg does not exists.
#  25006/66055358180_000986_Endzone_1046.jpg does not exists.
#  25007/66055358180_000986_Endzone_1046.jpg does not exists.
#  25008/66055358180_000986_Endzone_1046.jpg does not exists.
#  25009/66055358180_000986_Endzone_1046.jpg does not exists.
#  25010/66055358180_000986_Endzone_1046.jpg does not exists.
#  25011/66055358180_000986_Endzone_1046.jpg does not exists.
#  25012/66055358180_000986_Endzone_1046.jpg does not exists.
#  25013/66055358180_000986_Endzone_1046.jpg does not exists.
#  25014/66055358180_000986_Endzone_1046.jpg does not exists.
#  25015/66055358180_000986_Endzone_1046.jpg does not exists.
#  25016/66055358180_000986_Endzone_1046.jpg does not exists.
#  25017/66055358180_000986_Endzone_1046.jpg does not exists.
#  37274/66055358187_001691_Endzone_0915.jpg does not exists.
#  37275/66055358187_001691_Endzone_0915.jpg does not exists.
#  37276/66055358187_001691_Endzone_0915.jpg does not exists.
#  37277/66055358187_001691_Endzone_0915.jpg does not exists.
#  37278/66055358187_001691_Endzone_0915.jpg does not exists.
#  37279/66055358187_001691_Endzone_0915.jpg does not exists.
#  37280/66055358187_001691_Endzone_0915.jpg does not exists.
#  37281/66055358187_001691_Endzone_0915.jpg does not exists.
#  37282/66055358187_001691_Endzone_0915.jpg does not exists.
#  37283/66055358187_001691_Endzone_0915.jpg does not exists.
#  40000/660553		 idx = 40000, elapsed time = 14.079 min
#  46158/66055358187_003092_Endzone_0804.jpg does not exists.
#  46159/66055358187_003092_Endzone_0804.jpg does not exists.
#  46160/66055358187_003092_Endzone_0804.jpg does not exists.
#  46161/66055358187_003092_Endzone_0804.jpg does not exists.
#  46162/66055358187_003092_Endzone_0804.jpg does not exists.
#  46163/66055358187_003092_Endzone_0804.jpg does not exists.
#  46164/66055358187_003092_Endzone_0804.jpg does not exists.
#  46165/66055358187_003092_Endzone_0804.jpg does not exists.
#  46166/66055358187_003092_Endzone_0804.jpg does not exists.
#  46167/66055358187_003092_Endzone_0804.jpg does not exists.
#  46168/66055358187_003092_Endzone_0804.jpg does not exists.
#  46169/66055358187_003092_Endzone_0804.jpg does not exists.
#  46170/66055358187_003092_Endzone_0804.jpg does not exists.
#  46171/66055358187_003092_Endzone_0804.jpg does not exists.
#  46172/66055358187_003092_Endzone_0804.jpg does not exists.
#  46173/66055358187_003092_Endzone_0804.jpg does not exists.
#  46174/66055358187_003092_Endzone_0804.jpg does not exists.
#  46175/66055358187_003092_Endzone_0804.jpg does not exists.
#  46176/66055358187_003092_Endzone_0804.jpg does not exists.
#  46177/66055358187_003092_Endzone_0804.jpg does not exists.
#  46178/66055358187_003092_Endzone_0804.jpg does not exists.
#  46179/66055358187_003092_Endzone_0804.jpg does not exists.
#  46180/66055358187_003092_Endzone_0804.jpg does not exists.
#  46181/66055358187_003092_Endzone_0804.jpg does not exists.
#  46182/66055358187_003092_Endzone_0804.jpg does not exists.
#  50000/660553		 idx = 50000, elapsed time = 17.312 min
#  60000/660553		 idx = 60000, elapsed time = 20.875 min
#  62110/66055358198_002514_Endzone_0783.jpg does not exists.
#  62111/66055358198_002514_Endzone_0783.jpg does not exists.
#  62112/66055358198_002514_Endzone_0783.jpg does not exists.
#  62113/66055358198_002514_Endzone_0783.jpg does not exists.
#  62114/66055358198_002514_Endzone_0783.jpg does not exists.
#  62115/66055358198_002514_Endzone_0783.jpg does not exists.
#  62116/66055358198_002514_Endzone_0783.jpg does not exists.
#  62117/66055358198_002514_Endzone_0783.jpg does not exists.
#  62118/66055358198_002514_Endzone_0783.jpg does not exists.
#  62119/66055358198_002514_Endzone_0783.jpg does not exists.
#  62120/66055358198_002514_Endzone_0783.jpg does not exists.
#  62121/66055358198_002514_Endzone_0783.jpg does not exists.
#  62122/66055358198_002514_Endzone_0783.jpg does not exists.
#  62123/66055358198_002514_Endzone_0783.jpg does not exists.
#  62124/66055358198_002514_Endzone_0783.jpg does not exists.
#  62125/66055358198_002514_Endzone_0783.jpg does not exists.
#  62126/66055358198_002514_Endzone_0783.jpg does not exists.
#  62127/66055358198_002514_Endzone_0783.jpg does not exists.
#  62128/66055358198_002514_Endzone_0783.jpg does not exists.
#  62129/66055358198_002514_Endzone_0783.jpg does not exists.
#  62130/66055358198_002514_Endzone_0783.jpg does not exists.
#  62131/66055358198_002514_Endzone_0783.jpg does not exists.
#  62132/66055358198_002514_Endzone_0783.jpg does not exists.
#  62133/66055358198_002514_Endzone_0783.jpg does not exists.
#  62134/66055358198_002514_Endzone_0783.jpg does not exists.
#  62135/66055358198_002514_Endzone_0783.jpg does not exists.
#  70000/660553		 idx = 70000, elapsed time = 23.882 min
#  80000/660553		 idx = 80000, elapsed time = 27.526 min
#  90000/660553		 idx = 90000, elapsed time = 30.923 min
#  100000/660553		 idx = 100000, elapsed time = 34.136 min
#  107123/66055358204_003581_Endzone_0709.jpg does not exists.
#  107124/66055358204_003581_Endzone_0709.jpg does not exists.
#  107125/66055358204_003581_Endzone_0709.jpg does not exists.
#  107126/66055358204_003581_Endzone_0709.jpg does not exists.
#  107127/66055358204_003581_Endzone_0709.jpg does not exists.
#  107128/66055358204_003581_Endzone_0709.jpg does not exists.
#  107129/66055358204_003581_Endzone_0709.jpg does not exists.
#  107130/66055358204_003581_Endzone_0709.jpg does not exists.
#  107131/66055358204_003581_Endzone_0709.jpg does not exists.
#  107132/66055358204_003581_Endzone_0709.jpg does not exists.
#  107133/66055358204_003581_Endzone_0709.jpg does not exists.
#  107134/66055358204_003581_Endzone_0709.jpg does not exists.
#  107135/66055358204_003581_Endzone_0709.jpg does not exists.
#  107136/66055358204_003581_Endzone_0709.jpg does not exists.
#  107137/66055358204_003581_Endzone_0709.jpg does not exists.
#  107138/66055358204_003581_Endzone_0709.jpg does not exists.
#  107139/66055358204_003581_Endzone_0709.jpg does not exists.
#  107140/66055358204_003581_Endzone_0709.jpg does not exists.
#  107141/66055358204_003581_Endzone_0709.jpg does not exists.
#  107142/66055358204_003581_Endzone_0709.jpg does not exists.
#  107143/66055358204_003581_Endzone_0709.jpg does not exists.
#  107144/66055358204_003581_Endzone_0709.jpg does not exists.
#  110000/660553		 idx = 110000, elapsed time = 37.519 min
#  120000/660553		 idx = 120000, elapsed time = 40.282 min
#  126824/66055358216_001891_Endzone_0664.jpg does not exists.
#  126825/66055358216_001891_Endzone_0664.jpg does not exists.
#  126826/66055358216_001891_Endzone_0664.jpg does not exists.
#  126827/66055358216_001891_Endzone_0664.jpg does not exists.
#  126828/66055358216_001891_Endzone_0664.jpg does not exists.
#  126829/66055358216_001891_Endzone_0664.jpg does not exists.
#  126830/66055358216_001891_Endzone_0664.jpg does not exists.
#  126831/66055358216_001891_Endzone_0664.jpg does not exists.
#  126832/66055358216_001891_Endzone_0664.jpg does not exists.
#  126833/66055358216_001891_Endzone_0664.jpg does not exists.
#  126834/66055358216_001891_Endzone_0664.jpg does not exists.
#  126835/66055358216_001891_Endzone_0664.jpg does not exists.
#  126836/66055358216_001891_Endzone_0664.jpg does not exists.
#  126837/66055358216_001891_Endzone_0664.jpg does not exists.
#  126838/66055358216_001891_Endzone_0664.jpg does not exists.
#  126839/66055358216_001891_Endzone_0664.jpg does not exists.
#  126840/66055358216_001891_Endzone_0664.jpg does not exists.
#  126841/66055358216_001891_Endzone_0664.jpg does not exists.
#  126842/66055358216_001891_Endzone_0664.jpg does not exists.
#  126843/66055358216_001891_Endzone_0664.jpg does not exists.
#  126844/66055358216_001891_Endzone_0664.jpg does not exists.
#  126845/66055358216_001891_Endzone_0664.jpg does not exists.
#  126846/66055358216_001891_Endzone_0664.jpg does not exists.
#  126847/66055358216_001891_Endzone_0664.jpg does not exists.
#  126848/66055358216_001891_Endzone_0664.jpg does not exists.
#  126849/66055358216_001891_Endzone_0664.jpg does not exists.
#  126850/66055358216_001891_Endzone_0664.jpg does not exists.
#  126851/66055358216_001891_Endzone_0664.jpg does not exists.
#  126852/66055358216_001891_Endzone_0664.jpg does not exists.
#  126853/66055358216_001891_Endzone_0664.jpg does not exists.
#  126854/66055358216_001891_Endzone_0664.jpg does not exists.
#  126855/66055358216_001891_Endzone_0664.jpg does not exists.
#  126856/66055358216_001891_Endzone_0664.jpg does not exists.
#  126857/66055358216_001891_Endzone_0664.jpg does not exists.
#  126858/66055358216_001891_Endzone_0664.jpg does not exists.
#  126859/66055358216_001891_Endzone_0664.jpg does not exists.
#  126860/66055358216_001891_Endzone_0664.jpg does not exists.
#  126861/66055358216_001891_Endzone_0664.jpg does not exists.
#  126862/66055358216_001891_Endzone_0664.jpg does not exists.
#  126863/66055358216_001891_Endzone_0664.jpg does not exists.
#  126864/66055358216_001891_Endzone_0664.jpg does not exists.
#  126865/66055358216_001891_Endzone_0664.jpg does not exists.
#  126866/66055358216_001891_Endzone_0664.jpg does not exists.
#  126867/66055358216_001891_Endzone_0664.jpg does not exists.
#  126868/66055358216_001891_Endzone_0664.jpg does not exists.
#  126869/66055358216_001891_Endzone_0664.jpg does not exists.
#  126870/66055358216_001891_Endzone_0664.jpg does not exists.
#  126871/66055358216_001891_Endzone_0664.jpg does not exists.
#  126872/66055358216_001891_Endzone_0664.jpg does not exists.
#  126873/66055358216_001891_Endzone_0664.jpg does not exists.
#  126874/66055358216_001891_Endzone_0664.jpg does not exists.
#  126875/66055358216_001891_Endzone_0664.jpg does not exists.
#  126876/66055358216_001891_Endzone_0664.jpg does not exists.
#  126877/66055358216_001891_Endzone_0664.jpg does not exists.
#  126878/66055358216_001891_Endzone_0664.jpg does not exists.
#  126879/66055358216_001891_Endzone_0664.jpg does not exists.
#  126880/66055358216_001891_Endzone_0664.jpg does not exists.
#  126881/66055358216_001891_Endzone_0664.jpg does not exists.
#  126882/66055358216_001891_Endzone_0664.jpg does not exists.
#  126883/66055358216_001891_Endzone_0664.jpg does not exists.
#  130000/660553		 idx = 130000, elapsed time = 43.623 min
#  134024/66055358217_002635_Endzone_0739.jpg does not exists.
#  134025/66055358217_002635_Endzone_0739.jpg does not exists.
#  134026/66055358217_002635_Endzone_0739.jpg does not exists.
#  134027/66055358217_002635_Endzone_0739.jpg does not exists.
#  134028/66055358217_002635_Endzone_0739.jpg does not exists.
#  134029/66055358217_002635_Endzone_0739.jpg does not exists.
#  134030/66055358217_002635_Endzone_0739.jpg does not exists.
#  134031/66055358217_002635_Endzone_0739.jpg does not exists.
#  134032/66055358217_002635_Endzone_0739.jpg does not exists.
#  134033/66055358217_002635_Endzone_0739.jpg does not exists.
#  134034/66055358217_002635_Endzone_0739.jpg does not exists.
#  134035/66055358217_002635_Endzone_0739.jpg does not exists.
#  134036/66055358217_002635_Endzone_0739.jpg does not exists.
#  134037/66055358217_002635_Endzone_0739.jpg does not exists.
#  134038/66055358217_002635_Endzone_0739.jpg does not exists.
#  134039/66055358217_002635_Endzone_0739.jpg does not exists.
#  134040/66055358217_002635_Endzone_0739.jpg does not exists.
#  134041/66055358217_002635_Endzone_0739.jpg does not exists.
#  134042/66055358217_002635_Endzone_0739.jpg does not exists.
#  134043/66055358217_002635_Endzone_0739.jpg does not exists.
#  134044/66055358217_002635_Endzone_0739.jpg does not exists.
#  134045/66055358217_002635_Endzone_0739.jpg does not exists.
#  134046/66055358217_002635_Endzone_0739.jpg does not exists.
#  134047/66055358217_002635_Endzone_0739.jpg does not exists.
#  134048/66055358217_002635_Endzone_0739.jpg does not exists.
#  134049/66055358217_002635_Endzone_0739.jpg does not exists.
#  134050/66055358217_002635_Endzone_0739.jpg does not exists.
#  134051/66055358217_002635_Endzone_0739.jpg does not exists.
#  134052/66055358217_002635_Endzone_0739.jpg does not exists.
#  134053/66055358217_002635_Endzone_0739.jpg does not exists.
#  134054/66055358217_002635_Endzone_0739.jpg does not exists.
#  134055/66055358217_002635_Endzone_0739.jpg does not exists.
#  137979/66055358218_003210_Endzone_0689.jpg does not exists.
#  137980/66055358218_003210_Endzone_0689.jpg does not exists.
#  137981/66055358218_003210_Endzone_0689.jpg does not exists.
#  137982/66055358218_003210_Endzone_0689.jpg does not exists.
#  137983/66055358218_003210_Endzone_0689.jpg does not exists.
#  137984/66055358218_003210_Endzone_0689.jpg does not exists.
#  137985/66055358218_003210_Endzone_0689.jpg does not exists.
#  137986/66055358218_003210_Endzone_0689.jpg does not exists.
#  137987/66055358218_003210_Endzone_0689.jpg does not exists.
#  137988/66055358218_003210_Endzone_0689.jpg does not exists.
#  137989/66055358218_003210_Endzone_0689.jpg does not exists.
#  137990/66055358218_003210_Endzone_0689.jpg does not exists.
#  137991/66055358218_003210_Endzone_0689.jpg does not exists.
#  137992/66055358218_003210_Endzone_0689.jpg does not exists.
#  137993/66055358218_003210_Endzone_0689.jpg does not exists.
#  137994/66055358218_003210_Endzone_0689.jpg does not exists.
#  137995/66055358218_003210_Endzone_0689.jpg does not exists.
#  137996/66055358218_003210_Endzone_0689.jpg does not exists.
#  137997/66055358218_003210_Endzone_0689.jpg does not exists.
#  137998/66055358218_003210_Endzone_0689.jpg does not exists.
#  192724/66055358254_002516_Endzone_0792.jpg does not exists.
#  192725/66055358254_002516_Endzone_0792.jpg does not exists.
#  192726/66055358254_002516_Endzone_0792.jpg does not exists.
#  192727/66055358254_002516_Endzone_0792.jpg does not exists.
#  192728/66055358254_002516_Endzone_0792.jpg does not exists.
#  192729/66055358254_002516_Endzone_0792.jpg does not exists.
#  192730/66055358254_002516_Endzone_0792.jpg does not exists.
#  192731/66055358254_002516_Endzone_0792.jpg does not exists.
#  192732/66055358254_002516_Endzone_0792.jpg does not exists.
#  192733/66055358254_002516_Endzone_0792.jpg does not exists.
#  192734/66055358254_002516_Endzone_0792.jpg does not exists.
#  192735/66055358254_002516_Endzone_0792.jpg does not exists.
#  192736/66055358254_002516_Endzone_0792.jpg does not exists.
#  200000/660553		 idx = 200000, elapsed time = 65.982 min
#  201454/66055358257_003529_Endzone_0746.jpg does not exists.
#  201455/66055358257_003529_Endzone_0746.jpg does not exists.
#  201456/66055358257_003529_Endzone_0746.jpg does not exists.
#  201457/66055358257_003529_Endzone_0746.jpg does not exists.
#  201458/66055358257_003529_Endzone_0746.jpg does not exists.
#  201459/66055358257_003529_Endzone_0746.jpg does not exists.
#  201460/66055358257_003529_Endzone_0746.jpg does not exists.
#  201461/66055358257_003529_Endzone_0746.jpg does not exists.
#  201462/66055358257_003529_Endzone_0746.jpg does not exists.
#  201463/66055358257_003529_Endzone_0746.jpg does not exists.
#  201464/66055358257_003529_Endzone_0746.jpg does not exists.
#  201465/66055358257_003529_Endzone_0746.jpg does not exists.
#  201466/66055358257_003529_Endzone_0746.jpg does not exists.
#  201467/66055358257_003529_Endzone_0746.jpg does not exists.
#  201468/66055358257_003529_Endzone_0746.jpg does not exists.
#  201469/66055358257_003529_Endzone_0746.jpg does not exists.
#  201470/66055358257_003529_Endzone_0746.jpg does not exists.
#  201471/66055358257_003529_Endzone_0746.jpg does not exists.
#  201472/66055358257_003529_Endzone_0746.jpg does not exists.
#  201473/66055358257_003529_Endzone_0746.jpg does not exists.
#  201474/66055358257_003529_Endzone_0746.jpg does not exists.
#  201475/66055358257_003529_Endzone_0746.jpg does not exists.
#  201476/66055358257_003529_Endzone_0746.jpg does not exists.
#  201477/66055358257_003529_Endzone_0746.jpg does not exists.
#  201478/66055358257_003529_Endzone_0746.jpg does not exists.
#  201479/66055358257_003529_Endzone_0746.jpg does not exists.
#  201480/66055358257_003529_Endzone_0746.jpg does not exists.
#  201481/66055358257_003529_Endzone_0746.jpg does not exists.
#  201482/66055358257_003529_Endzone_0746.jpg does not exists.
#  201483/66055358257_003529_Endzone_0746.jpg does not exists.
#  201484/66055358257_003529_Endzone_0746.jpg does not exists.
#  201485/66055358257_003529_Endzone_0746.jpg does not exists.
#  210000/660553		 idx = 210000, elapsed time = 69.378 min
#  220000/660553		 idx = 220000, elapsed time = 73.143 min
#  229668/66055358279_002309_Endzone_0796.jpg does not exists.
#  229669/66055358279_002309_Endzone_0796.jpg does not exists.
#  229670/66055358279_002309_Endzone_0796.jpg does not exists.
#  229671/66055358279_002309_Endzone_0796.jpg does not exists.
#  250000/660553		 idx = 250000, elapsed time = 84.037 min
#  251454/66055358290_000442_Endzone_0881.jpg does not exists.
#  251455/66055358290_000442_Endzone_0881.jpg does not exists.
#  251456/66055358290_000442_Endzone_0881.jpg does not exists.
#  251457/66055358290_000442_Endzone_0881.jpg does not exists.
#  251458/66055358290_000442_Endzone_0881.jpg does not exists.
#  251459/66055358290_000442_Endzone_0881.jpg does not exists.
#  251460/66055358290_000442_Endzone_0881.jpg does not exists.
#  251461/66055358290_000442_Endzone_0881.jpg does not exists.
#  251462/66055358290_000442_Endzone_0881.jpg does not exists.
#  251463/66055358290_000442_Endzone_0881.jpg does not exists.
#  251464/66055358290_000442_Endzone_0881.jpg does not exists.
#  251465/66055358290_000442_Endzone_0881.jpg does not exists.
#  251466/66055358290_000442_Endzone_0881.jpg does not exists.
#  251467/66055358290_000442_Endzone_0881.jpg does not exists.
#  251468/66055358290_000442_Endzone_0881.jpg does not exists.
#  251469/66055358290_000442_Endzone_0881.jpg does not exists.
#  251470/66055358290_000442_Endzone_0881.jpg does not exists.
#  251471/66055358290_000442_Endzone_0881.jpg does not exists.
#  251472/66055358290_000442_Endzone_0881.jpg does not exists.
#  251473/66055358290_000442_Endzone_0881.jpg does not exists.
#  251474/66055358290_000442_Endzone_0881.jpg does not exists.
#  251475/66055358290_000442_Endzone_0881.jpg does not exists.
#  251476/66055358290_000442_Endzone_0881.jpg does not exists.
#  251477/66055358290_000442_Endzone_0881.jpg does not exists.
#  251478/66055358290_000442_Endzone_0881.jpg does not exists.
#  260000/660553		 idx = 260000, elapsed time = 87.742 min
#  270000/660553		 idx = 270000, elapsed time = 91.211 min
#  280000/660553		 idx = 280000, elapsed time = 94.981 min
#  284193/66055358302_004013_Endzone_0666.jpg does not exists.
#  284194/66055358302_004013_Endzone_0666.jpg does not exists.
#  284195/66055358302_004013_Endzone_0666.jpg does not exists.
#  284196/66055358302_004013_Endzone_0666.jpg does not exists.
#  284197/66055358302_004013_Endzone_0666.jpg does not exists.
#  284198/66055358302_004013_Endzone_0666.jpg does not exists.
#  284199/66055358302_004013_Endzone_0666.jpg does not exists.
#  284200/66055358302_004013_Endzone_0666.jpg does not exists.
#  284201/66055358302_004013_Endzone_0666.jpg does not exists.
#  284202/66055358302_004013_Endzone_0666.jpg does not exists.
#  284203/66055358302_004013_Endzone_0666.jpg does not exists.
#  284204/66055358302_004013_Endzone_0666.jpg does not exists.
#  284205/66055358302_004013_Endzone_0666.jpg does not exists.
#  284206/66055358302_004013_Endzone_0666.jpg does not exists.
#  284207/66055358302_004013_Endzone_0666.jpg does not exists.
#  284208/66055358302_004013_Endzone_0666.jpg does not exists.
#  284209/66055358302_004013_Endzone_0666.jpg does not exists.
#  284210/66055358302_004013_Endzone_0666.jpg does not exists.
#  284211/66055358302_004013_Endzone_0666.jpg does not exists.
#  284212/66055358302_004013_Endzone_0666.jpg does not exists.
#  284213/66055358302_004013_Endzone_0666.jpg does not exists.
#  284214/66055358302_004013_Endzone_0666.jpg does not exists.
#  313924/66055358316_004343_Endzone_0519.jpg does not exists.
#  313925/66055358316_004343_Endzone_0519.jpg does not exists.
#  313926/66055358316_004343_Endzone_0519.jpg does not exists.
#  313927/66055358316_004343_Endzone_0519.jpg does not exists.
#  313928/66055358316_004343_Endzone_0519.jpg does not exists.
#  313929/66055358316_004343_Endzone_0519.jpg does not exists.
#  313930/66055358316_004343_Endzone_0519.jpg does not exists.
#  320000/660553		 idx = 320000, elapsed time = 109.490 min
#  323956/66055358326_002516_Endzone_0900.jpg does not exists.
#  323957/66055358326_002516_Endzone_0900.jpg does not exists.
#  323958/66055358326_002516_Endzone_0900.jpg does not exists.
#  323959/66055358326_002516_Endzone_0900.jpg does not exists.
#  323960/66055358326_002516_Endzone_0900.jpg does not exists.
#  323961/66055358326_002516_Endzone_0900.jpg does not exists.
#  323962/66055358326_002516_Endzone_0900.jpg does not exists.
#  323963/66055358326_002516_Endzone_0900.jpg does not exists.
#  323964/66055358326_002516_Endzone_0900.jpg does not exists.
#  323965/66055358326_002516_Endzone_0900.jpg does not exists.
#  323966/66055358326_002516_Endzone_0900.jpg does not exists.
#  323967/66055358326_002516_Endzone_0900.jpg does not exists.
#  323968/66055358326_002516_Endzone_0900.jpg does not exists.
#  323969/66055358326_002516_Endzone_0900.jpg does not exists.
#  323970/66055358326_002516_Endzone_0900.jpg does not exists.
#  323971/66055358326_002516_Endzone_0900.jpg does not exists.
#  323972/66055358326_002516_Endzone_0900.jpg does not exists.
#  323973/66055358326_002516_Endzone_0900.jpg does not exists.
#  323974/66055358326_002516_Endzone_0900.jpg does not exists.
#  323975/66055358326_002516_Endzone_0900.jpg does not exists.
#  323976/66055358326_002516_Endzone_0900.jpg does not exists.
#  323977/66055358326_002516_Endzone_0900.jpg does not exists.
#  323978/66055358326_002516_Endzone_0900.jpg does not exists.
#  330000/660553		 idx = 330000, elapsed time = 113.060 min
#  338223/66055358336_000203_Endzone_0898.jpg does not exists.
#  338224/66055358336_000203_Endzone_0898.jpg does not exists.
#  338225/66055358336_000203_Endzone_0898.jpg does not exists.
#  338226/66055358336_000203_Endzone_0898.jpg does not exists.
#  338227/66055358336_000203_Endzone_0898.jpg does not exists.
#  338228/66055358336_000203_Endzone_0898.jpg does not exists.
#  338229/66055358336_000203_Endzone_0898.jpg does not exists.
#  338230/66055358336_000203_Endzone_0898.jpg does not exists.
#  338231/66055358336_000203_Endzone_0898.jpg does not exists.
#  338232/66055358336_000203_Endzone_0898.jpg does not exists.
#  338233/66055358336_000203_Endzone_0898.jpg does not exists.
#  338234/66055358336_000203_Endzone_0898.jpg does not exists.
#  338235/66055358336_000203_Endzone_0898.jpg does not exists.
#  338236/66055358336_000203_Endzone_0898.jpg does not exists.
#  338237/66055358336_000203_Endzone_0898.jpg does not exists.
#  338238/66055358336_000203_Endzone_0898.jpg does not exists.
#  338239/66055358336_000203_Endzone_0898.jpg does not exists.
#  338240/66055358336_000203_Endzone_0898.jpg does not exists.
#  338241/66055358336_000203_Endzone_0898.jpg does not exists.
#  338242/66055358336_000203_Endzone_0898.jpg does not exists.
#  338243/66055358336_000203_Endzone_0898.jpg does not exists.
#  338244/66055358336_000203_Endzone_0898.jpg does not exists.
#  338245/66055358336_000203_Endzone_0898.jpg does not exists.
#  338246/66055358336_000203_Endzone_0898.jpg does not exists.
#  338247/66055358336_000203_Endzone_0898.jpg does not exists.
#  338248/66055358336_000203_Endzone_0898.jpg does not exists.
#  338249/66055358336_000203_Endzone_0898.jpg does not exists.
#  338250/66055358336_000203_Endzone_0898.jpg does not exists.
#  338251/66055358336_000203_Endzone_0898.jpg does not exists.
#  338252/66055358336_000203_Endzone_0898.jpg does not exists.
#  338253/66055358336_000203_Endzone_0898.jpg does not exists.
#  338254/66055358336_000203_Endzone_0898.jpg does not exists.
#  338255/66055358336_000203_Endzone_0898.jpg does not exists.
#  340000/660553		 idx = 340000, elapsed time = 116.628 min
#  342074/66055358341_002805_Endzone_0713.jpg does not exists.
#  342075/66055358341_002805_Endzone_0713.jpg does not exists.
#  342076/66055358341_002805_Endzone_0713.jpg does not exists.
#  342077/66055358341_002805_Endzone_0713.jpg does not exists.
#  342078/66055358341_002805_Endzone_0713.jpg does not exists.
#  342079/66055358341_002805_Endzone_0713.jpg does not exists.
#  342080/66055358341_002805_Endzone_0713.jpg does not exists.
#  342081/66055358341_002805_Endzone_0713.jpg does not exists.
#  342082/66055358341_002805_Endzone_0713.jpg does not exists.
#  342083/66055358341_002805_Endzone_0713.jpg does not exists.
#  342084/66055358341_002805_Endzone_0713.jpg does not exists.
#  342085/66055358341_002805_Endzone_0713.jpg does not exists.
#  342086/66055358341_002805_Endzone_0713.jpg does not exists.
#  342087/66055358341_002805_Endzone_0713.jpg does not exists.
#  342088/66055358341_002805_Endzone_0713.jpg does not exists.
#  342089/66055358341_002805_Endzone_0713.jpg does not exists.
#  342090/66055358341_002805_Endzone_0713.jpg does not exists.
#  342091/66055358341_002805_Endzone_0713.jpg does not exists.
#  342092/66055358341_002805_Endzone_0713.jpg does not exists.
#  342093/66055358341_002805_Endzone_0713.jpg does not exists.
#  342094/66055358341_002805_Endzone_0713.jpg does not exists.
#  342095/66055358341_002805_Endzone_0713.jpg does not exists.
#  342096/66055358341_002805_Endzone_0713.jpg does not exists.
#  342097/66055358341_002805_Endzone_0713.jpg does not exists.
#  342098/66055358341_002805_Endzone_0713.jpg does not exists.
#  342099/66055358341_002805_Endzone_0713.jpg does not exists.
#  342100/66055358341_002805_Endzone_0713.jpg does not exists.
#  342101/66055358341_002805_Endzone_0713.jpg does not exists.
#  342102/66055358341_002805_Endzone_0713.jpg does not exists.
#  342103/66055358341_002805_Endzone_0713.jpg does not exists.
#  342104/66055358341_002805_Endzone_0713.jpg does not exists.
#  342105/66055358341_002805_Endzone_0713.jpg does not exists.
#  342106/66055358341_002805_Endzone_0713.jpg does not exists.
#  342107/66055358341_002805_Endzone_0713.jpg does not exists.
#  342108/66055358341_002805_Endzone_0713.jpg does not exists.
#  342109/66055358341_002805_Endzone_0713.jpg does not exists.
# ...
#  540000/660553		 idx = 540000, elapsed time = 197.261 min
#  550000/660553		 idx = 550000, elapsed time = 201.116 min
#  555147/66055358540_002206_Sideline_0713.jpg does not exists.
#  555148/66055358540_002206_Sideline_0713.jpg does not exists.
#  555149/66055358540_002206_Sideline_0713.jpg does not exists.
#  555150/66055358540_002206_Sideline_0713.jpg does not exists.
#  555151/66055358540_002206_Sideline_0713.jpg does not exists.
#  555152/66055358540_002206_Sideline_0713.jpg does not exists.
#  555153/66055358540_002206_Sideline_0713.jpg does not exists.
#  555154/66055358540_002206_Sideline_0713.jpg does not exists.
#  555155/66055358540_002206_Sideline_0713.jpg does not exists.
#  555156/66055358540_002206_Sideline_0713.jpg does not exists.
#  555157/66055358540_002206_Sideline_0713.jpg does not exists.
#  555158/66055358540_002206_Sideline_0713.jpg does not exists.
#  555159/66055358540_002206_Sideline_0713.jpg does not exists.
#  555160/66055358540_002206_Sideline_0713.jpg does not exists.
#  555161/66055358540_002206_Sideline_0713.jpg does not exists.
#  555162/66055358540_002206_Sideline_0713.jpg does not exists.
#  555163/66055358540_002206_Sideline_0713.jpg does not exists.
#  555164/66055358540_002206_Sideline_0713.jpg does not exists.
#  555165/66055358540_002206_Sideline_0713.jpg does not exists.
#  555166/66055358540_002206_Sideline_0713.jpg does not exists.
#  555167/66055358540_002206_Sideline_0713.jpg does not exists.
#  555168/66055358540_002206_Sideline_0713.jpg does not exists.
#  555169/66055358540_002206_Sideline_0713.jpg does not exists.
#  555170/66055358540_002206_Sideline_0713.jpg does not exists.
#  555171/66055358540_002206_Sideline_0713.jpg does not exists.
#  555172/66055358540_002206_Sideline_0713.jpg does not exists.
#  555173/66055358540_002206_Sideline_0713.jpg does not exists.
#  555174/66055358540_002206_Sideline_0713.jpg does not exists.
#  555175/66055358540_002206_Sideline_0713.jpg does not exists.
#  560000/660553		 idx = 560000, elapsed time = 204.725 min
#  562234/66055358541_000795_Sideline_0982.jpg does not exists.
#  562235/66055358541_000795_Sideline_0982.jpg does not exists.
#  562236/66055358541_000795_Sideline_0982.jpg does not exists.
#  562237/66055358541_000795_Sideline_0982.jpg does not exists.
#  562238/66055358541_000795_Sideline_0982.jpg does not exists.
#  562239/66055358541_000795_Sideline_0982.jpg does not exists.
#  562240/66055358541_000795_Sideline_0982.jpg does not exists.
#  562241/66055358541_000795_Sideline_0982.jpg does not exists.
#  562242/66055358541_000795_Sideline_0982.jpg does not exists.
#  562243/66055358541_000795_Sideline_0982.jpg does not exists.
#  562244/66055358541_000795_Sideline_0982.jpg does not exists.
#  562245/66055358541_000795_Sideline_0982.jpg does not exists.
#  562246/66055358541_000795_Sideline_0982.jpg does not exists.
#  562247/66055358541_000795_Sideline_0982.jpg does not exists.
#  562248/66055358541_000795_Sideline_0982.jpg does not exists.
#  562249/66055358541_000795_Sideline_0982.jpg does not exists.
#  562250/66055358541_000795_Sideline_0982.jpg does not exists.
#  562251/66055358541_000795_Sideline_0982.jpg does not exists.
#  562252/66055358541_000795_Sideline_0982.jpg does not exists.
#  562253/66055358541_000795_Sideline_0982.jpg does not exists.
#  562254/66055358541_000795_Sideline_0982.jpg does not exists.
#  562255/66055358541_000795_Sideline_0982.jpg does not exists.
#  562256/66055358541_000795_Sideline_0982.jpg does not exists.
#  562257/66055358541_000795_Sideline_0982.jpg does not exists.
#  562258/66055358541_000795_Sideline_0982.jpg does not exists.
#  562259/66055358541_000795_Sideline_0982.jpg does not exists.
#  570000/660553		 idx = 570000, elapsed time = 208.252 min
#  580000/660553		 idx = 580000, elapsed time = 211.995 min
#  582614/66055358550_002742_Sideline_0710.jpg does not exists.
#  582615/66055358550_002742_Sideline_0710.jpg does not exists.
#  582616/66055358550_002742_Sideline_0710.jpg does not exists.
#  582617/66055358550_002742_Sideline_0710.jpg does not exists.
#  582618/66055358550_002742_Sideline_0710.jpg does not exists.
#  582619/66055358550_002742_Sideline_0710.jpg does not exists.
#  582620/66055358550_002742_Sideline_0710.jpg does not exists.
#  582621/66055358550_002742_Sideline_0710.jpg does not exists.
#  582622/66055358550_002742_Sideline_0710.jpg does not exists.
#  582623/66055358550_002742_Sideline_0710.jpg does not exists.
#  582624/66055358550_002742_Sideline_0710.jpg does not exists.
#  582625/66055358550_002742_Sideline_0710.jpg does not exists.
#  582626/66055358550_002742_Sideline_0710.jpg does not exists.
#  582627/66055358550_002742_Sideline_0710.jpg does not exists.
#  582628/66055358550_002742_Sideline_0710.jpg does not exists.
#  582629/66055358550_002742_Sideline_0710.jpg does not exists.
#  582630/66055358550_002742_Sideline_0710.jpg does not exists.
#  582631/66055358550_002742_Sideline_0710.jpg does not exists.
#  582632/66055358550_002742_Sideline_0710.jpg does not exists.
#  582633/66055358550_002742_Sideline_0710.jpg does not exists.
#  582634/66055358550_002742_Sideline_0710.jpg does not exists.
#  582635/66055358550_002742_Sideline_0710.jpg does not exists.
#  582636/66055358550_002742_Sideline_0710.jpg does not exists.
#  582637/66055358550_002742_Sideline_0710.jpg does not exists.
#  582638/66055358550_002742_Sideline_0710.jpg does not exists.
#  582639/66055358550_002742_Sideline_0710.jpg does not exists.
#  582640/66055358550_002742_Sideline_0710.jpg does not exists.
#  582641/66055358550_002742_Sideline_0710.jpg does not exists.
#  590000/660553		 idx = 590000, elapsed time = 215.850 min
#  600000/660553		 idx = 600000, elapsed time = 219.569 min
#  601554/66055358553_003801_Sideline_0895.jpg does not exists.
#  601555/66055358553_003801_Sideline_0895.jpg does not exists.
#  601556/66055358553_003801_Sideline_0895.jpg does not exists.
#  601557/66055358553_003801_Sideline_0895.jpg does not exists.
#  601558/66055358553_003801_Sideline_0895.jpg does not exists.
#  601559/66055358553_003801_Sideline_0895.jpg does not exists.
#  601560/66055358553_003801_Sideline_0895.jpg does not exists.
#  601561/66055358553_003801_Sideline_0895.jpg does not exists.
#  601562/66055358553_003801_Sideline_0895.jpg does not exists.
#  601563/66055358553_003801_Sideline_0895.jpg does not exists.
#  601564/66055358553_003801_Sideline_0895.jpg does not exists.
#  601565/66055358553_003801_Sideline_0895.jpg does not exists.
#  601566/66055358553_003801_Sideline_0895.jpg does not exists.
#  601567/66055358553_003801_Sideline_0895.jpg does not exists.
#  601568/66055358553_003801_Sideline_0895.jpg does not exists.
#  601569/66055358553_003801_Sideline_0895.jpg does not exists.
#  601570/66055358553_003801_Sideline_0895.jpg does not exists.
#  601571/66055358553_003801_Sideline_0895.jpg does not exists.
#  601572/66055358553_003801_Sideline_0895.jpg does not exists.
#  601573/66055358553_003801_Sideline_0895.jpg does not exists.
#  601574/66055358553_003801_Sideline_0895.jpg does not exists.
#  601575/66055358553_003801_Sideline_0895.jpg does not exists.
#  601576/66055358553_003801_Sideline_0895.jpg does not exists.
#  601577/66055358553_003801_Sideline_0895.jpg does not exists.
#  601578/66055358553_003801_Sideline_0895.jpg does not exists.
#  601579/66055358553_003801_Sideline_0895.jpg does not exists.
#  610000/660553		 idx = 610000, elapsed time = 223.277 min
#  615881/66055358560_001856_Sideline_0767.jpg does not exists.
#  615882/66055358560_001856_Sideline_0767.jpg does not exists.
#  615883/66055358560_001856_Sideline_0767.jpg does not exists.
#  615884/66055358560_001856_Sideline_0767.jpg does not exists.
#  615885/66055358560_001856_Sideline_0767.jpg does not exists.
#  615886/66055358560_001856_Sideline_0767.jpg does not exists.
#  615887/66055358560_001856_Sideline_0767.jpg does not exists.
#  615888/66055358560_001856_Sideline_0767.jpg does not exists.
#  615889/66055358560_001856_Sideline_0767.jpg does not exists.
#  615890/66055358560_001856_Sideline_0767.jpg does not exists.
#  615891/66055358560_001856_Sideline_0767.jpg does not exists.
#  615892/66055358560_001856_Sideline_0767.jpg does not exists.
#  615893/66055358560_001856_Sideline_0767.jpg does not exists.
#  615894/66055358560_001856_Sideline_0767.jpg does not exists.
#  615895/66055358560_001856_Sideline_0767.jpg does not exists.
#  615896/66055358560_001856_Sideline_0767.jpg does not exists.
#  615897/66055358560_001856_Sideline_0767.jpg does not exists.
#  615898/66055358560_001856_Sideline_0767.jpg does not exists.
#  615899/66055358560_001856_Sideline_0767.jpg does not exists.
#  615900/66055358560_001856_Sideline_0767.jpg does not exists.
#  615901/66055358560_001856_Sideline_0767.jpg does not exists.
#  615902/66055358560_001856_Sideline_0767.jpg does not exists.
#  615903/66055358560_001856_Sideline_0767.jpg does not exists.
#  615904/66055358560_001856_Sideline_0767.jpg does not exists.
#  615905/66055358560_001856_Sideline_0767.jpg does not exists.
#  615906/66055358560_001856_Sideline_0767.jpg does not exists.
#  615907/66055358560_001856_Sideline_0767.jpg does not exists.
#  615908/66055358560_001856_Sideline_0767.jpg does not exists.
#  615909/66055358560_001856_Sideline_0767.jpg does not exists.
#  615910/66055358560_001856_Sideline_0767.jpg does not exists.
#  615911/66055358560_001856_Sideline_0767.jpg does not exists.
#  615912/66055358560_001856_Sideline_0767.jpg does not exists.
#  615913/66055358560_001856_Sideline_0767.jpg does not exists.
#  615914/66055358560_001856_Sideline_0767.jpg does not exists.
#  615915/66055358560_001856_Sideline_0767.jpg does not exists.
#  615916/66055358560_001856_Sideline_0767.jpg does not exists.
#  615917/66055358560_001856_Sideline_0767.jpg does not exists.
#  620000/660553		 idx = 620000, elapsed time = 226.898 min
#  633102/66055358568_002209_Sideline_0608.jpg does not exists.
#  633103/66055358568_002209_Sideline_0608.jpg does not exists.
#  633104/66055358568_002209_Sideline_0608.jpg does not exists.
#  633105/66055358568_002209_Sideline_0608.jpg does not exists.
#  633106/66055358568_002209_Sideline_0608.jpg does not exists.
#  633107/66055358568_002209_Sideline_0608.jpg does not exists.
#  633108/66055358568_002209_Sideline_0608.jpg does not exists.
#  633109/66055358568_002209_Sideline_0608.jpg does not exists.
#  633110/66055358568_002209_Sideline_0608.jpg does not exists.
#  633111/66055358568_002209_Sideline_0608.jpg does not exists.
#  633112/66055358568_002209_Sideline_0608.jpg does not exists.
#  640000/660553		 idx = 640000, elapsed time = 234.050 min
#  640938/66055358573_002569_Sideline_0708.jpg does not exists.
#  640939/66055358573_002569_Sideline_0708.jpg does not exists.
#  640940/66055358573_002569_Sideline_0708.jpg does not exists.
#  640941/66055358573_002569_Sideline_0708.jpg does not exists.
#  640942/66055358573_002569_Sideline_0708.jpg does not exists.
#  640943/66055358573_002569_Sideline_0708.jpg does not exists.
#  640944/66055358573_002569_Sideline_0708.jpg does not exists.
#  640945/66055358573_002569_Sideline_0708.jpg does not exists.
#  640946/66055358573_002569_Sideline_0708.jpg does not exists.
#  640947/66055358573_002569_Sideline_0708.jpg does not exists.
#  640948/66055358573_002569_Sideline_0708.jpg does not exists.
#  640949/66055358573_002569_Sideline_0708.jpg does not exists.
#  640950/66055358573_002569_Sideline_0708.jpg does not exists.
#  640951/66055358573_002569_Sideline_0708.jpg does not exists.
#  640952/66055358573_002569_Sideline_0708.jpg does not exists.
#  640953/66055358573_002569_Sideline_0708.jpg does not exists.
#  640954/66055358573_002569_Sideline_0708.jpg does not exists.
#  640955/66055358573_002569_Sideline_0708.jpg does not exists.
#  640956/66055358573_002569_Sideline_0708.jpg does not exists.
#  640957/66055358573_002569_Sideline_0708.jpg does not exists.
#  640958/66055358573_002569_Sideline_0708.jpg does not exists.
#  640959/66055358573_002569_Sideline_0708.jpg does not exists.
#  640960/66055358573_002569_Sideline_0708.jpg does not exists.
#  640961/66055358573_002569_Sideline_0708.jpg does not exists.
#  640962/66055358573_002569_Sideline_0708.jpg does not exists.
#  640963/66055358573_002569_Sideline_0708.jpg does not exists.
#  640964/66055358573_002569_Sideline_0708.jpg does not exists.
#  640965/66055358573_002569_Sideline_0708.jpg does not exists.
#  640966/66055358573_002569_Sideline_0708.jpg does not exists.
#  640967/66055358573_002569_Sideline_0708.jpg does not exists.
#  640968/66055358573_002569_Sideline_0708.jpg does not exists.
#  640969/66055358573_002569_Sideline_0708.jpg does not exists.
#  640970/66055358573_002569_Sideline_0708.jpg does not exists.
#  640971/66055358573_002569_Sideline_0708.jpg does not exists.
#  640972/66055358573_002569_Sideline_0708.jpg does not exists.
#  640973/66055358573_002569_Sideline_0708.jpg does not exists.
#  640974/66055358573_002569_Sideline_0708.jpg does not exists.
#  650000/660553		 idx = 650000, elapsed time = 237.631 min
#  660000/660553		 idx = 660000, elapsed time = 241.218 min
#  660552/660553
