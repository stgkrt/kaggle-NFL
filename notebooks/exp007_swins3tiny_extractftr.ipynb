# %% [markdown]
# # NFL Baseline
# - create target_df (distance in tracking_df is lower than threshold=3)
# https://www.kaggle.com/code/stgkrtua/nfl-creatatraindataset-targetdf
# - create dataset save frames in target_df
# https://www.kaggle.com/code/stgkrtua/nfl-createdataset-saveframes
# - check saved images
# https://www.kaggle.com/code/stgkrtua/nfl-checkdataset-plotsavedimage

# %% [markdown]
# # import libraries

# %%
# general
import os
import gc
import pickle
import glob
import random
import numpy as np
import pandas as pd
from tqdm.notebook import tqdm
import cv2
import matplotlib.pyplot as plt
import time
import math

import sys
sys.path.append('/kaggle/input/timm-pytorch-image-models/pytorch-image-models-master')
import timm


# deep learning
from torch.utils.data import Dataset, DataLoader
from torch.optim import SGD, Adam, AdamW
from torch.optim.lr_scheduler import CosineAnnealingLR, CosineAnnealingWarmRestarts, ReduceLROnPlateau
import torch
import torchvision
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

import albumentations as A
from albumentations.pytorch import ToTensorV2

from sklearn.model_selection import StratifiedKFold

# loss metrics
from sklearn.metrics import matthews_corrcoef, confusion_matrix, roc_auc_score

import mlflow
# import wandb
# warningの表示方法の設定
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # Set Configurations

# %%
CFG = {
        "kaggle" : False,
        "DEBUG" : False,
        # model config
        "model_name" : "swin_s3_tiny_224",
        "out_features" : 20,
        "inp_channels": 3*2,
        "num_extractFTR" : 5,
        "pretrained" : True,
        "features" : ['x_position_1', 'y_position_1', 'x_position_2', 'y_position_2', 
                      'speed_1', 'distance_1', 'direction_1', 'orientation_1','acceleration_1', 'sa_1', 
                      'speed_2', 'distance_2', 'direction_2', 'orientation_2', 'acceleration_2', 'sa_2',
                      'players_dis', 'is_ground'],
        "track_features_x_1" : ['x_position_shift-6_1','x_position_shift-5_1', 'x_position_shift-4_1',
                                'x_position_shift-3_1','x_position_shift-2_1', 'x_position_shift-1_1', 
                                'x_position_shift0_1','x_position_shift1_1', 'x_position_shift2_1', 
                                'x_position_shift3_1','x_position_shift4_1', 'x_position_shift5_1'],    
        "track_features_y_1" : ['y_position_shift-6_1','y_position_shift-5_1', 'y_position_shift-4_1',
                                'y_position_shift-3_1','y_position_shift-2_1', 'y_position_shift-1_1',
                                'y_position_shift0_1','y_position_shift1_1', 'y_position_shift2_1',
                                'y_position_shift3_1','y_position_shift4_1', 'y_position_shift5_1'],
        "track_features_x_2" : ['x_position_shift-6_2','x_position_shift-5_2', 'x_position_shift-4_2',
                                'x_position_shift-3_2','x_position_shift-2_2', 'x_position_shift-1_2',
                                'x_position_shift0_2','x_position_shift1_2', 'x_position_shift2_2',
                                'x_position_shift3_2','x_position_shift4_2', 'x_position_shift5_2'],
        "track_features_y_2" : ['y_position_shift-6_2','y_position_shift-5_2', 'y_position_shift-4_2',
                                'y_position_shift-3_2','y_position_shift-2_2', 'y_position_shift-1_2',
                                'y_position_shift0_2','y_position_shift1_2', 'y_position_shift2_2',
                                'y_position_shift3_2','y_position_shift4_2', 'y_position_shift5_2'],
        # learning config
        "n_epoch" : 40,
        "lr" : 1e-4,
        "T_max" : 10,
        "min_lr" : 1e-8,
        "weight_decay" : 1e-6,

        # etc
        "print_freq" : 1000,
        "random_seed" : 21,

        # data config    
        "img_size" : (224, 224),
        "batch_size" : 32,
        "num_workers" : 8,
        "masksize_helmet_ratio" : 4, # helmetサイズにこの係数をかけたサイズだけ色を残して後は黒塗りする
        "TRAIN_VIDEO_NUM" : 100,
        "VALID_VIDEO_NUM" : 10,
        "sample_num" : -1, 

        "EXP_CATEGORY" : "exps",
        "EXP_NAME" : "exp007_swins3tiny_extractFTR",
}

if CFG["DEBUG"]:
    CFG["EXP_CATEGORY"] = "DEBUG"
    CFG["EXP_NAME"] = "DEBUG"
    CFG["n_epoch"] = 2
    CFG["sample_num"] = 1000
    CFG["batch_size"] = 32

if CFG["kaggle"]:
    CFG["INPUT_DIR"] = "/kaggle/input/"
    CFG["OUTPUT_DIR"] = "/kaggle/working/"
    CFG["TRAIN_HELMET_CSV"] = os.path.join(CFG["INPUT_DIR"], "nfl-player-contact-detection", "train_baseline_helmets.csv")
    CFG["TRAIN_TRACKING_CSV"] = os.path.join(CFG["INPUT_DIR"], "nfl-player-contact-detection", "train_player_tracking.csv")
    CFG["TRAIN_VIDEO_META_CSV"] = os.path.join(CFG["INPUT_DIR"], "nfl-player-contact-detection", "train_video_metadata.csv")
    CFG["TRAIN_LABEL_CSV"] = os.path.join(CFG["INPUT_DIR"], "nfl-player-contact-detection", "train_labels.csv")
    CFG["TARGET_CSV"] = os.path.join(CFG["INPUT_DIR"], "nfl-createdataset-saveframes-shift", "saved_frame_target.csv")
    CFG["TRAIN_E_IMG_DIR"] = os.path.join(CFG["INPUT_DIR"], "nfl-createdataset-saveframes-shift", "train_images")
    CFG["TRAIN_S_IMG_DIR"] = os.path.join(CFG["INPUT_DIR"], "nfl-createdataset-saveframes-shift-sview", "train_images")
    CFG["MODEL_DIR"] = CFG["OUTPUT_DIR"]
else:
    CFG["INPUT_DIR"] = "/workspace/input"
    CFG["OUTPUT_DIR"] = "/workspace/output"
    CFG["TRAIN_HELMET_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_baseline_helmets.csv")
    CFG["TRAIN_TRACKING_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_player_tracking.csv")
    CFG["TRAIN_VIDEO_META_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_video_metadata.csv")
    CFG["TRAIN_LABEL_CSV"] = os.path.join(CFG["INPUT_DIR"], "train_labels.csv")
    CFG["TARGET_CSV"] = os.path.join(CFG["INPUT_DIR"], "target_fillna0_shift_2.csv")
    CFG["TRAIN_E_IMG_DIR"] = os.path.join(CFG["INPUT_DIR"], "train_frames")
    CFG["TRAIN_S_IMG_DIR"] = CFG["TRAIN_E_IMG_DIR"]
    CFG["CONTACT_IMG_DIR"] = os.path.join(CFG["INPUT_DIR"], "contact_images")
    CFG["MODEL_DIR"] = os.path.join(CFG["OUTPUT_DIR"], CFG["EXP_NAME"] ,"model")
    
# if not CFG["kaggle"] and not CFG["DEBUG"]:
    # os.mkdir(os.path.join(CFG["OUTPUT_DIR"], CFG["EXP_NAME"]))
    # os.mkdir(CFG["MODEL_DIR"])

# %%
if CFG["kaggle"]:
    os.environ["WANDB_SILENT"] = "true"
    WANDB_CONFIG = {'competition': 'NFL', '_wandb_kernel': 'taro'}
    # Secrets
    from kaggle_secrets import UserSecretsClient
    user_secrets = UserSecretsClient()
    secret_value_0 = user_secrets.get_secret("wandb")

    # !wandb login $secret_value_0
    #! TODO : logger settings
    wandb.init(project=WANDB_CONFIG["competition"], config=CFG, group=CFG["EXP_CATEGORY"], name=CFG["EXP_NAME"])

else:
    mlflow.set_tracking_uri("/workspace/mlruns")
    experiment = mlflow.get_experiment_by_name(CFG["EXP_CATEGORY"])
    if experiment is None:  # 当該Experiment存在しないとき、新たに作成
        experiment_id = mlflow.create_experiment(name=CFG["EXP_CATEGORY"])
    else: # 当該Experiment存在するとき、IDを取得
        experiment_id = experiment.experiment_id

# %% [markdown]
# # Utils

# %%
def logging_metrics_epoch(fold, epoch, train_loss_avg, valid_loss_avg, score, threshold, tn_best, fp_best, fn_best, tp_best, auc_score):
    if CFG["kaggle"]:
        wandb.log({"loss avg":{f"train/fold{fold}": train_loss_avg,
                                f"valid/fold{fold}": valid_loss_avg}}, step=epoch)
        wandb.log({"Metircs" : {f"score/fold{fold}":score,
                                f"score threshold/fold{fold}":threshold,
                                f"tn/fold{fold}":tn_best,
                                f"fp/fold{fold}":fp_best,
                                f"fn/fold{fold}":fn_best,
                                f"tp/fold{fold}":tp_best,
                                f"auc/fold{fold}":auc_score,
                               }}, step=epoch)
    else:
        mlflow.log_metric(f"fold{fold} train loss avg", train_loss_avg, step=epoch)
        mlflow.log_metric(f"fold{fold} valid loss avg", valid_loss_avg, step=epoch)
        mlflow.log_metric(f"fold{fold} score", score, step=epoch)
        mlflow.log_metric(f"fold{fold} score threshold", threshold, step=epoch)
        mlflow.log_metric(f"fold{fold} tn", tn_best, step=epoch)
        mlflow.log_metric(f"fold{fold} fp", fp_best, step=epoch)
        mlflow.log_metric(f"fold{fold} fn", fn_best, step=epoch)
        mlflow.log_metric(f"fold{fold} tp", tp_best, step=epoch)
        mlflow.log_metric(f"fold{fold} auc", auc_score, step=epoch)

# %%
def seed_everything(seed=CFG["random_seed"]):
    #os.environ['PYTHONSEED'] = str(seed)
    np.random.seed(seed%(2**32-1))
    random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic =True
    torch.backends.cudnn.benchmark = False
seed_everything()

# device optimization
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')
print(f'Using device: {device}')
# Out:
# Using device: cuda

# %%
def asMinutes(s):
    """Convert Seconds to Minutes."""
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)

def timeSince(since, percent):
    """Accessing and Converting Time Data."""
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))

class AverageMeter(object):
    """Computes and stores the average and current value."""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count

# %% [markdown]
# # Load Data

# %%
target_df = pd.read_csv(CFG["TARGET_CSV"])
# target_game_plays = target_df["game_play"].unique()[:50]
train_game_plays = target_df["game_play"].unique()[:CFG["TRAIN_VIDEO_NUM"]]
valid_game_plays = target_df["game_play"].unique()[-CFG["VALID_VIDEO_NUM"]:]
target_game_plays = list(set(train_game_plays) | set(valid_game_plays))
CFG["target_game_plays"] = list(target_game_plays)
target_df = target_df[target_df["game_play"].isin(target_game_plays)]

if CFG["DEBUG"]:
    target_df = target_df.sample(CFG["sample_num"])
elif CFG["sample_num"] != -1:
    target_df = target_df.sample(CFG["sample_num"])

target_df["is_ground"] = (target_df["nfl_player_id_2"] == "G").astype(np.int)
print(len(target_df))
display(target_df["contact"].value_counts())
# Out:
# 305164
# 0    274357
# 1     30807
# Name: contact, dtype: int64

# %%
# diff_cols = ['speed', 'distance', 'direction', 'orientation','acceleration', 'sa']

# for col in diff_cols:
#     target_df[f"{col}_diff"] = abs(target_df[f"{col}_1"] - target_df[f"{col}_2"])

# %%
train_transform = A.Compose([
    A.HorizontalFlip(p=0.5),
    A.RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.3, 0.3), p=0.5),
    A.Normalize(mean=[0.], std=[1.]),
    ToTensorV2()
])

valid_transform = A.Compose([
    A.Normalize(mean=[0.], std=[1.]),
    ToTensorV2()
])

# %% [markdown]
# # Dataset

# %%
class NFLDataset(Dataset):
    def __init__(self, target_df, transform=None):
        self.target_df = target_df
        self.features = target_df[CFG["features"]].values
        self.track_features_x_1 = target_df[CFG["track_features_x_1"]].values
        self.track_features_y_1 = target_df[CFG["track_features_y_1"]].values
        self.track_features_x_2 = target_df[CFG["track_features_x_2"]].values
        self.track_features_y_2 = target_df[CFG["track_features_y_2"]].values
        self.transform = transform

    def __len__(self):
        return len(self.target_df)

    def __getitem__(self, idx):
        target_info = self.target_df.iloc[idx]
        features = self.features[idx]
        track_x_1 = self.track_features_x_1[idx]
        track_y_1 = self.track_features_y_1[idx]
        track_x_2 = self.track_features_x_2[idx]
        track_y_2 = self.track_features_y_2[idx]
        track_features = np.concatenate([track_x_1[np.newaxis, :],
                                         track_y_1[np.newaxis, :],
                                         track_x_2[np.newaxis, :],
                                         track_y_2[np.newaxis, :]])

        target = target_info.contact
        # read frame image
        game_play = target_info.game_play
        frame = target_info.frame
        contact_id = target_info.contact_id
        contact_fileid = f"{contact_id}_Endzone.jpg"
        contact_filename = os.path.join(CFG["CONTACT_IMG_DIR"], contact_fileid)
        img = cv2.imread(contact_filename)
        if img is None:
            img = np.zeros((224, 224, 3))
            img = np.transpose(img, (2, 0, 1)).astype(np.float)
            img = torch.tensor(img, dtype=torch.float)
        else:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img / 255. # convert to 0-1
                img = np.transpose(img, (2, 0, 1)).astype(np.float32)
            img = torch.tensor(img, dtype=torch.float)
        input_img = img
        contact_fileid = f"{contact_id}_Sideline.jpg"
        contact_filename = os.path.join(CFG["CONTACT_IMG_DIR"], contact_fileid)
        img = cv2.imread(contact_filename)
        if img is None:
            img = np.zeros((224, 224, 3))
            img = np.transpose(img, (2, 0, 1)).astype(np.float)
            img = torch.tensor(img, dtype=torch.float)
        else:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            if self.transform:
                img = self.transform(image=img)["image"]
            else:
                img = img / 255. # convert to 0-1
                img = np.transpose(img, (2, 0, 1)).astype(np.float32)
            img = torch.tensor(img, dtype=torch.float)
        input_img = np.concatenate([input_img, img], axis=0)
        input_img = torch.tensor(input_img, dtype=torch.float)
        target = torch.tensor(target, dtype=torch.float)
        features = torch.tensor(features, dtype=torch.float)
        track_features = torch.tensor(track_features, dtype=torch.float)
        return input_img, features, track_features, target

# %%
# checkするときは255.で割るのを全体にかける(normalizeがcheckにはないので真っ白とか真っ黒になるのを回避)
# show_img_num = 4

# check_transform = A.Compose([
#     A.HorizontalFlip(p=1.0),
#     A.RandomBrightnessContrast(brightness_limit=(-0.1, 0.1), contrast_limit=(-0.3, 0.3), p=1.0),
# #     A.Normalize(mean=[0.], std=[1.]),
#     ToTensorV2()
# ])


# pick_df = target_df[target_df["contact"]==1]
# train_dataset = NFLDataset(pick_df, check_transform)
# train_loader = DataLoader(
#     train_dataset,
#     batch_size = show_img_num,
#     shuffle = False,
#     num_workers = CFG["num_workers"],
#     pin_memory = True
# )
# for batch_idx, (images, features, track_features, targets) in enumerate(train_loader):
#     fig = plt.figure(figsize=(12, 25))
#     print(images.shape)
#     print("features shape =",features.shape)
#     print("track features shape =",track_features.shape)
#     for idx in range(show_img_num):
#         img = images[idx].numpy()
#         img = img.transpose((1,2,0))
#         img = img[:, :, 0:3]
#         fig.add_subplot(1,show_img_num ,idx+1)
#         plt.imshow(img)
#         plt.title(targets[idx].numpy())
#     plt.show()
    
#     fig = plt.figure(figsize=(12, 25))
#     for idx in range(show_img_num):
#         img = images[idx].numpy()
#         img = img.transpose((1,2,0))
#         img = img[:, :, 3:6]
#         fig.add_subplot(1,show_img_num ,idx+1)
#         plt.imshow(img)
#         plt.title(targets[idx].numpy())
#     plt.show()
#     break
# del train_loader, train_dataset

# pick_df = target_df[target_df["contact"]==1]
# train_dataset = NFLDataset(pick_df)
# train_loader = DataLoader(
#     train_dataset,
#     batch_size = show_img_num,
#     shuffle = False,
#     num_workers = CFG["num_workers"],
#     pin_memory = True
# )
# for batch_idx, (images, features, track_features, targets) in enumerate(train_loader):
#     fig = plt.figure(figsize=(12, 25))
#     print(images.shape)
#     print("features shape =",features.shape)
#     print("track features shape =",track_features.shape)
#     for idx in range(show_img_num):
#         img = images[idx].numpy()
#         img = img.transpose((1,2,0))
#         img = img[:, :, 0:3]
#         fig.add_subplot(1,show_img_num ,idx+1)
#         plt.imshow(img)
#         plt.title(targets[idx].numpy())
#     plt.show()
    
#     fig = plt.figure(figsize=(12, 25))
#     for idx in range(show_img_num):
#         img = images[idx].numpy()
#         img = img.transpose((1,2,0))
#         img = img[:, :, 3:6]
#         fig.add_subplot(1,show_img_num ,idx+1)
#         plt.imshow(img)
#         plt.title(targets[idx].numpy())
#     plt.show()
#     break
# del train_loader, train_dataset

# %% [markdown]
# # Model

# %%
# without meta
class NFLNet(nn.Module):
    def __init__(
        self,
        model_name = CFG["model_name"],
        out_features = CFG["out_features"],
        inp_channels= CFG["inp_channels"],
        pretrained = CFG["pretrained"]
    ):
        super().__init__()
        self.model = timm.create_model(model_name, pretrained=pretrained, in_chans=inp_channels, num_classes=out_features)
        self.mlp = nn.Sequential(
                        nn.Linear(len(CFG["features"]), 32),
                        nn.LayerNorm(32),
                        nn.ReLU(),
                        nn.Dropout(0.2),
                    )
        self.conv1 = nn.Sequential(
                        nn.Conv1d(4, 1, 5),
                        nn.Linear(len(CFG["track_features_y_2"])-4, 32),
                        nn.ReLU(),
                    )
        self.fc = nn.Linear(out_features+32+32, 1)
        self.emb = nn.Linear(out_features+32, CFG["num_extractFTR"])

    def forward(self, image, features, track_features):
        image_feature = self.model(image)
        features = self.mlp(features)
        track_features = self.conv1(track_features)
        if features.shape[0] == 1:
            track_featurs = track_featurs.reshape(1, -1)
        else:
            track_featurs = torch.squeeze(track_features)
        output = self.fc(torch.cat([image_feature, features, track_featurs], dim=1))
        embeddings = self.emb(torch.cat([image_feature, track_featurs], dim=1))
        return output, embeddings

# %% [markdown]
# # train fn

# %%
def train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler):
    model.train()
    batch_time = AverageMeter()
    losses = AverageMeter()
    start, end = time.time(), time.time()
    for batch_idx, (images, features, track_features, targets) in enumerate(train_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float().view(-1, 1)      
        features = features.to(device, non_blocking = True).float()
        track_features = track_features.to(device, non_blocking = True).float()
        preds, _ = model(images, features, track_features)
        
        loss = criterion(preds, targets)
        losses.update(loss.item(), CFG["batch_size"]) 
        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = torch.sigmoid(preds).detach().cpu().numpy().ravel().tolist()

        loss.backward() # パラメータの勾配を計算
        optimizer.step() # モデル更新
        optimizer.zero_grad() # 勾配の初期化
                
        batch_time.update(time.time() - end)
        end = time.time()
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(train_loader)-1):
            print('\t Epoch: [{0}][{1}/{2}] '
                    'Elapsed {remain:s} '
                    'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                    .format(
                        epoch, batch_idx, len(train_loader), batch_time=batch_time, loss=losses,
                        remain=timeSince(start, float(batch_idx+1)/len(train_loader)),
            ))
        del preds, images, features, targets
    gc.collect()
    torch.cuda.empty_cache()
    return losses.avg

# %% [markdown]
# # valid fn

# %%
def valid_fn(model, valid_loader, criterion):
    model.eval()# モデルを検証モードに設定
    test_targets = []
    test_preds = []

    batch_time = AverageMeter()
    losses = AverageMeter()
    start, end = time.time(), time.time()
    for batch_idx, (images, features, track_features, targets) in enumerate(valid_loader):
        images = images.to(device, non_blocking = True).float()
        targets = targets.to(device, non_blocking = True).float().view(-1, 1)
        features = features.to(device, non_blocking = True).float()
        track_features = track_features.to(device, non_blocking = True).float()
        with torch.no_grad():
            preds, _ = model(images, features, track_features)
            loss = criterion(preds, targets)
        losses.update(loss.item(), CFG["batch_size"])
        batch_time.update(time.time() - end)

        targets = targets.detach().cpu().numpy().ravel().tolist()
        preds = torch.sigmoid(preds).detach().cpu().numpy().ravel().tolist()

        test_preds.extend(preds)
        test_targets.extend(targets)
        # score = matthews_corrcoef(preds, targets)
        if batch_idx % CFG["print_freq"] == 0 or batch_idx == (len(valid_loader)-1):
            print('\t EVAL: [{0}/{1}] '
                'Elapsed {remain:s} '
                'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                .format(
                    batch_idx, len(valid_loader), batch_time=batch_time, loss=losses,
                    remain=timeSince(start, float(batch_idx+1)/len(valid_loader)),
                ))
        del preds, images, features, targets
        gc.collect()
        torch.cuda.empty_cache()
    test_preds = np.array(test_preds)
    test_targets = np.array(test_targets)
    return test_targets, test_preds, losses.avg

# %% [markdown]
# # Train loop

# %%
def training_loop(target_df):
    # set model & learning fn
    model = NFLNet()
    model = model.to(device)
    if CFG["kaggle"]:
        wandb.watch(model)
    criterion = nn.BCEWithLogitsLoss()
    optimizer = AdamW(model.parameters(), lr=CFG["lr"], weight_decay=CFG["weight_decay"], amsgrad=False)
    scheduler = CosineAnnealingLR(optimizer, T_max=CFG["T_max"], eta_min=CFG["min_lr"], last_epoch=-1)

    oof_df = pd.DataFrame()
    fold = 0
    # separate train/valid data 
    train_df = target_df[target_df["game_play"].isin(train_game_plays)]
    valid_df = target_df[target_df["game_play"].isin(valid_game_plays)]
    train_dataset = NFLDataset(train_df, train_transform)
    valid_dataset = NFLDataset(valid_df, valid_transform)
    train_loader = DataLoader(train_dataset,batch_size=CFG["batch_size"], shuffle = True,
                                num_workers = CFG["num_workers"], pin_memory = True)
    valid_loader = DataLoader(valid_dataset,batch_size=CFG["batch_size"], shuffle = False,
                                num_workers = CFG["num_workers"], pin_memory = True)

    # training
    best_score = -np.inf
    best_auc = -np.inf
    start_time, end = time.time(), time.time()
    for epoch in range(1, CFG["n_epoch"] + 1):
        print(f'\t === epoch: {epoch}: training ===')
        train_loss_avg = train_fn(train_loader, model, criterion, epoch ,optimizer, scheduler)
        valid_targets, valid_preds, valid_loss_avg = valid_fn(model, valid_loader, criterion)

        valid_score = -np.inf
        valid_threshold = 0
        tn_best, fp_best, fn_best, tp_best = 0, 0, 0, 0
        for idx in range(1, 10, 1):
            thr = idx*0.1
            valid_targets = (np.array(valid_targets) > thr).astype(np.int32)
            valid_binary_preds = (np.array(valid_preds) > thr).astype(np.int32)
            score_tmp = matthews_corrcoef(valid_targets, valid_binary_preds)
            cm = confusion_matrix(valid_targets, valid_binary_preds)
            tn, fp, fn, tp = cm.flatten()
            if score_tmp > valid_score:
                valid_score = score_tmp 
                valid_threshold = thr
                tn_best, fp_best, fn_best, tp_best = tn, fp, fn, tp
        elapsed = time.time() - start_time
        print(f'\t epoch:{epoch}, avg train loss:{train_loss_avg:.4f}, avg valid loss:{valid_loss_avg:.4f}, score:{valid_score:.4f}(th={valid_threshold}) ::: time:{elapsed:.2f}s')
        scheduler.step()
        # validationスコアがbestを更新したらモデルを保存する
        if valid_score > best_score:
            best_score = valid_score
            model_name = CFG["model_name"]
            torch.save(model.state_dict(), f'{CFG["MODEL_DIR"]}/{model_name}_fold{fold}.pth')
            print(f'\t Epoch {epoch} - Save Best Score: {best_score:.4f}. Model is saved.')
            contact_id = valid_df["contact_id"].values
            _oof_df = pd.DataFrame({
                "contact_id" : contact_id,
                "pred" : valid_preds,
                "contact" : valid_targets,
                "fold" : fold,
            })
            
        auc_score = roc_auc_score(valid_targets, valid_preds)
        if best_auc < auc_score:
            best_auc = auc_score
            model_name = CFG["model_name"]
            torch.save(model.state_dict(), f'{CFG["MODEL_DIR"]}/{model_name}_bestauc_fold{fold}.pth')
            print(f'\t Epoch {epoch} - Save Best AUC Score: {best_auc:.4f}. Model is saved.')
            
        logging_metrics_epoch(fold, epoch, train_loss_avg, valid_loss_avg, valid_score, valid_threshold, tn_best, fp_best, fn_best, tp_best, auc_score)

    del train_loader, train_dataset, valid_loader, valid_dataset
    oof_df = pd.concat([oof_df, _oof_df], axis = 0)
    del _oof_df
    gc.collect()
    torch.cuda.empty_cache()
    return oof_df

# %%
if CFG["kaggle"]:
    oof_df = training_loop(target_df)
    wandb.finish()
else:
    with mlflow.start_run(experiment_id=experiment_id, run_name=CFG["EXP_NAME"]) as run:
        mlflow.log_dict(CFG, "configuration.yaml")
        mlflow.log_param("positive data num", len(target_df[target_df["contact"]==1]))
        mlflow.log_param("negative data num", len(target_df[target_df["contact"]==0]))
        oof_df = training_loop(target_df)
# Out:
# 	 === epoch: 1: training ===
# 	 Epoch: [1][0/8782] Elapsed 0m 1s (remain 234m 20s) Loss: 0.5872(0.5872)
# 	 Epoch: [1][1000/8782] Elapsed 2m 2s (remain 15m 55s) Loss: 0.2798(0.2666)
# 	 Epoch: [1][2000/8782] Elapsed 4m 4s (remain 13m 49s) Loss: 0.0623(0.2422)
# 	 Epoch: [1][3000/8782] Elapsed 6m 7s (remain 11m 47s) Loss: 0.2162(0.2293)
# 	 Epoch: [1][4000/8782] Elapsed 8m 9s (remain 9m 44s) Loss: 0.2849(0.2209)
# 	 Epoch: [1][5000/8782] Elapsed 10m 11s (remain 7m 42s) Loss: 0.1853(0.2140)
# 	 Epoch: [1][6000/8782] Elapsed 12m 13s (remain 5m 39s) Loss: 0.3232(0.2091)
# 	 Epoch: [1][7000/8782] Elapsed 14m 15s (remain 3m 37s) Loss: 0.2832(0.2048)
# 	 Epoch: [1][8000/8782] Elapsed 16m 18s (remain 1m 35s) Loss: 0.0772(0.2018)
# 	 Epoch: [1][8781/8782] Elapsed 17m 53s (remain 0m 0s) Loss: 0.1179(0.1994)
# 	 EVAL: [0/756] Elapsed 0m 1s (remain 13m 7s) Loss: 0.0161(0.0161)
# 	 EVAL: [755/756] Elapsed 1m 39s (remain 0m 0s) Loss: 0.0059(0.1842)
# 	 epoch:1, avg train loss:0.1994, avg valid loss:0.1842, score:0.5459(th=0.2) ::: time:1172.93s
# 	 Epoch 1 - Save Best Score: 0.5459. Model is saved.
# 	 Epoch 1 - Save Best AUC Score: 0.9238. Model is saved.
# 	 === epoch: 2: training ===
# 	 Epoch: [2][0/8782] Elapsed 0m 1s (remain 147m 41s) Loss: 0.2025(0.2025)
# 	 Epoch: [2][1000/8782] Elapsed 2m 0s (remain 15m 33s) Loss: 0.2261(0.1712)
# 	 Epoch: [2][2000/8782] Elapsed 3m 58s (remain 13m 28s) Loss: 0.0217(0.1679)
# 	 Epoch: [2][3000/8782] Elapsed 5m 57s (remain 11m 28s) Loss: 0.2164(0.1667)
# 	 Epoch: [2][4000/8782] Elapsed 7m 55s (remain 9m 28s) Loss: 0.0790(0.1667)
# 	 Epoch: [2][5000/8782] Elapsed 9m 54s (remain 7m 29s) Loss: 0.2440(0.1662)
# 	 Epoch: [2][6000/8782] Elapsed 11m 52s (remain 5m 30s) Loss: 0.0351(0.1651)
# 	 Epoch: [2][7000/8782] Elapsed 13m 51s (remain 3m 31s) Loss: 0.1698(0.1636)
# 	 Epoch: [2][8000/8782] Elapsed 15m 49s (remain 1m 32s) Loss: 0.2180(0.1635)
# 	 Epoch: [2][8781/8782] Elapsed 17m 22s (remain 0m 0s) Loss: 0.0603(0.1631)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 55s) Loss: 0.0219(0.0219)
# 	 EVAL: [755/756] Elapsed 1m 31s (remain 0m 0s) Loss: 0.0026(0.1699)
# 	 epoch:2, avg train loss:0.1631, avg valid loss:0.1699, score:0.5626(th=0.4) ::: time:2307.48s
# 	 Epoch 2 - Save Best Score: 0.5626. Model is saved.
# 	 Epoch 2 - Save Best AUC Score: 0.9274. Model is saved.
# 	 === epoch: 3: training ===
# 	 Epoch: [3][0/8782] Elapsed 0m 1s (remain 151m 2s) Loss: 0.0471(0.0471)
# 	 Epoch: [3][1000/8782] Elapsed 1m 58s (remain 15m 24s) Loss: 0.1022(0.1522)
# 	 Epoch: [3][2000/8782] Elapsed 3m 57s (remain 13m 24s) Loss: 0.1103(0.1498)
# 	 Epoch: [3][3000/8782] Elapsed 5m 56s (remain 11m 27s) Loss: 0.1657(0.1476)
# 	 Epoch: [3][4000/8782] Elapsed 7m 54s (remain 9m 27s) Loss: 0.1187(0.1479)
# 	 Epoch: [3][5000/8782] Elapsed 9m 53s (remain 7m 28s) Loss: 0.3690(0.1486)
# 	 Epoch: [3][6000/8782] Elapsed 11m 52s (remain 5m 29s) Loss: 0.2047(0.1487)
# 	 Epoch: [3][7000/8782] Elapsed 13m 50s (remain 3m 31s) Loss: 0.1089(0.1484)
# 	 Epoch: [3][8000/8782] Elapsed 15m 49s (remain 1m 32s) Loss: 0.0753(0.1479)
# 	 Epoch: [3][8781/8782] Elapsed 17m 21s (remain 0m 0s) Loss: 0.0027(0.1478)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 54s) Loss: 0.0315(0.0315)
# 	 EVAL: [755/756] Elapsed 1m 32s (remain 0m 0s) Loss: 0.0042(0.1764)
# 	 epoch:3, avg train loss:0.1478, avg valid loss:0.1764, score:0.5684(th=0.5) ::: time:3442.53s
# 	 Epoch 3 - Save Best Score: 0.5684. Model is saved.
# 	 === epoch: 4: training ===
# 	 Epoch: [4][0
# 	 Epoch: [9][6000/8782] Elapsed 11m 52s (remain 5m 30s) Loss: 0.1073(0.0666)
# 	 Epoch: [9][7000/8782] Elapsed 13m 51s (remain 3m 31s) Loss: 0.0132(0.0666)
# 	 Epoch: [9][8000/8782] Elapsed 15m 50s (remain 1m 32s) Loss: 0.0293(0.0667)
# 	 Epoch: [9][8781/8782] Elapsed 17m 22s (remain 0m 0s) Loss: 0.0007(0.0671)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 53s) Loss: 0.0146(0.0146)
# 	 EVAL: [755/756] Elapsed 1m 31s (remain 0m 0s) Loss: 0.0001(0.2401)
# 	 epoch:9, avg train loss:0.0671, avg valid loss:0.2401, score:0.5588(th=0.30000000000000004) ::: time:10251.40s
# 	 === epoch: 10: training ===
# 	 Epoch: [10][0/8782] Elapsed 0m 1s (remain 156m 38s) Loss: 0.0991(0.0991)
# 	 Epoch: [10][1000/8782] Elapsed 1m 59s (remain 15m 25s) Loss: 0.0657(0.0569)
# 	 Epoch: [10][2000/8782] Elapsed 3m 57s (remain 13m 25s) Loss: 0.0828(0.0599)
# 	 Epoch: [10][3000/8782] Elapsed 5m 56s (remain 11m 27s) Loss: 0.0612(0.0598)
# 	 Epoch: [10][4000/8782] Elapsed 7m 54s (remain 9m 27s) Loss: 0.0392(0.0600)
# 	 Epoch: [10][5000/8782] Elapsed 9m 53s (remain 7m 28s) Loss: 0.1215(0.0597)
# 	 Epoch: [10][6000/8782] Elapsed 11m 53s (remain 5m 30s) Loss: 0.0979(0.0600)
# 	 Epoch: [10][7000/8782] Elapsed 13m 51s (remain 3m 31s) Loss: 0.0229(0.0601)
# 	 Epoch: [10][8000/8782] Elapsed 15m 50s (remain 1m 32s) Loss: 0.0240(0.0601)
# 	 Epoch: [10][8781/8782] Elapsed 17m 22s (remain 0m 0s) Loss: 0.5774(0.0601)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 9m 12s) Loss: 0.0106(0.0106)
# 	 EVAL: [755/756] Elapsed 1m 31s (remain 0m 0s) Loss: 0.0000(0.2636)
# 	 epoch:10, avg train loss:0.0601, avg valid loss:0.2636, score:0.5510(th=0.30000000000000004) ::: time:11386.24s
# 	 === epoch: 11: training ===
# 	 Epoch: [11][0/8782] Elapsed 0m 1s (remain 156m 42s) Loss: 0.1101(0.1101)
# 	 Epoch: [11][1000/8782] Elapsed 1m 59s (remain 15m 26s) Loss: 0.0473(0.0613)
# 	 Epoch: [11][2000/8782] Elapsed 3m 57s (remain 13m 26s) Loss: 0.0278(0.0599)
# 	 Epoch: [11][3000/8782] Elapsed 5m 56s (remain 11m 27s) Loss: 0.0098(0.0593)
# 	 Epoch: [11][4000/8782] Elapsed 7m 55s (remain 9m 27s) Loss: 0.1422(0.0588)
# 	 Epoch: [11][5000/8782] Elapsed 9m 53s (remain 7m 28s) Loss: 0.0072(0.0588)
# 	 Epoch: [11][6000/8782] Elapsed 11m 52s (remain 5m 30s) Loss: 0.0242(0.0585)
# 	 Epoch: [11][7000/8782] Elapsed 13m 50s (remain 3m 31s) Loss: 0.1388(0.0585)
# 	 Epoch: [11][8000/8782] Elapsed 15m 49s (remain 1m 32s) Loss: 0.1695(0.0585)
# 	 Epoch: [11][8781/8782] Elapsed 17m 22s (remain 0m 0s) Loss: 0.0150(0.0587)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 36s) Loss: 0.0106(0.0106)
# 	 EVAL: [755/756] Elapsed 1m 31s (remain 0m 0s) Loss: 0.0000(0.2635)
# 	 epoch:11, avg train loss:0.0587, avg valid loss:0.2635, score:0.5514(th=0.30000000000000004) ::: time:12521.19s
# 	 === epoch: 12: training ===
# 	 Epoch: [12][0/8782] Elapsed 0m 0s (remain 125m 15s) Loss: 0.1661(0.1661)
# 	 Epoch: [12][1000/8782] Elapsed 1m 59s (remain 15m 28s) Loss: 0.0158(0.0572)

# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 56s) Loss: 0.0096(0.0096)
# 	 EVAL: [755/756] Elapsed 1m 32s (remain 0m 0s) Loss: 0.0000(0.2591)
# 	 epoch:14, avg train loss:0.0627, avg valid loss:0.2591, score:0.5551(th=0.30000000000000004) ::: time:15925.29s
# 	 === epoch: 15: training ===
# 	 Epoch: [15][0/8782] Elapsed 0m 1s (remain 157m 59s) Loss: 0.0858(0.0858)
# 	 Epoch: [15][1000/8782] Elapsed 2m 0s (remain 15m 38s) Loss: 0.0035(0.0622)
# 	 Epoch: [15][2000/8782] Elapsed 4m 0s (remain 13m 34s) Loss: 0.1843(0.0630)
# 	 Epoch: [15][3000/8782] Elapsed 6m 0s (remain 11m 34s) Loss: 0.1190(0.0633)
# 	 Epoch: [15][4000/8782] Elapsed 8m 0s (remain 9m 33s) Loss: 0.0134(0.0642)
# 	 Epoch: [15][5000/8782] Elapsed 10m 0s (remain 7m 33s) Loss: 0.0436(0.0642)
# 	 Epoch: [15][6000/8782] Elapsed 11m 59s (remain 5m 33s) Loss: 0.0889(0.0646)
# 	 Epoch: [15][7000/8782] Elapsed 13m 59s (remain 3m 33s) Loss: 0.0302(0.0654)
# 	 Epoch: [15][8000/8782] Elapsed 15m 59s (remain 1m 33s) Loss: 0.0924(0.0659)
# 	 Epoch: [15][8781/8782] Elapsed 17m 32s (remain 0m 0s) Loss: 0.0493(0.0663)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 12m 7s) Loss: 0.0136(0.0136)
# 	 EVAL: [755/756] Elapsed 1m 37s (remain 0m 0s) Loss: 0.0001(0.2426)
# 	 epoch:15, avg train loss:0.0663, avg valid loss:0.2426, score:0.5689(th=0.2) ::: time:17076.26s
# 	 === epoch: 16: training ===
# 	 Epoch: [16][0/8782] Elapsed 0m 1s (remain 150m 21s) Loss: 0.0435(0.0435)
# 	 Epoch: [16][1000/8782] Elapsed 1m 59s (remain 15m 26s) Loss: 0.0199(0.0663)
# 	 Epoch: [16][2000/8782] Elapsed 3m 57s (remain 13m 24s) Loss: 0.0713(0.0663)
# 	 Epoch: [16][3000/8782] Elapsed 5m 56s (remain 11m 27s) Loss: 0.0409(0.0678)
# 	 Epoch: [16][4000/8782] Elapsed 7m 54s (remain 9m 27s) Loss: 0.0221(0.0690)
# 	 Epoch: [16][5000/8782] Elapsed 9m 53s (remain 7m 28s) Loss: 0.2595(0.0697)
# 	 Epoch: [16][6000/8782] Elapsed 11m 52s (remain 5m 29s) Loss: 0.4071(0.0704)
# 	 Epoch: [16][7000/8782] Elapsed 13m 50s (remain 3m 31s) Loss: 0.0282(0.0713)
# 	 Epoch: [16][8000/8782] Elapsed 15m 48s (remain 1m 32s) Loss: 0.1165(0.0721)
# 	 Epoch: [16][8781/8782] Elapsed 17m 21s (remain 0m 0s) Loss: 0.0001(0.0725)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 9m 58s) Loss: 0.0618(0.0618)
# 	 EVAL: [755/756] Elapsed 1m 32s (remain 0m 0s) Loss: 0.0001(0.2362)
# 	 epoch:16, avg train loss:0.0725, avg valid loss:0.2362, score:0.5522(th=0.6000000000000001) ::: time:18210.67s
# 	 === epoch: 17: training ===
# 	 Epoch: [17][0/8782] Elapsed 0m 0s (remain 140m 53s) Loss: 0.0359(0.0359)
# 	 Epoch: [17][1000/8782] Elapsed 1m 59s (remain 15m 25s) Loss: 0.1614(0.0713)
# 	 Epoch: [17][2000/8782] Elapsed 3m 57s (remain 13m 24s) Loss: 0.1259(0.0732)
# 	 Epoch: [17][3000/8782] Elapsed 5m 56s (remain 11m 27s) Loss: 0.0286(0.0748)
# 	 Epoch: [17][4000/8782] Elapsed 7m 55s (remain 9m 27s) Loss: 0.0215(0.0760)
# 	 Epoch: [17][5000/8782] Elapsed 9m 53s (remain 7m 28s) Loss: 0.0560(0.0767)
# 	 Epoch: [17][6000/8782] Elapsed 11m 52s (remain 5m 30s) Loss: 0.0598(0.0768)
# 	 Epoch: [17][7000/8782] Elapsed 13m 50s (remain 3m 31s) Loss: 0.0193(0.0776)
# 	 Epoch: [17][8000/8782] Elapsed 15m 49s (remain 1m 32s) Loss: 0.0775(0.0782)
# 	 Epoch: [17][8781/8782] Elapsed 17m 22s (remain 0m 0s) Loss: 0.0092(0.0788)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 9m 10s) Loss: 0.0100(0.0100)
# 	 EVAL: [755/756] Elapsed 1m 31s (remain 0m 0s) Loss: 0.0001(0.2445)
# 	 epoch:17, avg train loss:0.0788, avg valid loss:0.2445, score:0.5443(th=0.2) ::: time:19344.44s
# 	 === epoch: 18: training ===
# 	 Epoch: [18][0/8782] Elapsed 0m 0s (remain 143m 10s) Loss: 0.1734(0.1734)
# 	 Epoch: [18][1000/8782] Elapsed 1m 59s (remain 15m 28s) Loss: 0.0240(0.0753)
# 	 Epoch: [18][2000/8782] Elapsed 3m 57s (remain 13m 26s) Loss: 0.0587(0.0788)
# 	 Epoch: [18][3000/8782] Elapsed 5m 56s (remain 11m 26s) Loss: 0.0771(0.0804)
# 	 Epoch: [18][4000/8782] Elapsed 7m 54s (remain 9m 27s) Loss: 0.0551(0.0813)
# 	 Epoch: [18][5000/8782] Elapsed 9m 53s (remain 7m 28s) Loss: 0.1005(0.0818)
# 	 Epoch: [18][6000/8782] Elapsed 11m 52s (remain 5m 29s) Loss: 0.0861(0.0827)
# 	 Epoch: [18][7000/8782] Elapsed 13m 50s (remain 3m 31s) Loss: 0.0504(0.0829)
# 	 Epoch: [18][8000/8782] Elapsed 15m 49s (remain 1m 32s) Loss: 0.1712(0.0831)
# 	 Epoch: [18][8781/8782] Elapsed 17m 21s (remain 0m 0s) Loss: 0.0064(0.0836)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 9m 32s) Loss: 0.0148(0.0148)
# 	 EVAL: [755/756] Elapsed 1m 32s (remain 0m 0s) Loss: 0.0005(0.2071)
# 	 epoch:18, avg train loss:0.0836, avg valid loss:0.2071, score:0.5677(th=0.30000000000000004) ::: time:20479.90s
# 	 === epoch: 19: training ===
# 	 Epoch: [19][0/8782] Elapsed 0m 1s (remain 176m 42s) Loss: 0.0668(0.0668)
# 	 Epoch: [19][1000/8782] Elapsed 1m 59s (remain 15m 30s) Loss: 0.1067(0.0773)
# 	 Epoch: [19][2000/8782] Elapsed 3m 59s (remain 13m 30s) Loss: 0.2049(0.0798)
# 	 Epoch: [19][3000/8782] Elapsed 5m 57s (remain 11m 28s) Loss: 0.0124(0.0804)
# 	 Epoch: [19][4000/8782] Elapsed 7m 55s (remain 9m 28s) Loss: 0.1422(0.0823)
# 	 Epoch: [19][5000/8782] Elapsed 9m 54s (remain 7m 29s) Loss: 0.0508(0.0831)
# 	 Epoch: [19][6000/8782] Elapsed 11m 52s (remain 5m 30s) Loss: 0.0740(0.0846)
# 	 Epoch: [19][7000/8782] Elapsed 13m 50s (remain 3m 31s) Loss: 0.1416(0.0855)
# 	 Epoch: [19][8000/8782] Elapsed 15m 49s (remain 1m 32s) Loss: 0.2004(0.0859)
# 	 Epoch: [19][8781/8782] Elapsed 17m 22s (remain 0m 0s) Loss: 0.0105(0.0863)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 36s) Loss: 0.0114(0.0114)
# 	 EVAL: [755/756] Elapsed 1m 31s (remain 0m 0s) Loss: 0.0013(0.2031)
# 	 epoch:19, avg train loss:0.0863, avg valid loss:0.2031, score:0.5805(th=0.30000000000000004) ::: time:21614.55s
# 	 Epoch 19 - Save Best Score: 0.5805. Model is saved.
# 	 Epoch 19 - Save Best AUC Score: 0.9293. Model is saved.
# 	 === epoch: 20: training ===
# 	 Epoch: [20][0/8782] Elapsed 0m 0s (remain 142m 43s) Loss: 0.0380(0.0380)
# 	 Epoch: [20][1000/8782] Elapsed 1m 59s (remain 15m 30s) Loss: 0.0811(0.0848)
# 	 Epoch: [20][2000/8782] Elapsed 3m 58s (remain 13m 26s) Loss: 0.1009(0.0862)
# 	 Epoch: [20][3000/8782] Elapsed 5m 56s (remain 11m 27s) Loss: 0.0780(0.0874)
# 	 Epoch: [20][4000/8782] Elapsed 7m 55s (remain 9m 27s) Loss: 0.0392(0.0873)
# 	 Epoch: [20][5000/8782] Elapsed 9m 53s (remain 7m 28s) Loss: 0.0062(0.0874)
# 	 Epoch: [20][6000/8782] Elapsed 11m 51s (remain 5m 29s) Loss: 0.0850(0.0878)
# 	 Epoch: [20][7000/8782] Elapsed 13m 50s (remain 3m 31s) Loss: 0.0797(0.0884)
# 	 Epoch: [20][8000/8782] Elapsed 15m 49s (remain 1m 32s) Loss: 0.0378(0.0884)
# 	 Epoch: [20][8781/8782] Elapsed 17m 21s (remain 0m 0s) Loss: 0.3092(0.0886)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 43s) Loss: 0.0240(0.0240)
# 	 EVAL: [755/756] Elapsed 1m 31s (remain 0m 0s) Loss: 0.0014(0.1973)
# 	 epoch:20, avg train loss:0.0886, avg valid loss:0.1973, score:0.5839(th=0.30000000000000004) ::: time:22748.56s
# 	 Epoch 20 - Save Best Score: 0.5839. Model is saved.
# 	 === epoch: 21: training ===
# 	 Epoch: [21][0/8782] Elapsed 0m 0s (remain 138m 14s) Loss: 0.0266(0.0266)
# 	 Epoch: [21][1000/8782] Elapsed 2m 0s (remain 15m 34s) Loss: 0.0214(0.0842)
# 	 Epoch: [21][2000/8782] Elapsed 3m 58s (remain 13m 27s) Loss: 0.1005(0.0843)
# 	 Epoch: [21][3000/8782] Elapsed 5m 56s (remain 11m 27s) Loss: 0.0331(0.0839)
# 	 Epoch: [21][4000/8782] Elapsed 7m 55s (remain 9m 28s) Loss: 0.0809(0.0846)
# 	 Epoch: [21][5000/8782] Elapsed 9m 53s (remain 7m 28s) Loss: 0.2053(0.0855)
# 	 Epoch: [21][6000/8782] Elapsed 11m 52s (remain 5m 29s) Loss: 0.1074(0.0863)
# 	 Epoch: [21][7000/8782] Elapsed 13m 51s (remain 3m 31s) Loss: 0.0147(0.0868)
# 	 Epoch: [21][8000/8782] Elapsed 15m 49s (remain 1m 32s) Loss: 0.1226(0.0872)
# 	 Epoch: [21][8781/8782] Elapsed 17m 21s (remain 0m 0s) Loss: 0.0059(0.0873)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 51s) Loss: 0.0079(0.0079)
# 	 EVAL: [755/756] Elapsed 1m 31s (remain 0m 0s) Loss: 0.0039(0.2401)
# 	 epoch:21, avg train loss:0.0873, avg valid loss:0.2401, score:0.5518(th=0.30000000000000004) ::: time:23882.77s
# 	 === epoch: 22: training ===
# 	 Epoch: [22][0/8782] Elapsed 0m 1s (remain 147m 20s) Loss: 0.0451(0.0451)
# 	 Epoch: [22][1000/8782] Elapsed 1m 59s (remain 15m 29s) Loss: 0.0618(0.0783)
# 	 Epoch: [22][2000/8782] Elapsed 3m 57s (remain 13m 26s) Loss: 0.0938(0.0786)
# 	 Epoch: [22][3000/8782] Elapsed 5m 56s (remain 11m 27s) Loss: 0.0924(0.0788)
# 	 Epoch: [22][4000/8782] Elapsed 7m 55s (remain 9m 28s) Loss: 0.0568(0.0797)
# 	 Epoch: [22][5000/8782] Elapsed 9m 53s (remain 7m 28s) Loss: 0.0597(0.0794)
# 	 Epoch: [22][6000/8782] Elapsed 11m 52s (remain 5m 30s) Loss: 0.0476(0.0797)
# 	 Epoch: [22][7000/8782] Elapsed 13m 50s (remain 3m 31s) Loss: 0.0412(0.0808)
# 	 Epoch: [22][8000/8782] Elapsed 15m 49s (remain 1m 32s) Loss: 0.0665(0.0815)
# 	 Epoch: [22][8781/8782] Elapsed 17m 21s (remain 0m 0s) Loss: 0.0132(0.0816)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 47s) Loss: 0.0125(0.0125)
# 	 EVAL: [755/756] Elapsed 1m 32s (remain 0m 0s) Loss: 0.0004(0.2065)
# 	 epoch:22, avg train loss:0.0816, avg valid loss:0.2065, score:0.5796(th=0.30000000000000004) ::: time:25018.04s
# 	 === epoch: 23: training ===
# 	 Epoch: [23][0/8782] Elapsed 0m 0s (remain 144m 41s) Loss: 0.0421(0.0421)
# 	 Epoch: [23][1000/8782] Elapsed 1m 59s (remain 15m 27s) Loss: 0.0298(0.0681)
# 	 Epoch: [23][2000/8782] Elapsed 3m 57s (remain 13m 25s) Loss: 0.1691(0.0699)
# 	 Epoch: [23][3000/8782] Elapsed 5m 56s (remain 11m 27s) Loss: 0.1721(0.0715)
# 	 Epoch: [23][4000/8782] Elapsed 7m 54s (remain 9m 27s) Loss: 0.0519(0.0726)
# 	 Epoch: [23][5000/8782] Elapsed 9m 53s (remain 7m 28s) Loss: 0.0455(0.0728)
# 	 Epoch: [23][6000/8782] Elapsed 11m 52s (remain 5m 29s) Loss: 0.0023(0.0735)
# 	 Epoch: [23][7000/8782] Elapsed 13m 50s (remain 3m 31s) Loss: 0.0228(0.0740)
# 	 Epoch: [23][8000/8782] Elapsed 15m 48s (remain 1m 32s) Loss: 0.1211(0.0748)
# 	 Epoch: [23][8781/8782] Elapsed 17m 21s (remain 0m 0s) Loss: 0.0934(0.0749)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 47s) Loss: 0.0063(0.0063)
# 	 EVAL: [755/756] Elapsed 1m 31s (remain 0m 0s) Loss: 0.0049(0.2298)
# 	 epoch:23, avg train loss:0.0749, avg valid loss:0.2298, score:0.5587(th=0.2) ::: time:26151.88s
# 	 === epoch: 24: training ===
# 	 Epoch: [24][0/8782] Elapsed 0m 0s (remain 133m 6s) Loss: 0.0246(0.0246)
# 	 Epoch: [24][1000/8782] Elapsed 1m 59s (remain 15m 26s) Loss: 0.0196(0.0641)
# 	 Epoch: [24][2000/8782] Elapsed 3m 57s (remain 13m 26s) Loss: 0.0387(0.0644)
# 	 Epoch: [24][3000/8782] Elapsed 5m 56s (remain 11m 26s) Loss: 0.0560(0.0641)
# 	 Epoch: [24][4000/8782] Elapsed 7m 54s (remain 9m 27s) Loss: 0.0784(0.0645)
# 	 Epoch: [24][5000/8782] Elapsed 9m 53s (remain 7m 28s) Loss: 0.0327(0.0649)
# 	 Epoch: [24][6000/8782] Elapsed 11m 51s (remain 5m 29s) Loss: 0.0463(0.0654)
# 	 Epoch: [24][7000/8782] Elapsed 13m 50s (remain 3m 31s) Loss: 0.0196(0.0657)
# 	 Epoch: [24][8000/8782] Elapsed 15m 49s (remain 1m 32s) Loss: 0.0498(0.0663)
# 	 Epoch: [24][8781/8782] Elapsed 17m 21s (remain 0m 0s) Loss: 0.0209(0.0665)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 47s) Loss: 0.0067(0.0067)
# 	 EVAL: [755/756] Elapsed 1m 31s (remain 0m 0s) Loss: 0.0001(0.2434)
# 	 epoch:24, avg train loss:0.0665, avg valid loss:0.2434, score:0.5605(th=0.30000000000000004) ::: time:27285.45s
# 	 === epoch: 25: training ===
# 	 Epoch: [25][0/8782] Elapsed 0m 1s (remain 149m 30s) Loss: 0.0082(0.0082)
# 	 Epoch: [25][1000/8782] Elapsed 2m 0s (remain 15m 33s) Loss: 0.0485(0.0529)
# 	 Epoch: [25][2000/8782] Elapsed 3m 58s (remain 13m 28s) Loss: 0.0190(0.0528)
# 	 Epoch: [25][3000/8782] Elapsed 5m 57s (remain 11m 27s) Loss: 0.0278(0.0547)
# 	 Epoch: [25][4000/8782] Elapsed 7m 55s (remain 9m 28s) Loss: 0.0654(0.0542)
# 	 Epoch: [25][5000/8782] Elapsed 9m 54s (remain 7m 29s) Loss: 0.0163(0.0549)
# 	 Epoch: [25][6000/8782] Elapsed 11m 52s (remain 5m 30s) Loss: 0.0839(0.0550)
# 	 Epoch: [25][7000/8782] Elapsed 13m 49s (remain 3m 31s) Loss: 0.0131(0.0555)
# 	 Epoch: [25][8000/8782] Elapsed 15m 46s (remain 1m 32s) Loss: 0.0948(0.0556)
# 	 Epoch: [25][8781/8782] Elapsed 17m 17s (remain 0m 0s) Loss: 0.2074(0.0561)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 9m

# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 39s) Loss: 0.0028(0.0028)
# 	 EVAL: [755/756] Elapsed 1m 31s (remain 0m 0s) Loss: 0.0000(0.2922)
# 	 epoch:39, avg train loss:0.0517, avg valid loss:0.2922, score:0.5569(th=0.2) ::: time:44146.22s
# 	 === epoch: 40: training ===
# 	 Epoch: [40][0/8782] Elapsed 0m 0s (remain 128m 3s) Loss: 0.0749(0.0749)
# 	 Epoch: [40][1000/8782] Elapsed 1m 57s (remain 15m 12s) Loss: 0.0426(0.0474)
# 	 Epoch: [40][2000/8782] Elapsed 3m 55s (remain 13m 18s) Loss: 0.0926(0.0487)
# 	 Epoch: [40][3000/8782] Elapsed 5m 54s (remain 11m 22s) Loss: 0.0078(0.0494)
# 	 Epoch: [40][4000/8782] Elapsed 7m 52s (remain 9m 24s) Loss: 0.0371(0.0507)
# 	 Epoch: [40][5000/8782] Elapsed 9m 51s (remain 7m 27s) Loss: 0.0496(0.0515)
# 	 Epoch: [40][6000/8782] Elapsed 11m 49s (remain 5m 29s) Loss: 0.1005(0.0523)
# 	 Epoch: [40][7000/8782] Elapsed 13m 48s (remain 3m 30s) Loss: 0.0202(0.0533)
# 	 Epoch: [40][8000/8782] Elapsed 15m 47s (remain 1m 32s) Loss: 0.0528(0.0536)
# 	 Epoch: [40][8781/8782] Elapsed 17m 20s (remain 0m 0s) Loss: 0.0001(0.0542)
# 	 EVAL: [0/756] Elapsed 0m 0s (remain 8m 52s) Loss: 0.0029(0.0029)
# 	 EVAL: [755/756] Elapsed 1m 32s (remain 0m 0s) Loss: 0.0001(0.2514)
# 	 epoch:40, avg train loss:0.0542, avg valid loss:0.2514, score:0.5704(th=0.30000000000000004) ::: time:45279.65s

# %%
display(oof_df)
if CFG["kaggle"]:
    oof_filename = os.path.join(CFG["OUTPUT_DIR"], "oof_df.csv")
    oof_df.to_csv(oof_filename, index=False)
else:
    oof_filename = os.path.join(CFG["OUTPUT_DIR"], CFG["EXP_NAME"], "oof_df.csv")
    oof_df.to_csv(oof_filename, index=False)
# Out:
#                        contact_id      pred  contact  fold
# 0      58573_000445_0_46131_47976  0.085422        0     0
# 1      58573_000445_0_47801_47976  0.000567        0     0
# 2      58573_000445_0_47801_52466  0.000978        0     0
# 3      58573_000445_0_44834_44888  0.006057        0     0
# 4      58573_000445_0_40171_47801  0.431797        0     0
# ...                           ...       ...      ...   ...
# 24162     58582_003121_91_48220_G  0.002690        0     0
# 24163     58582_003121_91_47906_G  0.001503        0     0
# 24164     58582_003121_91_38557_G  0.001845        0     0
# 24165     58582_003121_91_47872_G  0.000516        0     0
# 24166     58582_003121_91_52619_G  0.002107        0     0
#
# [24167 rows x 4 columns]

# %% [markdown]
# # Create CNN-Emb df

# %%
target_df = pd.read_csv(CFG["TARGET_CSV"])
target_game_plays = target_df["game_play"].unique()[-100:]
CFG["target_game_plays"] = list(target_game_plays)
target_df = target_df[target_df["game_play"].isin(target_game_plays)]

if CFG["DEBUG"]:
    target_df = target_df.sample(CFG["sample_num"])
elif CFG["sample_num"] != -1:
    target_df = target_df.sample(CFG["sample_num"])

target_df = target_df.reset_index(drop=True)
target_df["is_ground"] = (target_df["nfl_player_id_2"] == "G").astype(np.int)
target_df["is_helmet"] = 1 - ((target_df["E_width_1"]==0) & (target_df["E_width_2"]==0) & (target_df["S_width_1"]==0) & (target_df["S_width_2"]==0)).astype(np.int)
print(len(target_df))
display(target_df["contact"].value_counts())
# Out:
# 276406
# 0    251345
# 1     25061
# Name: contact, dtype: int64

# %%
emb_dataset = NFLDataset(target_df, valid_transform)
emb_loader = DataLoader(
    emb_dataset,
    batch_size = CFG["batch_size"],
    shuffle = False,
    num_workers = CFG["num_workers"],
    pin_memory = True
)
model = NFLNet()
model = model.to(device)
# model.load_state_dict(torch.load(CFG["trained_model_path"]))
model.load_state_dict(torch.load(f'{CFG["MODEL_DIR"]}/{CFG["model_name"]}_fold0.pth'))
model.eval()# モデルを検証モードに設定
cnn_features = []
preds_list = []
for batch_idx, (images, features, track_features, targets) in enumerate(emb_loader):
    print("\r {}/{}".format(batch_idx, len(emb_loader)), end="")
    images = images.to(device, non_blocking = True).float()
    features = features.to(device, non_blocking = True).float()
    track_features = track_features.to(device, non_blocking = True).float()    
    preds, emb = model(images, features, track_features)    
    emb_numpy = emb.detach().cpu().numpy()
    pred_numpy = preds.detach().cpu().numpy()
    cnn_features.extend(emb_numpy)
    preds_list.extend(pred_numpy)
# Out:
#  8637/8638

# %%
cnn_feature_df = pd.DataFrame(cnn_features, columns=[f'cnn_feature_{i}' for i in range(CFG["num_extractFTR"])])
# display(cnn_feature_df)

feat_num = CFG["num_extractFTR"]
preds_list_numpy = np.array(preds_list)
preds_list_numpy = preds_list_numpy.reshape(len(preds_list_numpy))
cnn_feature_df[f"cnn_feature_{feat_num}"] = preds_list_numpy
display(cnn_feature_df)
# Out:
#         cnn_feature_0  cnn_feature_1  cnn_feature_2  cnn_feature_3  \
# 0           -0.402914       0.171212       0.283435      -0.711763
# 1           -5.846717      -2.213527       1.358395       3.287734
# 2           -3.480849      -1.537423       0.882689       1.373709
# 3           -4.421182      -2.041551       0.860458       1.946726
# 4           -6.019276      -2.261920       1.350199       3.595107
# ...               ...            ...            ...            ...
# 276401      -4.688267      -1.787112       0.515126       2.733101
# 276402      -4.404750      -2.027193       1.346005       2.637756
# 276403      -3.930404      -1.552160       1.507079       1.787443
# 276404      -5.793984      -2.665453       1.026881       3.244825
# 276405      -4.466434      -1.527102       0.698936       1.951853
#
#         cnn_feature_4  cnn_feature_5
# 0           -3.745834      -2.308999
# 1           -6.748484      -8.201353
# 2           -5.240338      -5.810124
# 3           -5.016138      -6.806514
# 4           -7.012475      -9.686205
# ...               ...            ...
# 276401      -3.037546      -5.914847
# 276402      -5.030002      -6.497926
# 276403      -5.198478      -6.292576
# 276404      -4.477664      -7.568016
# 276405      -3.948841      -6.159570
#
# [276406 rows x 6 columns]

# %%
concat_df = target_df.copy()
concat_df = pd.concat([target_df, cnn_feature_df], axis=1)
display(concat_df)
cnn_features_filename = os.path.join(CFG["OUTPUT_DIR"], CFG["EXP_NAME"] ,"target_cnn_emb.csv")
concat_df.to_csv(cnn_features_filename, index=False)
# Out:
#                         contact_id     game_play  \
# 0       58403_001076_0_46082_46232  58403_001076
# 1       58403_001076_0_42424_46082  58403_001076
# 2       58403_001076_0_42424_46232  58403_001076
# 3       58403_001076_0_42424_44876  58403_001076
# 4       58403_001076_0_42393_46649  58403_001076
# ...                            ...           ...
# 276401     58582_003121_91_48220_G  58582_003121
